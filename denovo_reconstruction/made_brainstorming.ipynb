# %%
import cobra
import pandas as pd
import numpy as np
import os
import glob
from cobra import Model, Reaction, Metabolite
import subprocess
from cobra.flux_analysis.parsimonious import add_pfba
from cobra import test
print (cobra.__version__)

model = cobra.test.create_test_model("textbook")
# Out:
# 0.13.4

# %%
model.genes
# Out:
# [<Gene b1241 at 0x11a811668>,
#  <Gene b0351 at 0x11a8114a8>,
#  <Gene s0001 at 0x11a811208>,
#  <Gene b3115 at 0x11a8110b8>,
#  <Gene b1849 at 0x11a78bf98>,
#  <Gene b2296 at 0x11a78bb38>,
#  <Gene b1276 at 0x11a78beb8>,
#  <Gene b0118 at 0x11a78bc88>,
#  <Gene b0474 at 0x11a78bcc0>,
#  <Gene b0116 at 0x11a78bc18>,
#  <Gene b0726 at 0x11a78b9b0>,
#  <Gene b0727 at 0x11a78b5f8>,
#  <Gene b2587 at 0x11a78b710>,
#  <Gene b0356 at 0x11a78b6d8>,
#  <Gene b1478 at 0x11a78b128>,
#  <Gene b3735 at 0x11a78b4a8>,
#  <Gene b3733 at 0x11a78b160>,
#  <Gene b3734 at 0x11a78b1d0>,
#  <Gene b3732 at 0x11a77c748>,
#  <Gene b3736 at 0x11a77c860>,
#  <Gene b3738 at 0x11a77cf28>,
#  <Gene b3731 at 0x11a77cba8>,
#  <Gene b3737 at 0x11a77cd68>,
#  <Gene b3739 at 0x11a77cc88>,
#  <Gene b0720 at 0x11a77c048>,
#  <Gene b0733 at 0x11a77c9b0>,
#  <Gene b0979 at 0x11a77c780>,
#  <Gene b0978 at 0x11a77c898>,
#  <Gene b0734 at 0x11a77c908>,
#  <Gene b2975 at 0x11a77c1d0>,
#  <Gene b3603 at 0x11a77c5f8>,
#  <Gene b2779 at 0x11a77c390>,
#  <Gene b1773 at 0x11a77c0b8>,
#  <Gene b2925 at 0x11a77c2b0>,
#  <Gene b2097 at 0x11a76dc50>,
#  <Gene b4232 at 0x11a76df60>,
#  <Gene b3925 at 0x11a76d128>,
#  <Gene b0904 at 0x11a76dfd0>,
#  <Gene b2492 at 0x11a76d0b8>,
#  <Gene b4154 at 0x11a76d668>,
#  <Gene b4152 at 0x11a76d2b0>,
#  <Gene b4153 at 0x11a76d2e8>,
#  <Gene b4151 at 0x11a76dda0>,
#  <Gene b1819 at 0x11a76d080>,
#  <Gene b1817 at 0x11a76d400>,
#  <Gene b2415 at 0x11a76da90>,
#  <Gene b1818 at 0x11a76db38>,
#  <Gene b2416 at 0x11a76d208>,
#  <Gene b1611 at 0x11a76d198>,
#  <Gene b4122 at 0x11a76d860>,
#  <Gene b1612 at 0x11a76d940>,
#  <Gene b3528 at 0x11a76d780>,
#  <Gene b1852 at 0x11a76d0f0>,
#  <Gene b1779 at 0x11a75da90>,
#  <Gene b1621 at 0x11a75df98>,
#  <Gene b1101 at 0x11a75deb8>,
#  <Gene b2417 at 0x11a75db38>,
#  <Gene b3870 at 0x11a75dc50>,
#  <Gene b1297 at 0x11a75d860>,
#  <Gene b0809 at 0x11a75dc88>,
#  <Gene b0810 at 0x11a75dbe0>,
#  <Gene b0811 at 0x11a75dba8>,
#  <Gene b1761 at 0x11a75d630>,
#  <Gene b1524 at 0x11a75d940>,
#  <Gene b1812 at 0x11a75d4e0>,
#  <Gene b0485 at 0x11a75d048>,
#  <Gene b3213 at 0x11a75d2b0>,
#  <Gene b3212 at 0x11a75d278>,
#  <Gene b4077 at 0x11a74fb38>,
#  <Gene b2029 at 0x11a74fc18>,
#  <Gene b0875 at 0x11a74ff98>,
#  <Gene b1136 at 0x11a74f6a0>,
#  <Gene b4015 at 0x11a74fcf8>,
#  <Gene b2133 at 0x11a74fe10>,
#  <Gene b1380 at 0x11a74fbe0>,
#  <Gene b4014 at 0x11a74fc50>,
#  <Gene b2976 at 0x11a74f908>,
#  <Gene b3236 at 0x11a74fa20>,
#  <Gene b1479 at 0x11a74f828>,
#  <Gene b2463 at 0x11a74f2b0>,
#  <Gene b2286 at 0x11a74f668>,
#  <Gene b2279 at 0x11a74f358>,
#  <Gene b2276 at 0x11a74f3c8>,
#  <Gene b2280 at 0x11a74f208>,
#  <Gene b2288 at 0x11a74f080>,
#  <Gene b2284 at 0x11a740390>,
#  <Gene b2287 at 0x11a740f98>,
#  <Gene b2281 at 0x11a740eb8>,
#  <Gene b2277 at 0x11a740da0>,
#  <Gene b2285 at 0x11a740f28>,
#  <Gene b2282 at 0x11a740710>,
#  <Gene b2278 at 0x11a740c50>,
#  <Gene b2283 at 0x11a7409b0>,
#  <Gene b3962 at 0x11a740a20>,
#  <Gene b1602 at 0x11a740908>,
#  <Gene b1603 at 0x11a740860>,
#  <Gene b0451 at 0x11a740630>,
#  <Gene b0114 at 0x11a740470>,
#  <Gene b0115 at 0x11a7402e8>,
#  <Gene b3916 at 0x11a740198>,
#  <Gene b1723 at 0x11a7404a8>,
#  <Gene b0902 at 0x11a740240>,
#  <Gene b0903 at 0x11a732c18>,
#  <Gene b2579 at 0x11a732eb8>,
#  <Gene b3114 at 0x11a7326a0>,
#  <Gene b3952 at 0x11a732668>,
#  <Gene b3951 at 0x11a732be0>,
#  <Gene b4025 at 0x11a732c88>,
#  <Gene b2926 at 0x11a732ac8>,
#  <Gene b0767 at 0x11a732a58>,
#  <Gene b0755 at 0x11a7327f0>,
#  <Gene b3612 at 0x11a732898>,
#  <Gene b4395 at 0x11a7325f8>,
#  <Gene b3493 at 0x11a7324e0>,
#  <Gene b2987 at 0x11a732710>,
#  <Gene b3956 at 0x11a7322b0>,
#  <Gene b3403 at 0x11a7322e8>,
#  <Gene b1702 at 0x11a7320f0>,
#  <Gene b2297 at 0x11a732208>,
#  <Gene b2458 at 0x11a724828>,
#  <Gene b1676 at 0x11a724e48>,
#  <Gene b1854 at 0x11a724f60>,
#  <Gene b4301 at 0x11a724dd8>,
#  <Gene b3386 at 0x11a724a58>,
#  <Gene b2914 at 0x11a724cf8>,
#  <Gene b4090 at 0x11a724390>,
#  <Gene b0722 at 0x11a7247b8>,
#  <Gene b0724 at 0x11a724668>,
#  <Gene b0721 at 0x11a7246d8>,
#  <Gene b0723 at 0x11a724470>,
#  <Gene b0728 at 0x11a724320>,
#  <Gene b0729 at 0x11a724278>,
#  <Gene b2464 at 0x11a724080>,
#  <Gene b0008 at 0x11a716a20>,
#  <Gene b2935 at 0x11a716cc0>,
#  <Gene b2465 at 0x11a716ef0>,
#  <Gene b3919 at 0x11a716d30>]

# %%
# Out:
# array([[0.05, 0.05],
#        [0.05, 0.05],
#        [0.05, 0.05],
#        [0.05, 0.05],
#        [0.05, 0.05],
#        [0.05, 0.05],
#        [0.5 , 0.5 ]])

# %%
### FROM DRIVEN driven/src/driven/data_sets/expression_profile.py

from __future__ import absolute_import

from itertools import combinations

import numpy as np
import pandas as pd
from sympy import Min, Max, Add, Mul, Symbol
from sympy.parsing.ast_parser import parse_expr

class ExpressionProfile(object):
    """
    Representation of an expression profile.
    It can be RNA-Seq, Proteomics, TNSeq or any other profile that
    links genes/proteins to a value (continuous or discrete). It is
    the storage of single or multiple conditions as well as p-values.
    Attributes
    ----------
    identifiers: list
        The gene/protein IDs.
    conditions: list
        The conditions in the expression profile (e.g., time points,
        media conditions, etc.)
    expression: numpy.ndarray
        A 2-dimensional array having no. of genes/proteins as rows and
        no. of conditions as the columns.
    p_values: numpy.ndarray
        The p-values between conditions.
    """

    def __init__(self, identifiers, conditions, expression, p_values=None):
        """
        Instantiate a new ExpressionProfile.
        Parameters
        ----------
        identifiers: list or array-like
            Genes/Proteins for the dataset.
        conditions: list or array-like
            Conditions for the dataset.
        expression: numpy.ndarray
            Expression data being used.
        p_values: numpy.ndarray, optional (default None)
            p-values obtained from the expresion data.
        """
        array_error = "Not an array-like structure."
        dimension_error = "Expression data and label dimensions don't match."
        assert isinstance(identifiers, (list, np.ndarray)), array_error
        assert isinstance(conditions, (list, np.ndarray)), array_error
        assert isinstance(expression, np.ndarray), array_error
        assert isinstance(p_values, (type(None), np.ndarray)), array_error
        dimension = (len(identifiers), len(conditions))
        if len(identifiers) == 1:
            assert expression.shape[0] == len(conditions)
        else:
            assert expression.shape == dimension, dimension_error

        self.identifiers = identifiers
        self.identifier_index = {iden: idx for idx, iden in
                                 enumerate(identifiers)}
        self.conditions = conditions
        self._condition_index = {cond: idx for idx, cond in
                                 enumerate(conditions)}
        self.expression = expression
        self._p_values = p_values

    def __getitem__(self, item):
        """
        Index the ExpressionProfile.
        Parameters
        ----------
        item: [str, str] or [int, int] or [slice, slice]
        """
        attribute_error = ("Non-supported indexing method. "
                           "Use profile['gene', 'condition'] "
                           "or profile[1, 2].")
        if not isinstance(item, tuple):
            raise AttributeError(attribute_error)

        if isinstance(item[0], str) and isinstance(item[1], str):
            i = self.identifier_index[item[0]]
            j = self._condition_index[item[1]]
        elif isinstance(item[0], (slice, int)) and isinstance(item[1],
                                                              (slice, int)):
            i = item[0]
            j = item[1]
        else:
            raise AttributeError(attribute_error)

        return self.expression[i, j]

    def __eq__(self, other):
        """
        Check equality of two ExpressionProfiles.
        Parameters
        ----------
        other: ExpressionProfile or other object
            The object to check equality against.
        """
        if not isinstance(other, ExpressionProfile):
            return False
        else:
            if self._p_values is None and other.p_values is None:
                return self.identifiers == other.identifiers and \
                       self.conditions == other.conditions and \
                       self._p_values == other._p_values and \
                       (self.expression == other.expression).all()
            else:
                return self.identifiers == other.identifiers and \
                       self.conditions == other.conditions and \
                       (self._p_values == other._p_values).all() and \
                       (self.expression == other.expression).all()

    @classmethod
    def from_data_frame(cls, data_frame):
        """
        Read expression data from a pandas.DataFrame.
        Parameters
        ----------
        data_frame: pandas.DataFrame
            A DataFrame containing the genes as index and
            the columns as conditions.
            For more information about p-values see
            @ExpressionProfile.p_value_columns
        Returns
        -------
        ExpressionProfile
        """
        columns = data_frame.columns.tolist()
        conditions = [c for c in columns if "p-value" not in c]
        p_value_keys = [c for c in columns if "p-value" in c]
        if p_value_keys:
            p_values = data_frame[p_value_keys].values
        else:
            p_values = None

        expression = data_frame[conditions].values
        identifiers = data_frame.index.tolist()
        return ExpressionProfile(identifiers, conditions, expression, p_values)


    @property
    def data_frame(self):
        """
        Build a pandas.DataFrame from the ExpressionProfile.
        Returns
        -------
        pandas.DataFrame
        """
        if self._p_values is None:
            expression = self.expression
            conditions = self.conditions
        else:
            expression = np.concatenate((self.expression, self.p_values),
                                        axis=1)
            conditions = self.conditions + self.p_value_columns

        return pd.DataFrame(expression,
                            index=self.identifiers,
                            columns=conditions)

    @property
    def p_value_columns(self):
        """
        Generate the p-value column names.
        Returns
        -------
        list
        """
        return ["{} {} p-value".format(c[0], c[1])
                for c in combinations(self.conditions, 2)]

    @property
    def p_values(self):
        """
        Return the p-values between the conditions.
        Returns
        -------
        numpy.ndarray
        Raises
        ------
        ValueError
        """
        if not self._p_values.all():
            raise ValueError("No p-values defined.")
        else:
            return self._p_values

    @p_values.setter
    def p_values(self, p_values):
        """
        Set p_values.
        Parameters
        ----------
        p_values: numpy.ndarray
        """
        assert isinstance(p_values, (np.ndarray, type(None)))
        if p_values is not None:
            if p_values.shape[1] != len(self.p_value_columns):
                raise ValueError("Argument p-values do not cover all \
                                  conditions")

        self._p_values = p_values

    @p_values.deleter
    def p_values(self):
        """Delete p_values."""
        self._p_values = None

    def differences(self, p_value=0.005):
        """
        Calculate the differences based on the MADE method.
        Parameters
        ----------
        p_value: float, optional (default 0.005)
            A p-value to set as cutoff for calculation.
        Returns
        -------
        dict
        """
        diff = {}
        for idx, iden in enumerate(self.identifiers):
            diff[iden] = []
            for i in range(1, len(self.conditions)):
                start, end = self.expression[idx, i-1: i+1]
                p_val = self.p_values[idx, i-1]
                if p_val <= p_value:
                    if start < end:
                        diff[iden].append(+1)
                    elif start > end:
                        diff[iden].append(-1)
                    else:
                        diff[iden].append(0)
                else:
                    diff[iden].append(0)
        return diff

    def _map_gene_to_rxn(self, reaction, gene_values, by):
        """
        Map gene data to reactions (using GPR associations).
        Parameters
        ----------
        reaction: cobra.Reaction
            The reaction to map gene data to.
        gene_values: dict
            The dict of gene IDs as keys and expression values as values.
        by: str
            The method to use for mapping the gene data.
            "or2max_and2min": if more than one gene contribute as a complex,
                              the min of the gene values is taken and if the
                              genes act as isozymes, the max is taken.
            "or2sum_and2min": if more than one gene contribute as a complex,
                              the min of the gene values is taken and if the
                              genes act as isozymes, the sum is taken.
        Returns
        -------
        float
        """
        local_dict = {gene.id: Symbol(gene.id) for gene in reaction.genes}
        rule = reaction.gene_reaction_rule.replace("and", "*").replace("or",
                                                                       "+")
        expression = parse_expr(rule, local_dict)
        if by == "or2max_and2min":
            expression = expression.replace(Mul, Min).replace(Add, Max)
        elif by == "or2sum_and2min":
            expression = expression.replace(Mul, Min)
        return expression.subs(gene_values).evalf()

    def to_dict(self, condition):
        """
        Build a dict with identifiers and the expression for the condition.
        Parameters
        ----------
        condition: str or int
            The condition label or the column index.
        Returns
        -------
        dict
        """
        if isinstance(condition, int):
            index = condition
        else:
            index = self._condition_index[condition]
        return {identifier: expression for identifier, expression in
                zip(self.identifiers, self.expression[:, index])}

    def to_reaction_dict(self, condition, model, **kwargs):
        """
        Build a dict with reactions and the expression for the condition.
        If identifiers in the profile are genes, GPR associations are
        respected. If the gene expression data is missing in the profile,
        the reaction(s) related to that gene, is(are) supplied with the cutoff
        value.
        Parameters
        ----------
        condition: str or int
            The condition or the column index.
        model: cobra.Model
            The constraint-based model to obtain the GPR associations from.
        map_by: str, optional (default "or2max_and2min")
            The method to use for mapping gene values to reactions.
        cutoff: float, optional (default 0.0)
            The value to set for reaction(s) whose gene lacks a value in
            the profile.
        Returns
        -------
        dict
        """
        cutoff = 0.0
        map_by = "or2max_and2min"
        gene_exp = self.to_dict(condition)
        rxn_exp = {}
        for rxn in model.reactions:
            if rxn.genes is not None and any([gene.id in self.identifiers
                                              for gene in rxn.genes]):
                gene_values = {gene.id: gene_exp.get(gene.id, cutoff)
                               for gene in rxn.genes}
                rxn_exp[rxn.id] = self._map_gene_to_rxn(rxn, gene_values,
                                                        by=map_by)
        return rxn_exp

    def minmax(self, condition=None):
        """
        Return the min and max values for the specified condition.
        Parameters
        ----------
        condition: str or int or None, optional (default None)
            The condition to obtain the min and max values for.
        Returns
        -------
        tuple of (min, max)
        """
        if condition is None:
            values = self[:, :]
        elif isinstance(condition, int):
            values = self[:, condition]
        elif isinstance(condition, str):
            values = self[:, self._condition_index[condition]]
        return np.amin(values), np.amax(values)

    def _repr_html_(self):
        return self.data_frame._repr_html_()
    
from __future__ import absolute_import

from optlang.symbolics import Zero
from six import iteritems

# %%
exp = np.array([[.1,1,2],[.1,1,2],[.1,1,2],[.1,1,2],[.1,1,2],[.5,1,.5]])
pval = np.array([[0.05,0.05],[0.05,0.05],[0.05,0.05],[0.05,0.05],[0.05,0.05],[0.05,0.05],[.5,.5]])

new_obj = ExpressionProfile(identifiers = ['b1702','b4151','b4152','b4153','b4154','b2284'],
                               conditions = ['control','experimental_1','experimental_2'],
                               expression = exp)

new_obj
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>control</th>
#       <th>experimental_1</th>
#       <th>experimental_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b1702</th>
#       <td>0.1</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>b4151</th>
#       <td>0.1</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>b4152</th>
#       <td>0.1</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>b4153</th>
#       <td>0.1</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>b4154</th>
#       <td>0.1</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>b2284</th>
#       <td>0.5</td>
#       <td>1.0</td>
#       <td>0.5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
new_obj._condition_index
# Out:
# {'control': 0, 'experimental_1': 1, 'experimental_2': 2}

# %%
new_obj.identifier_index
# Out:
# {'b1702': 0, 'b2284': 5, 'b4151': 1, 'b4152': 2, 'b4153': 3, 'b4154': 4}

# %%
solution = model.slim_optimize()
prob = model.problem
rxn_profile = new_obj.to_reaction_dict(condition, model)

rxn_profile

# if model.objective_direction == 'max':
#     fix_obj_const = prob.Constraint(model.objective.expression,
#                                     lb=fraction_of_optimum * solution,
#                                     name="RMF")
# else:
#     fix_obj_const = prob.Constraint(model.objective.expression,
#                                     ub=fraction_of_optimum * solution,
#                                     name="RMF")
# model.add_cons_vars(fix_obj_const)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-85516e62ccdc> in <module>()
#       2 solution = model.slim_optimize()
#       3 prob = model.problem
# ----> 4 rxn_profile = new_obj.to_reaction_dict(condition, model)
#       5
#       6 rxn_profile
#
# <ipython-input-42-d496d2afab5a> in to_reaction_dict(self, condition, model, **kwargs)
#     302         cutoff = 0.0
#     303         map_by = "or2max_and2min"
# --> 304         gene_exp = self.to_dict(condition)
#     305         rxn_exp = {}
#     306         for rxn in model.reactions:
#
# <ipython-input-42-d496d2afab5a> in to_dict(self, condition)
#     274             index = condition
#     275         else:
# --> 276             index = self._condition_index[condition]
#     277         return {identifier: expression for identifier, expression in
#     278                 zip(self.identifiers, self.expression[:, index])}
#
# KeyError: 'San_Diego'

# %%
# inspired by NEW GIMME IN DRIVEN


prob = model.problem
rxn_profile = expression_profile.to_reaction_dict(condition, model)

solution = model.slim_optimize()
fix_obj_const = prob.Constraint(model.objective.expression,
                                lb=fraction_of_optimum * solution, name="RMF")

model.add_cons_vars(fix_obj_const)

coefficients = {rxn_id: cutoff - expression
                for rxn_id, expression in iteritems(rxn_profile)
                if cutoff > expression}
obj_vars = []
for rxn_id, coefficient in iteritems(coefficients):
    rxn = model.reactions.get_by_id(rxn_id)
    obj_vars.append((rxn.forward_variable, coefficient))
    obj_vars.append((rxn.reverse_variable, coefficient))

model.objective = prob.Objective(Zero, sloppy=True, direction="min")
model.objective.set_linear_coefficients({v: c for v, c in obj_vars})
sol = model.optimize()
# Out:
# {0.0 <= DM_4CRSOL <= 1000.0: 1.0,
#  0 <= DM_4CRSOL_reverse_50477 <= 0: 1.0,
#  0.0 <= DM_5DRIB <= 1000.0: 1.0,
#  0 <= DM_5DRIB_reverse_0b428 <= 0: 1.0,
#  0.0 <= DM_AACALD <= 1000.0: 1.0,
#  0 <= DM_AACALD_reverse_73112 <= 0: 1.0,
#  0.0 <= DM_AMOB <= 1000.0: 1.0,
#  0 <= DM_AMOB_reverse_9e172 <= 0: 1.0,
#  0.0 <= DM_MTHTHF <= 1000.0: 1.0,
#  0 <= DM_MTHTHF_reverse_78338 <= 0: 1.0,
#  0.0 <= DM_OXAM <= 1000.0: 1.0,
#  0 <= DM_OXAM_reverse_7c3e7 <= 0: 1.0,
#  0.0 <= Ec_biomass_iJO1366_WT_53p95M <= 1000.0: 1.0,
#  0 <= Ec_biomass_iJO1366_WT_53p95M_reverse_55db7 <= 0: 1.0,
#  0.0 <= Ec_biomass_iJO1366_core_53p95M <= 1000.0: 1.0,
#  0 <= Ec_biomass_iJO1366_core_53p95M_reverse_e94eb <= 0: 1.0,
#  0.0 <= EX_12ppd__R_e <= 1000.0: 1.0,
#  0 <= EX_12ppd__R_e_reverse_cb334 <= 0: 1.0,
#  0.0 <= EX_12ppd__S_e <= 1000.0: 1.0,
#  0 <= EX_12ppd__S_e_reverse_6f659 <= 0: 1.0,
#  0.0 <= EX_14glucan_e <= 1000.0: 1.0,
#  0 <= EX_14glucan_e_reverse_4b919 <= 0: 1.0,
#  0.0 <= EX_15dap_e <= 1000.0: 1.0,
#  0 <= EX_15dap_e_reverse_020d4 <= 0: 1.0,
#  0.0 <= EX_23camp_e <= 1000.0: 1.0,
#  0 <= EX_23camp_e_reverse_60590 <= 0: 1.0,
#  0.0 <= EX_23ccmp_e <= 1000.0: 1.0,
#  0 <= EX_23ccmp_e_reverse_3700b <= 0: 1.0,
#  0.0 <= EX_23cgmp_e <= 1000.0: 1.0,
#  0 <= EX_23cgmp_e_reverse_48b5f <= 0: 1.0,
#  0.0 <= EX_23cump_e <= 1000.0: 1.0,
#  0 <= EX_23cump_e_reverse_f767c <= 0: 1.0,
#  0.0 <= EX_23dappa_e <= 1000.0: 1.0,
#  0 <= EX_23dappa_e_reverse_dfe54 <= 0: 1.0,
#  0.0 <= EX_26dap__M_e <= 1000.0: 1.0,
#  0 <= EX_26dap__M_e_reverse_a7bf0 <= 0: 1.0,
#  0.0 <= EX_2ddglcn_e <= 1000.0: 1.0,
#  0 <= EX_2ddglcn_e_reverse_e7cfb <= 0: 1.0,
#  0.0 <= EX_34dhpac_e <= 1000.0: 1.0,
#  0 <= EX_34dhpac_e_reverse_01c3a <= 0: 1.0,
#  0.0 <= EX_3amp_e <= 1000.0: 1.0,
#  0 <= EX_3amp_e_reverse_5699b <= 0: 1.0,
#  0.0 <= EX_3cmp_e <= 1000.0: 1.0,
#  0 <= EX_3cmp_e_reverse_4c45a <= 0: 1.0,
#  0.0 <= EX_3gmp_e <= 1000.0: 1.0,
#  0 <= EX_3gmp_e_reverse_00dd4 <= 0: 1.0,
#  0.0 <= EX_3hcinnm_e <= 1000.0: 1.0,
#  0 <= EX_3hcinnm_e_reverse_2f2b9 <= 0: 1.0,
#  0.0 <= EX_3hpp_e <= 1000.0: 1.0,
#  0 <= EX_3hpp_e_reverse_0d47d <= 0: 1.0,
#  0.0 <= EX_3hpppn_e <= 1000.0: 1.0,
#  0 <= EX_3hpppn_e_reverse_d4e4c <= 0: 1.0,
#  0.0 <= EX_3ump_e <= 1000.0: 1.0,
#  0 <= EX_3ump_e_reverse_f1b20 <= 0: 1.0,
#  0.0 <= EX_4abut_e <= 1000.0: 1.0,
#  0 <= EX_4abut_e_reverse_82295 <= 0: 1.0,
#  0.0 <= EX_4hoxpacd_e <= 1000.0: 1.0,
#  0 <= EX_4hoxpacd_e_reverse_7a05b <= 0: 1.0,
#  0.0 <= EX_5dglcn_e <= 1000.0: 1.0,
#  0 <= EX_5dglcn_e_reverse_af9e8 <= 0: 1.0,
#  0.0 <= EX_5mtr_e <= 1000.0: 1.0,
#  0 <= EX_5mtr_e_reverse_0c671 <= 0: 1.0,
#  0.0 <= EX_LalaDglu_e <= 1000.0: 1.0,
#  0 <= EX_LalaDglu_e_reverse_e27e3 <= 0: 1.0,
#  0.0 <= EX_LalaDgluMdap_e <= 1000.0: 1.0,
#  0 <= EX_LalaDgluMdap_e_reverse_1661a <= 0: 1.0,
#  0.0 <= EX_LalaDgluMdapDala_e <= 1000.0: 1.0,
#  0 <= EX_LalaDgluMdapDala_e_reverse_8fceb <= 0: 1.0,
#  0.0 <= EX_LalaLglu_e <= 1000.0: 1.0,
#  0 <= EX_LalaLglu_e_reverse_d1493 <= 0: 1.0,
#  0.0 <= EX_ac_e <= 1000.0: 1.0,
#  0 <= EX_ac_e_reverse_0be96 <= 0: 1.0,
#  0.0 <= EX_acac_e <= 1000.0: 1.0,
#  0 <= EX_acac_e_reverse_c46d5 <= 0: 1.0,
#  0.0 <= EX_acald_e <= 1000.0: 1.0,
#  0 <= EX_acald_e_reverse_c096e <= 0: 1.0,
#  0.0 <= EX_acgal_e <= 1000.0: 1.0,
#  0 <= EX_acgal_e_reverse_abd5a <= 0: 1.0,
#  0.0 <= EX_acgal1p_e <= 1000.0: 1.0,
#  0 <= EX_acgal1p_e_reverse_bcbdf <= 0: 1.0,
#  0.0 <= EX_acgam_e <= 1000.0: 1.0,
#  0 <= EX_acgam_e_reverse_da887 <= 0: 1.0,
#  0.0 <= EX_acgam1p_e <= 1000.0: 1.0,
#  0 <= EX_acgam1p_e_reverse_c1eb9 <= 0: 1.0,
#  0.0 <= EX_acmana_e <= 1000.0: 1.0,
#  0 <= EX_acmana_e_reverse_ae727 <= 0: 1.0,
#  0.0 <= EX_acmum_e <= 1000.0: 1.0,
#  0 <= EX_acmum_e_reverse_d42f2 <= 0: 1.0,
#  0.0 <= EX_acnam_e <= 1000.0: 1.0,
#  0 <= EX_acnam_e_reverse_7701a <= 0: 1.0,
#  0.0 <= EX_acolipa_e <= 1000.0: 1.0,
#  0 <= EX_acolipa_e_reverse_df5a1 <= 0: 1.0,
#  0.0 <= EX_acser_e <= 1000.0: 1.0,
#  0 <= EX_acser_e_reverse_f0c22 <= 0: 1.0,
#  0.0 <= EX_ade_e <= 1000.0: 1.0,
#  0 <= EX_ade_e_reverse_ea308 <= 0: 1.0,
#  0.0 <= EX_adn_e <= 1000.0: 1.0,
#  0 <= EX_adn_e_reverse_dffe8 <= 0: 1.0,
#  0.0 <= EX_adocbl_e <= 1000.0: 1.0,
#  0 <= EX_adocbl_e_reverse_70f85 <= 0: 1.0,
#  0.0 <= EX_ag_e <= 1000.0: 1.0,
#  0 <= EX_ag_e_reverse_4d026 <= 0: 1.0,
#  0.0 <= EX_agm_e <= 1000.0: 1.0,
#  0 <= EX_agm_e_reverse_86b3b <= 0: 1.0,
#  0.0 <= EX_akg_e <= 1000.0: 1.0,
#  0 <= EX_akg_e_reverse_70d85 <= 0: 1.0,
#  0.0 <= EX_ala__B_e <= 1000.0: 1.0,
#  0 <= EX_ala__B_e_reverse_1729c <= 0: 1.0,
#  0.0 <= EX_ala__D_e <= 1000.0: 1.0,
#  0 <= EX_ala__D_e_reverse_15447 <= 0: 1.0,
#  0.0 <= EX_ala__L_e <= 1000.0: 1.0,
#  0 <= EX_ala__L_e_reverse_1eb4b <= 0: 1.0,
#  0.0 <= EX_alaala_e <= 1000.0: 1.0,
#  0 <= EX_alaala_e_reverse_fad8b <= 0: 1.0,
#  0.0 <= EX_all__D_e <= 1000.0: 1.0,
#  0 <= EX_all__D_e_reverse_3d5f1 <= 0: 1.0,
#  0.0 <= EX_alltn_e <= 1000.0: 1.0,
#  0 <= EX_alltn_e_reverse_6592a <= 0: 1.0,
#  0.0 <= EX_amp_e <= 1000.0: 1.0,
#  0 <= EX_amp_e_reverse_ed5eb <= 0: 1.0,
#  0.0 <= EX_anhgm_e <= 1000.0: 1.0,
#  0 <= EX_anhgm_e_reverse_87c70 <= 0: 1.0,
#  0.0 <= EX_arab__L_e <= 1000.0: 1.0,
#  0 <= EX_arab__L_e_reverse_d0f5e <= 0: 1.0,
#  0.0 <= EX_arbt_e <= 1000.0: 1.0,
#  0 <= EX_arbt_e_reverse_87033 <= 0: 1.0,
#  0.0 <= EX_arbtn_e <= 1000.0: 1.0,
#  0 <= EX_arbtn_e_reverse_f3f32 <= 0: 1.0,
#  0.0 <= EX_arbtn__fe3_e <= 1000.0: 1.0,
#  0 <= EX_arbtn__fe3_e_reverse_dfaee <= 0: 1.0,
#  0.0 <= EX_arg__L_e <= 1000.0: 1.0,
#  0 <= EX_arg__L_e_reverse_d8799 <= 0: 1.0,
#  0.0 <= EX_ascb__L_e <= 1000.0: 1.0,
#  0 <= EX_ascb__L_e_reverse_75b41 <= 0: 1.0,
#  0.0 <= EX_asn__L_e <= 1000.0: 1.0,
#  0 <= EX_asn__L_e_reverse_460df <= 0: 1.0,
#  0.0 <= EX_aso3_e <= 1000.0: 1.0,
#  0 <= EX_aso3_e_reverse_32104 <= 0: 1.0,
#  0.0 <= EX_asp__L_e <= 1000.0: 1.0,
#  0 <= EX_asp__L_e_reverse_742f6 <= 0: 1.0,
#  0.0 <= EX_btn_e <= 1000.0: 1.0,
#  0 <= EX_btn_e_reverse_f2678 <= 0: 1.0,
#  0.0 <= EX_but_e <= 1000.0: 1.0,
#  0 <= EX_but_e_reverse_35eb9 <= 0: 1.0,
#  0.0 <= EX_butso3_e <= 1000.0: 1.0,
#  0 <= EX_butso3_e_reverse_31183 <= 0: 1.0,
#  0 <= EX_ca2_e <= 1000.0: 1.0,
#  0 <= EX_ca2_e_reverse_aac13 <= 1000.0: 1.0,
#  0.0 <= EX_cbi_e <= 1000.0: 1.0,
#  0 <= EX_cbi_e_reverse_207cf <= 0: 1.0,
#  0 <= EX_cbl1_e <= 1000.0: 1.0,
#  0 <= EX_cbl1_e_reverse_1093e <= 0.01: 1.0,
#  0.0 <= EX_cd2_e <= 1000.0: 1.0,
#  0 <= EX_cd2_e_reverse_0e8ba <= 0: 1.0,
#  0.0 <= EX_cgly_e <= 1000.0: 1.0,
#  0 <= EX_cgly_e_reverse_12551 <= 0: 1.0,
#  0.0 <= EX_chol_e <= 1000.0: 1.0,
#  0 <= EX_chol_e_reverse_b6b50 <= 0: 1.0,
#  0.0 <= EX_chtbs_e <= 1000.0: 1.0,
#  0 <= EX_chtbs_e_reverse_bbe59 <= 0: 1.0,
#  0.0 <= EX_cit_e <= 1000.0: 1.0,
#  0 <= EX_cit_e_reverse_0835e <= 0: 1.0,
#  0 <= EX_cl_e <= 1000.0: 1.0,
#  0 <= EX_cl_e_reverse_2429b <= 1000.0: 1.0,
#  0.0 <= EX_cm_e <= 1000.0: 1.0,
#  0 <= EX_cm_e_reverse_d60e9 <= 0: 1.0,
#  0.0 <= EX_cmp_e <= 1000.0: 1.0,
#  0 <= EX_cmp_e_reverse_e7a73 <= 0: 1.0,
#  0 <= EX_co2_e <= 1000.0: 1.0,
#  0 <= EX_co2_e_reverse_d0466 <= 1000.0: 1.0,
#  0 <= EX_cobalt2_e <= 1000.0: 1.0,
#  0 <= EX_cobalt2_e_reverse_2bf0e <= 1000.0: 1.0,
#  0.0 <= EX_colipa_e <= 1000.0: 1.0,
#  0 <= EX_colipa_e_reverse_f9125 <= 0: 1.0,
#  0.0 <= EX_colipap_e <= 1000.0: 1.0,
#  0 <= EX_colipap_e_reverse_c02be <= 0: 1.0,
#  0.0 <= EX_cpgn_e <= 1000.0: 1.0,
#  0 <= EX_cpgn_e_reverse_a1559 <= 0: 1.0,
#  0.0 <= EX_cpgn__un_e <= 1000.0: 1.0,
#  0 <= EX_cpgn__un_e_reverse_a7fcb <= 0: 1.0,
#  0.0 <= EX_crn_e <= 1000.0: 1.0,
#  0 <= EX_crn_e_reverse_a19eb <= 0: 1.0,
#  0.0 <= EX_crn__D_e <= 1000.0: 1.0,
#  0 <= EX_crn__D_e_reverse_fbfeb <= 0: 1.0,
#  0.0 <= EX_csn_e <= 1000.0: 1.0,
#  0 <= EX_csn_e_reverse_80cf5 <= 0: 1.0,
#  0.0 <= EX_cu_e <= 1000.0: 1.0,
#  0 <= EX_cu_e_reverse_829ec <= 0: 1.0,
#  0 <= EX_cu2_e <= 1000.0: 1.0,
#  0 <= EX_cu2_e_reverse_02682 <= 1000.0: 1.0,
#  0.0 <= EX_cyan_e <= 1000.0: 1.0,
#  0 <= EX_cyan_e_reverse_7cb7e <= 0: 1.0,
#  0.0 <= EX_cynt_e <= 1000.0: 1.0,
#  0 <= EX_cynt_e_reverse_b53e8 <= 0: 1.0,
#  0.0 <= EX_cys__D_e <= 1000.0: 1.0,
#  0 <= EX_cys__D_e_reverse_fd0d3 <= 0: 1.0,
#  0.0 <= EX_cys__L_e <= 1000.0: 1.0,
#  0 <= EX_cys__L_e_reverse_41339 <= 0: 1.0,
#  0.0 <= EX_cytd_e <= 1000.0: 1.0,
#  0 <= EX_cytd_e_reverse_5950b <= 0: 1.0,
#  0.0 <= EX_dad__2_e <= 1000.0: 1.0,
#  0 <= EX_dad__2_e_reverse_30ab9 <= 0: 1.0,
#  0.0 <= EX_damp_e <= 1000.0: 1.0,
#  0 <= EX_damp_e_reverse_2e1bd <= 0: 1.0,
#  0.0 <= EX_dca_e <= 1000.0: 1.0,
#  0 <= EX_dca_e_reverse_4575c <= 0: 1.0,
#  0.0 <= EX_dcmp_e <= 1000.0: 1.0,
#  0 <= EX_dcmp_e_reverse_83ed5 <= 0: 1.0,
#  0.0 <= EX_dcyt_e <= 1000.0: 1.0,
#  0 <= EX_dcyt_e_reverse_13102 <= 0: 1.0,
#  0.0 <= EX_ddca_e <= 1000.0: 1.0,
#  0 <= EX_ddca_e_reverse_6b9d2 <= 0: 1.0,
#  0.0 <= EX_dgmp_e <= 1000.0: 1.0,
#  0 <= EX_dgmp_e_reverse_88fd2 <= 0: 1.0,
#  0.0 <= EX_dgsn_e <= 1000.0: 1.0,
#  0 <= EX_dgsn_e_reverse_1b175 <= 0: 1.0,
#  0.0 <= EX_dha_e <= 1000.0: 1.0,
#  0 <= EX_dha_e_reverse_63f6d <= 0: 1.0,
#  0.0 <= EX_dimp_e <= 1000.0: 1.0,
#  0 <= EX_dimp_e_reverse_7aa5e <= 0: 1.0,
#  0.0 <= EX_din_e <= 1000.0: 1.0,
#  0 <= EX_din_e_reverse_f97eb <= 0: 1.0,
#  0.0 <= EX_dms_e <= 1000.0: 1.0,
#  0 <= EX_dms_e_reverse_51567 <= 0: 1.0,
#  0.0 <= EX_dmso_e <= 1000.0: 1.0,
#  0 <= EX_dmso_e_reverse_f4576 <= 0: 1.0,
#  0.0 <= EX_dopa_e <= 1000.0: 1.0,
#  0 <= EX_dopa_e_reverse_71ff0 <= 0: 1.0,
#  0.0 <= EX_doxrbcn_e <= 1000.0: 1.0,
#  0 <= EX_doxrbcn_e_reverse_d7e41 <= 0: 1.0,
#  0.0 <= EX_dtmp_e <= 1000.0: 1.0,
#  0 <= EX_dtmp_e_reverse_7a713 <= 0: 1.0,
#  0.0 <= EX_dump_e <= 1000.0: 1.0,
#  0 <= EX_dump_e_reverse_2c836 <= 0: 1.0,
#  0.0 <= EX_duri_e <= 1000.0: 1.0,
#  0 <= EX_duri_e_reverse_d0523 <= 0: 1.0,
#  0.0 <= EX_eca4colipa_e <= 1000.0: 1.0,
#  0 <= EX_eca4colipa_e_reverse_579ab <= 0: 1.0,
#  0.0 <= EX_enlipa_e <= 1000.0: 1.0,
#  0 <= EX_enlipa_e_reverse_2dd41 <= 0: 1.0,
#  0.0 <= EX_enter_e <= 1000.0: 1.0,
#  0 <= EX_enter_e_reverse_7bf45 <= 0: 1.0,
#  0.0 <= EX_etha_e <= 1000.0: 1.0,
#  0 <= EX_etha_e_reverse_a3984 <= 0: 1.0,
#  0.0 <= EX_ethso3_e <= 1000.0: 1.0,
#  0 <= EX_ethso3_e_reverse_d2ed7 <= 0: 1.0,
#  0.0 <= EX_etoh_e <= 1000.0: 1.0,
#  0 <= EX_etoh_e_reverse_cc64f <= 0: 1.0,
#  0.0 <= EX_f6p_e <= 1000.0: 1.0,
#  0 <= EX_f6p_e_reverse_e362f <= 0: 1.0,
#  0.0 <= EX_fald_e <= 1000.0: 1.0,
#  0 <= EX_fald_e_reverse_57d26 <= 0: 1.0,
#  0 <= EX_fe2_e <= 1000.0: 1.0,
#  0 <= EX_fe2_e_reverse_25e68 <= 1000.0: 1.0,
#  0 <= EX_fe3_e <= 1000.0: 1.0,
#  0 <= EX_fe3_e_reverse_8b617 <= 1000.0: 1.0,
#  0.0 <= EX_fe3dcit_e <= 1000.0: 1.0,
#  0 <= EX_fe3dcit_e_reverse_a5939 <= 0: 1.0,
#  0.0 <= EX_fe3dhbzs_e <= 1000.0: 1.0,
#  0 <= EX_fe3dhbzs_e_reverse_93deb <= 0: 1.0,
#  0.0 <= EX_fe3hox_e <= 1000.0: 1.0,
#  0 <= EX_fe3hox_e_reverse_e323a <= 0: 1.0,
#  0.0 <= EX_fe3hox__un_e <= 1000.0: 1.0,
#  0 <= EX_fe3hox__un_e_reverse_342fd <= 0: 1.0,
#  0.0 <= EX_fecrm_e <= 1000.0: 1.0,
#  0 <= EX_fecrm_e_reverse_26983 <= 0: 1.0,
#  0.0 <= EX_fecrm__un_e <= 1000.0: 1.0,
#  0 <= EX_fecrm__un_e_reverse_a4187 <= 0: 1.0,
#  0.0 <= EX_feenter_e <= 1000.0: 1.0,
#  0 <= EX_feenter_e_reverse_73fde <= 0: 1.0,
#  0.0 <= EX_feoxam_e <= 1000.0: 1.0,
#  0 <= EX_feoxam_e_reverse_97348 <= 0: 1.0,
#  0.0 <= EX_feoxam__un_e <= 1000.0: 1.0,
#  0 <= EX_feoxam__un_e_reverse_411be <= 0: 1.0,
#  0.0 <= EX_for_e <= 1000.0: 1.0,
#  0 <= EX_for_e_reverse_23269 <= 0: 1.0,
#  0.0 <= EX_fru_e <= 1000.0: 1.0,
#  0 <= EX_fru_e_reverse_c3828 <= 0: 1.0,
#  0.0 <= EX_frulys_e <= 1000.0: 1.0,
#  0 <= EX_frulys_e_reverse_379f1 <= 0: 1.0,
#  0.0 <= EX_fruur_e <= 1000.0: 1.0,
#  0 <= EX_fruur_e_reverse_2763f <= 0: 1.0,
#  0.0 <= EX_fuc__L_e <= 1000.0: 1.0,
#  0 <= EX_fuc__L_e_reverse_e70a8 <= 0: 1.0,
#  0.0 <= EX_fum_e <= 1000.0: 1.0,
#  0 <= EX_fum_e_reverse_e3432 <= 0: 1.0,
#  0.0 <= EX_fusa_e <= 1000.0: 1.0,
#  0 <= EX_fusa_e_reverse_bf5b5 <= 0: 1.0,
#  0.0 <= EX_g1p_e <= 1000.0: 1.0,
#  0 <= EX_g1p_e_reverse_350fc <= 0: 1.0,
#  0.0 <= EX_g3pc_e <= 1000.0: 1.0,
#  0 <= EX_g3pc_e_reverse_ffe85 <= 0: 1.0,
#  0.0 <= EX_g3pe_e <= 1000.0: 1.0,
#  0 <= EX_g3pe_e_reverse_8f39b <= 0: 1.0,
#  0.0 <= EX_g3pg_e <= 1000.0: 1.0,
#  0 <= EX_g3pg_e_reverse_5e370 <= 0: 1.0,
#  0.0 <= EX_g3pi_e <= 1000.0: 1.0,
#  0 <= EX_g3pi_e_reverse_f11b2 <= 0: 1.0,
#  0.0 <= EX_g3ps_e <= 1000.0: 1.0,
#  0 <= EX_g3ps_e_reverse_70d70 <= 0: 1.0,
#  0.0 <= EX_g6p_e <= 1000.0: 1.0,
#  0 <= EX_g6p_e_reverse_c15e5 <= 0: 1.0,
#  0.0 <= EX_gal_e <= 1000.0: 1.0,
#  0 <= EX_gal_e_reverse_d166c <= 0: 1.0,
#  0.0 <= EX_gal__bD_e <= 1000.0: 1.0,
#  0 <= EX_gal__bD_e_reverse_6cde3 <= 0: 1.0,
#  0.0 <= EX_gal1p_e <= 1000.0: 1.0,
#  0 <= EX_gal1p_e_reverse_aab63 <= 0: 1.0,
#  0.0 <= EX_galct__D_e <= 1000.0: 1.0,
#  0 <= EX_galct__D_e_reverse_ff408 <= 0: 1.0,
#  0.0 <= EX_galctn__D_e <= 1000.0: 1.0,
#  0 <= EX_galctn__D_e_reverse_c58a3 <= 0: 1.0,
#  0.0 <= EX_galctn__L_e <= 1000.0: 1.0,
#  0 <= EX_galctn__L_e_reverse_998c0 <= 0: 1.0,
#  0.0 <= EX_galt_e <= 1000.0: 1.0,
#  0 <= EX_galt_e_reverse_4d1d0 <= 0: 1.0,
#  0.0 <= EX_galur_e <= 1000.0: 1.0,
#  0 <= EX_galur_e_reverse_f6a10 <= 0: 1.0,
#  0.0 <= EX_gam_e <= 1000.0: 1.0,
#  0 <= EX_gam_e_reverse_3d249 <= 0: 1.0,
#  0.0 <= EX_gam6p_e <= 1000.0: 1.0,
#  0 <= EX_gam6p_e_reverse_be0d8 <= 0: 1.0,
#  0.0 <= EX_gbbtn_e <= 1000.0: 1.0,
#  0 <= EX_gbbtn_e_reverse_767c1 <= 0: 1.0,
#  0.0 <= EX_gdp_e <= 1000.0: 1.0,
#  0 <= EX_gdp_e_reverse_950ab <= 0: 1.0,
#  0 <= EX_glc_e <= 1000.0: 1.0,
#  0 <= EX_glc_e_reverse_6226d <= 10.0: 1.0,
#  0.0 <= EX_glcn_e <= 1000.0: 1.0,
#  0 <= EX_glcn_e_reverse_9e36b <= 0: 1.0,
#  0.0 <= EX_glcr_e <= 1000.0: 1.0,
#  0 <= EX_glcr_e_reverse_ea55f <= 0: 1.0,
#  0.0 <= EX_glcur_e <= 1000.0: 1.0,
#  0 <= EX_glcur_e_reverse_0ab2d <= 0: 1.0,
#  0.0 <= EX_glcur1p_e <= 1000.0: 1.0,
#  0 <= EX_glcur1p_e_reverse_7a2e5 <= 0: 1.0,
#  0.0 <= EX_gln__L_e <= 1000.0: 1.0,
#  0 <= EX_gln__L_e_reverse_6a1a1 <= 0: 1.0,
#  0.0 <= EX_glu__L_e <= 1000.0: 1.0,
#  0 <= EX_glu__L_e_reverse_42f6c <= 0: 1.0,
#  0.0 <= EX_gly_e <= 1000.0: 1.0,
#  0 <= EX_gly_e_reverse_6956b <= 0: 1.0,
#  0.0 <= EX_glyald_e <= 1000.0: 1.0,
#  0 <= EX_glyald_e_reverse_f761f <= 0: 1.0,
#  0.0 <= EX_glyb_e <= 1000.0: 1.0,
#  0 <= EX_glyb_e_reverse_0bd65 <= 0: 1.0,
#  0.0 <= EX_glyc_e <= 1000.0: 1.0,
#  0 <= EX_glyc_e_reverse_c3ec2 <= 0: 1.0,
#  0.0 <= EX_glyc__R_e <= 1000.0: 1.0,
#  0 <= EX_glyc__R_e_reverse_91560 <= 0: 1.0,
#  0.0 <= EX_glyc2p_e <= 1000.0: 1.0,
#  0 <= EX_glyc2p_e_reverse_7a57e <= 0: 1.0,
#  0.0 <= EX_glyc3p_e <= 1000.0: 1.0,
#  0 <= EX_glyc3p_e_reverse_74e5f <= 0: 1.0,
#  0.0 <= EX_glyclt_e <= 1000.0: 1.0,
#  0 <= EX_glyclt_e_reverse_395e1 <= 0: 1.0,
#  0.0 <= EX_gmp_e <= 1000.0: 1.0,
#  0 <= EX_gmp_e_reverse_f6d0a <= 0: 1.0,
#  0.0 <= EX_gsn_e <= 1000.0: 1.0,
#  0 <= EX_gsn_e_reverse_cb307 <= 0: 1.0,
#  0.0 <= EX_gthox_e <= 1000.0: 1.0,
#  0 <= EX_gthox_e_reverse_ca051 <= 0: 1.0,
#  0.0 <= EX_gthrd_e <= 1000.0: 1.0,
#  0 <= EX_gthrd_e_reverse_be1ab <= 0: 1.0,
#  0.0 <= EX_gtp_e <= 1000.0: 1.0,
#  0 <= EX_gtp_e_reverse_9f3aa <= 0: 1.0,
#  0.0 <= EX_gua_e <= 1000.0: 1.0,
#  0 <= EX_gua_e_reverse_11317 <= 0: 1.0,
#  0 <= EX_h_e <= 1000.0: 1.0,
#  0 <= EX_h_e_reverse_3e0c5 <= 1000.0: 1.0,
#  0.0 <= EX_h2_e <= 1000.0: 1.0,
#  0 <= EX_h2_e_reverse_f55e9 <= 0: 1.0,
#  0 <= EX_h2o_e <= 1000.0: 1.0,
#  0 <= EX_h2o_e_reverse_3ced4 <= 1000.0: 1.0,
#  0.0 <= EX_h2o2_e <= 1000.0: 1.0,
#  0 <= EX_h2o2_e_reverse_d52c5 <= 0: 1.0,
#  0.0 <= EX_h2s_e <= 1000.0: 1.0,
#  0 <= EX_h2s_e_reverse_c847c <= 0: 1.0,
#  0.0 <= EX_hacolipa_e <= 1000.0: 1.0,
#  0 <= EX_hacolipa_e_reverse_4a785 <= 0: 1.0,
#  0.0 <= EX_halipa_e <= 1000.0: 1.0,
#  0 <= EX_halipa_e_reverse_f6505 <= 0: 1.0,
#  0.0 <= EX_hdca_e <= 1000.0: 1.0,
#  0 <= EX_hdca_e_reverse_9ab38 <= 0: 1.0,
#  0.0 <= EX_hdcea_e <= 1000.0: 1.0,
#  0 <= EX_hdcea_e_reverse_e9406 <= 0: 1.0,
#  0.0 <= EX_hg2_e <= 1000.0: 1.0,
#  0 <= EX_hg2_e_reverse_fc882 <= 0: 1.0,
#  0.0 <= EX_his__L_e <= 1000.0: 1.0,
#  0 <= EX_his__L_e_reverse_33439 <= 0: 1.0,
#  0.0 <= EX_hom__L_e <= 1000.0: 1.0,
#  0 <= EX_hom__L_e_reverse_3e4e5 <= 0: 1.0,
#  0.0 <= EX_hxa_e <= 1000.0: 1.0,
#  0 <= EX_hxa_e_reverse_e1287 <= 0: 1.0,
#  0.0 <= EX_hxan_e <= 1000.0: 1.0,
#  0 <= EX_hxan_e_reverse_90f99 <= 0: 1.0,
#  0.0 <= EX_idon__L_e <= 1000.0: 1.0,
#  0 <= EX_idon__L_e_reverse_54aa6 <= 0: 1.0,
#  0.0 <= EX_ile__L_e <= 1000.0: 1.0,
#  0 <= EX_ile__L_e_reverse_e862a <= 0: 1.0,
#  0.0 <= EX_imp_e <= 1000.0: 1.0,
#  0 <= EX_imp_e_reverse_a877a <= 0: 1.0,
#  0.0 <= EX_indole_e <= 1000.0: 1.0,
#  0 <= EX_indole_e_reverse_3cb9c <= 0: 1.0,
#  0.0 <= EX_inost_e <= 1000.0: 1.0,
#  0 <= EX_inost_e_reverse_4d21d <= 0: 1.0,
#  0.0 <= EX_ins_e <= 1000.0: 1.0,
#  0 <= EX_ins_e_reverse_989e1 <= 0: 1.0,
#  0.0 <= EX_isetac_e <= 1000.0: 1.0,
#  0 <= EX_isetac_e_reverse_62d58 <= 0: 1.0,
#  0 <= EX_k_e <= 1000.0: 1.0,
#  0 <= EX_k_e_reverse_42613 <= 1000.0: 1.0,
#  0.0 <= EX_kdo2lipid4_e <= 1000.0: 1.0,
#  0 <= EX_kdo2lipid4_e_reverse_fb486 <= 0: 1.0,
#  0.0 <= EX_lac__D_e <= 1000.0: 1.0,
#  0 <= EX_lac__D_e_reverse_f95b4 <= 0: 1.0,
#  0.0 <= EX_lac__L_e <= 1000.0: 1.0,
#  0 <= EX_lac__L_e_reverse_8586b <= 0: 1.0,
#  0.0 <= EX_lcts_e <= 1000.0: 1.0,
#  0 <= EX_lcts_e_reverse_13088 <= 0: 1.0,
#  0.0 <= EX_leu__L_e <= 1000.0: 1.0,
#  0 <= EX_leu__L_e_reverse_d40a5 <= 0: 1.0,
#  0.0 <= EX_lipa_e <= 1000.0: 1.0,
#  0 <= EX_lipa_e_reverse_1cc13 <= 0: 1.0,
#  0.0 <= EX_lipa_cold_e <= 1000.0: 1.0,
#  0 <= EX_lipa_cold_e_reverse_ce98e <= 0: 1.0,
#  0.0 <= EX_lipoate_e <= 1000.0: 1.0,
#  0 <= EX_lipoate_e_reverse_4faad <= 0: 1.0,
#  0.0 <= EX_lys__L_e <= 1000.0: 1.0,
#  0 <= EX_lys__L_e_reverse_4f08c <= 0: 1.0,
#  0.0 <= EX_lyx__L_e <= 1000.0: 1.0,
#  0 <= EX_lyx__L_e_reverse_693d8 <= 0: 1.0,
#  0.0 <= EX_mal__D_e <= 1000.0: 1.0,
#  0 <= EX_mal__D_e_reverse_ce476 <= 0: 1.0,
#  0.0 <= EX_mal__L_e <= 1000.0: 1.0,
#  0 <= EX_mal__L_e_reverse_af154 <= 0: 1.0,
#  0.0 <= EX_malt_e <= 1000.0: 1.0,
#  0 <= EX_malt_e_reverse_ab2d1 <= 0: 1.0,
#  0.0 <= EX_malthx_e <= 1000.0: 1.0,
#  0 <= EX_malthx_e_reverse_73b54 <= 0: 1.0,
#  0.0 <= EX_maltpt_e <= 1000.0: 1.0,
#  0 <= EX_maltpt_e_reverse_f82d5 <= 0: 1.0,
#  0.0 <= EX_malttr_e <= 1000.0: 1.0,
#  0 <= EX_malttr_e_reverse_241c6 <= 0: 1.0,
#  0.0 <= EX_maltttr_e <= 1000.0: 1.0,
#  0 <= EX_maltttr_e_reverse_90d23 <= 0: 1.0,
#  0.0 <= EX_man_e <= 1000.0: 1.0,
#  0 <= EX_man_e_reverse_48020 <= 0: 1.0,
#  0.0 <= EX_man6p_e <= 1000.0: 1.0,
#  0 <= EX_man6p_e_reverse_b160c <= 0: 1.0,
#  0.0 <= EX_manglyc_e <= 1000.0: 1.0,
#  0 <= EX_manglyc_e_reverse_51b57 <= 0: 1.0,
#  0.0 <= EX_melib_e <= 1000.0: 1.0,
#  0 <= EX_melib_e_reverse_68f2f <= 0: 1.0,
#  0.0 <= EX_meoh_e <= 1000.0: 1.0,
#  0 <= EX_meoh_e_reverse_45228 <= 0: 1.0,
#  0.0 <= EX_met__D_e <= 1000.0: 1.0,
#  0 <= EX_met__D_e_reverse_6e944 <= 0: 1.0,
#  0.0 <= EX_met__L_e <= 1000.0: 1.0,
#  0 <= EX_met__L_e_reverse_14908 <= 0: 1.0,
#  0.0 <= EX_metsox__R__L_e <= 1000.0: 1.0,
#  0 <= EX_metsox__R__L_e_reverse_424e5 <= 0: 1.0,
#  0.0 <= EX_metsox__S__L_e <= 1000.0: 1.0,
#  0 <= EX_metsox__S__L_e_reverse_6a3fe <= 0: 1.0,
#  0 <= EX_mg2_e <= 1000.0: 1.0,
#  0 <= EX_mg2_e_reverse_b1c98 <= 1000.0: 1.0,
#  0.0 <= EX_mincyc_e <= 1000.0: 1.0,
#  0 <= EX_mincyc_e_reverse_10267 <= 0: 1.0,
#  0.0 <= EX_minohp_e <= 1000.0: 1.0,
#  0 <= EX_minohp_e_reverse_3ce45 <= 0: 1.0,
#  0.0 <= EX_mmet_e <= 1000.0: 1.0,
#  0 <= EX_mmet_e_reverse_b6b96 <= 0: 1.0,
#  0 <= EX_mn2_e <= 1000.0: 1.0,
#  0 <= EX_mn2_e_reverse_48316 <= 1000.0: 1.0,
#  0.0 <= EX_mnl_e <= 1000.0: 1.0,
#  0 <= EX_mnl_e_reverse_c8f2a <= 0: 1.0,
#  0 <= EX_mobd_e <= 1000.0: 1.0,
#  0 <= EX_mobd_e_reverse_c6396 <= 1000.0: 1.0,
#  0.0 <= EX_mso3_e <= 1000.0: 1.0,
#  0 <= EX_mso3_e_reverse_b23ed <= 0: 1.0,
#  0.0 <= EX_n2o_e <= 1000.0: 1.0,
#  0 <= EX_n2o_e_reverse_33405 <= 0: 1.0,
#  0 <= EX_na1_e <= 1000.0: 1.0,
#  0 <= EX_na1_e_reverse_c64df <= 1000.0: 1.0,
#  0.0 <= EX_nac_e <= 1000.0: 1.0,
#  0 <= EX_nac_e_reverse_23356 <= 0: 1.0,
#  0 <= EX_nh4_e <= 1000.0: 1.0,
#  0 <= EX_nh4_e_reverse_f9cc6 <= 1000.0: 1.0,
#  0 <= EX_ni2_e <= 1000.0: 1.0,
#  0 <= EX_ni2_e_reverse_7ba33 <= 1000.0: 1.0,
#  0.0 <= EX_nmn_e <= 1000.0: 1.0,
#  0 <= EX_nmn_e_reverse_59f7d <= 0: 1.0,
#  0.0 <= EX_no_e <= 1000.0: 1.0,
#  0 <= EX_no_e_reverse_ffd01 <= 0: 1.0,
#  0.0 <= EX_no2_e <= 1000.0: 1.0,
#  0 <= EX_no2_e_reverse_1ddec <= 0: 1.0,
#  0.0 <= EX_no3_e <= 1000.0: 1.0,
#  0 <= EX_no3_e_reverse_98d30 <= 0: 1.0,
#  0.0 <= EX_novbcn_e <= 1000.0: 1.0,
#  0 <= EX_novbcn_e_reverse_14cc2 <= 0: 1.0,
#  0.0 <= EX_o16a4colipa_e <= 1000.0: 1.0,
#  0 <= EX_o16a4colipa_e_reverse_48f50 <= 0: 1.0,
#  0 <= EX_o2_e <= 1000.0: 1.0,
#  0 <= EX_o2_e_reverse_efa94 <= 1000.0: 1.0,
#  0.0 <= EX_o2s_e <= 1000.0: 1.0,
#  0 <= EX_o2s_e_reverse_82732 <= 0: 1.0,
#  0.0 <= EX_ocdca_e <= 1000.0: 1.0,
#  0 <= EX_ocdca_e_reverse_86d1d <= 0: 1.0,
#  0.0 <= EX_ocdcea_e <= 1000.0: 1.0,
#  0 <= EX_ocdcea_e_reverse_5ebe2 <= 0: 1.0,
#  0.0 <= EX_octa_e <= 1000.0: 1.0,
#  0 <= EX_octa_e_reverse_38d1e <= 0: 1.0,
#  0.0 <= EX_orn_e <= 1000.0: 1.0,
#  0 <= EX_orn_e_reverse_269bb <= 0: 1.0,
#  0.0 <= EX_orot_e <= 1000.0: 1.0,
#  0 <= EX_orot_e_reverse_032e7 <= 0: 1.0,
#  0.0 <= EX_pacald_e <= 1000.0: 1.0,
#  0 <= EX_pacald_e_reverse_54b80 <= 0: 1.0,
#  0.0 <= EX_peamn_e <= 1000.0: 1.0,
#  0 <= EX_peamn_e_reverse_34c33 <= 0: 1.0,
#  0.0 <= EX_phe__L_e <= 1000.0: 1.0,
#  0 <= EX_phe__L_e_reverse_10066 <= 0: 1.0,
#  0.0 <= EX_pheme_e <= 1000.0: 1.0,
#  0 <= EX_pheme_e_reverse_8e123 <= 0: 1.0,
#  0 <= EX_pi_e <= 1000.0: 1.0,
#  0 <= EX_pi_e_reverse_1fb09 <= 1000.0: 1.0,
#  0.0 <= EX_pnto__R_e <= 1000.0: 1.0,
#  0 <= EX_pnto__R_e_reverse_a498c <= 0: 1.0,
#  0.0 <= EX_ppa_e <= 1000.0: 1.0,
#  0 <= EX_ppa_e_reverse_1faa3 <= 0: 1.0,
#  0.0 <= EX_ppal_e <= 1000.0: 1.0,
#  0 <= EX_ppal_e_reverse_bb983 <= 0: 1.0,
#  0.0 <= EX_pppn_e <= 1000.0: 1.0,
#  0 <= EX_pppn_e_reverse_4f187 <= 0: 1.0,
#  0.0 <= EX_ppt_e <= 1000.0: 1.0,
#  0 <= EX_ppt_e_reverse_b97a7 <= 0: 1.0,
#  0.0 <= EX_pro__L_e <= 1000.0: 1.0,
#  0 <= EX_pro__L_e_reverse_5f8c5 <= 0: 1.0,
#  0.0 <= EX_progly_e <= 1000.0: 1.0,
#  0 <= EX_progly_e_reverse_cccb4 <= 0: 1.0,
#  0.0 <= EX_psclys_e <= 1000.0: 1.0,
#  0 <= EX_psclys_e_reverse_4686a <= 0: 1.0,
#  0.0 <= EX_pser__L_e <= 1000.0: 1.0,
#  0 <= EX_pser__L_e_reverse_164b6 <= 0: 1.0,
#  0.0 <= EX_ptrc_e <= 1000.0: 1.0,
#  0 <= EX_ptrc_e_reverse_6c850 <= 0: 1.0,
#  0.0 <= EX_pydam_e <= 1000.0: 1.0,
#  0 <= EX_pydam_e_reverse_b5003 <= 0: 1.0,
#  0.0 <= EX_pydx_e <= 1000.0: 1.0,
#  0 <= EX_pydx_e_reverse_9cc71 <= 0: 1.0,
#  0.0 <= EX_pydxn_e <= 1000.0: 1.0,
#  0 <= EX_pydxn_e_reverse_ce451 <= 0: 1.0,
#  0.0 <= EX_pyr_e <= 1000.0: 1.0,
#  0 <= EX_pyr_e_reverse_1f6de <= 0: 1.0,
#  0.0 <= EX_quin_e <= 1000.0: 1.0,
#  0 <= EX_quin_e_reverse_45058 <= 0: 1.0,
#  0.0 <= EX_r5p_e <= 1000.0: 1.0,
#  0 <= EX_r5p_e_reverse_383fe <= 0: 1.0,
#  0.0 <= EX_rfamp_e <= 1000.0: 1.0,
#  0 <= EX_rfamp_e_reverse_6d14f <= 0: 1.0,
#  0.0 <= EX_rib__D_e <= 1000.0: 1.0,
#  0 <= EX_rib__D_e_reverse_4a19a <= 0: 1.0,
#  0.0 <= EX_rmn_e <= 1000.0: 1.0,
#  0 <= EX_rmn_e_reverse_b3160 <= 0: 1.0,
#  0.0 <= EX_sbt__D_e <= 1000.0: 1.0,
#  0 <= EX_sbt__D_e_reverse_52f23 <= 0: 1.0,
#  0 <= EX_sel_e <= 1000.0: 1.0,
#  0 <= EX_sel_e_reverse_ffc35 <= 1000.0: 1.0,
#  0.0 <= EX_ser__D_e <= 1000.0: 1.0,
#  0 <= EX_ser__D_e_reverse_99725 <= 0: 1.0,
#  0.0 <= EX_ser__L_e <= 1000.0: 1.0,
#  0 <= EX_ser__L_e_reverse_b0b37 <= 0: 1.0,
#  0.0 <= EX_skm_e <= 1000.0: 1.0,
#  0 <= EX_skm_e_reverse_ed122 <= 0: 1.0,
#  0 <= EX_slnt_e <= 1000.0: 1.0,
#  0 <= EX_slnt_e_reverse_97bba <= 1000.0: 1.0,
#  0.0 <= EX_so2_e <= 1000.0: 1.0,
#  0 <= EX_so2_e_reverse_de12f <= 0: 1.0,
#  0.0 <= EX_so3_e <= 1000.0: 1.0,
#  0 <= EX_so3_e_reverse_116a1 <= 0: 1.0,
#  0 <= EX_so4_e <= 1000.0: 1.0,
#  0 <= EX_so4_e_reverse_5c8ed <= 1000.0: 1.0,
#  0.0 <= EX_spmd_e <= 1000.0: 1.0,
#  0 <= EX_spmd_e_reverse_761ad <= 0: 1.0,
#  0.0 <= EX_succ_e <= 1000.0: 1.0,
#  0 <= EX_succ_e_reverse_a9039 <= 0: 1.0,
#  0.0 <= EX_sucr_e <= 1000.0: 1.0,
#  0 <= EX_sucr_e_reverse_0215c <= 0: 1.0,
#  0.0 <= EX_sulfac_e <= 1000.0: 1.0,
#  0 <= EX_sulfac_e_reverse_2695d <= 0: 1.0,
#  0.0 <= EX_tartr__D_e <= 1000.0: 1.0,
#  0 <= EX_tartr__D_e_reverse_93e71 <= 0: 1.0,
#  0.0 <= EX_tartr__L_e <= 1000.0: 1.0,
#  0 <= EX_tartr__L_e_reverse_6023a <= 0: 1.0,
#  0.0 <= EX_taur_e <= 1000.0: 1.0,
#  0 <= EX_taur_e_reverse_69949 <= 0: 1.0,
#  0.0 <= EX_tcynt_e <= 1000.0: 1.0,
#  0 <= EX_tcynt_e_reverse_739e6 <= 0: 1.0,
#  0.0 <= EX_thm_e <= 1000.0: 1.0,
#  0 <= EX_thm_e_reverse_96547 <= 0: 1.0,
#  0.0 <= EX_thr__L_e <= 1000.0: 1.0,
#  0 <= EX_thr__L_e_reverse_ddaf9 <= 0: 1.0,
#  0.0 <= EX_thrp_e <= 1000.0: 1.0,
#  0 <= EX_thrp_e_reverse_51d63 <= 0: 1.0,
#  0.0 <= EX_thym_e <= 1000.0: 1.0,
#  0 <= EX_thym_e_reverse_84e99 <= 0: 1.0,
#  0.0 <= EX_thymd_e <= 1000.0: 1.0,
#  0 <= EX_thymd_e_reverse_94c6c <= 0: 1.0,
#  0.0 <= EX_tma_e <= 1000.0: 1.0,
#  0 <= EX_tma_e_reverse_1429d <= 0: 1.0,
#  0.0 <= EX_tmao_e <= 1000.0: 1.0,
#  0 <= EX_tmao_e_reverse_18ba4 <= 0: 1.0,
#  0.0 <= EX_tre_e <= 1000.0: 1.0,
#  0 <= EX_tre_e_reverse_fb5f1 <= 0: 1.0,
#  0.0 <= EX_trp__L_e <= 1000.0: 1.0,
#  0 <= EX_trp__L_e_reverse_d9983 <= 0: 1.0,
#  0.0 <= EX_tsul_e <= 1000.0: 1.0,
#  0 <= EX_tsul_e_reverse_22ca1 <= 0: 1.0,
#  0.0 <= EX_ttdca_e <= 1000.0: 1.0,
#  0 <= EX_ttdca_e_reverse_c67f4 <= 0: 1.0,
#  0.0 <= EX_ttdcea_e <= 1000.0: 1.0,
#  0 <= EX_ttdcea_e_reverse_e3700 <= 0: 1.0,
#  0.0 <= EX_ttrcyc_e <= 1000.0: 1.0,
#  0 <= EX_ttrcyc_e_reverse_0d8fb <= 0: 1.0,
#  0 <= EX_tungs_e <= 1000.0: 1.0,
#  0 <= EX_tungs_e_reverse_6ffff <= 1000.0: 1.0,
#  0.0 <= EX_tym_e <= 1000.0: 1.0,
#  0 <= EX_tym_e_reverse_e1acb <= 0: 1.0,
#  0.0 <= EX_tyr__L_e <= 1000.0: 1.0,
#  0 <= EX_tyr__L_e_reverse_516d2 <= 0: 1.0,
#  0.0 <= EX_tyrp_e <= 1000.0: 1.0,
#  0 <= EX_tyrp_e_reverse_36480 <= 0: 1.0,
#  0.0 <= EX_uacgam_e <= 1000.0: 1.0,
#  0 <= EX_uacgam_e_reverse_abfb0 <= 0: 1.0,
#  0.0 <= EX_udpacgal_e <= 1000.0: 1.0,
#  0 <= EX_udpacgal_e_reverse_a02b1 <= 0: 1.0,
#  0.0 <= EX_udpg_e <= 1000.0: 1.0,
#  0 <= EX_udpg_e_reverse_a3f02 <= 0: 1.0,
#  0.0 <= EX_udpgal_e <= 1000.0: 1.0,
#  0 <= EX_udpgal_e_reverse_9c019 <= 0: 1.0,
#  0.0 <= EX_udpglcur_e <= 1000.0: 1.0,
#  0 <= EX_udpglcur_e_reverse_baf0e <= 0: 1.0,
#  0.0 <= EX_ump_e <= 1000.0: 1.0,
#  0 <= EX_ump_e_reverse_58471 <= 0: 1.0,
#  0.0 <= EX_ura_e <= 1000.0: 1.0,
#  0 <= EX_ura_e_reverse_98cbe <= 0: 1.0,
#  0.0 <= EX_urea_e <= 1000.0: 1.0,
#  0 <= EX_urea_e_reverse_02f51 <= 0: 1.0,
#  0.0 <= EX_uri_e <= 1000.0: 1.0,
#  0 <= EX_uri_e_reverse_019f3 <= 0: 1.0,
#  0.0 <= EX_val__L_e <= 1000.0: 1.0,
#  0 <= EX_val__L_e_reverse_9e0f7 <= 0: 1.0,
#  0.0 <= EX_xan_e <= 1000.0: 1.0,
#  0 <= EX_xan_e_reverse_7bb40 <= 0: 1.0,
#  0.0 <= EX_xmp_e <= 1000.0: 1.0,
#  0 <= EX_xmp_e_reverse_5fd31 <= 0: 1.0,
#  0.0 <= EX_xtsn_e <= 1000.0: 1.0,
#  0 <= EX_xtsn_e_reverse_33417 <= 0: 1.0,
#  0.0 <= EX_xyl__D_e <= 1000.0: 1.0,
#  0 <= EX_xyl__D_e_reverse_e202a <= 0: 1.0,
#  0.0 <= EX_xylu__L_e <= 1000.0: 1.0,
#  0 <= EX_xylu__L_e_reverse_a93ff <= 0: 1.0,
#  0 <= EX_zn2_e <= 1000.0: 1.0,
#  0 <= EX_zn2_e_reverse_3c725 <= 1000.0: 1.0,
#  0.0 <= 12DGR120tipp <= 1000.0: 1.0,
#  0 <= 12DGR120tipp_reverse_757ef <= 0: 1.0,
#  0.0 <= 12DGR140tipp <= 1000.0: 1.0,
#  0 <= 12DGR140tipp_reverse_aea46 <= 0: 1.0,
#  0.0 <= 12DGR141tipp <= 1000.0: 1.0,
#  0 <= 12DGR141tipp_reverse_a0957 <= 0: 1.0,
#  0.0 <= 12DGR160tipp <= 1000.0: 1.0,
#  0 <= 12DGR160tipp_reverse_eac16 <= 0: 1.0,
#  0.0 <= 12DGR161tipp <= 1000.0: 1.0,
#  0 <= 12DGR161tipp_reverse_dcd80 <= 0: 1.0,
#  0.0 <= 12DGR180tipp <= 1000.0: 1.0,
#  0 <= 12DGR180tipp_reverse_7a012 <= 0: 1.0,
#  0.0 <= 12DGR181tipp <= 1000.0: 1.0,
#  0 <= 12DGR181tipp_reverse_34fd5 <= 0: 1.0,
#  0 <= 12PPDRtex <= 1000.0: 1.0,
#  0 <= 12PPDRtex_reverse_1d688 <= 1000.0: 1.0,
#  0 <= 12PPDRtpp <= 1000.0: 1.0,
#  0 <= 12PPDRtpp_reverse_c5519 <= 1000.0: 1.0,
#  0 <= 12PPDStex <= 1000.0: 1.0,
#  0 <= 12PPDStex_reverse_ec7d6 <= 1000.0: 1.0,
#  0 <= 12PPDStpp <= 1000.0: 1.0,
#  0 <= 12PPDStpp_reverse_81431 <= 1000.0: 1.0,
#  0.0 <= 14GLUCANabcpp <= 1000.0: 1.0,
#  0 <= 14GLUCANabcpp_reverse_c6351 <= 0: 1.0,
#  0.0 <= 14GLUCANtexi <= 1000.0: 1.0,
#  0 <= 14GLUCANtexi_reverse_2d4f8 <= 0: 1.0,
#  0 <= 23CAMPtex <= 1000.0: 1.0,
#  0 <= 23CAMPtex_reverse_1c6db <= 1000.0: 1.0,
#  0 <= 23CCMPtex <= 1000.0: 1.0,
#  0 <= 23CCMPtex_reverse_e7e14 <= 1000.0: 1.0,
#  0 <= 23CGMPtex <= 1000.0: 1.0,
#  0 <= 23CGMPtex_reverse_d266a <= 1000.0: 1.0,
#  0 <= 23CUMPtex <= 1000.0: 1.0,
#  0 <= 23CUMPtex_reverse_7c421 <= 1000.0: 1.0,
#  0.0 <= 23DAPPAt2pp <= 1000.0: 1.0,
#  0 <= 23DAPPAt2pp_reverse_59b55 <= 0: 1.0,
#  0 <= 23DAPPAtex <= 1000.0: 1.0,
#  0 <= 23DAPPAtex_reverse_0c987 <= 1000.0: 1.0,
#  0.0 <= 23PDE2pp <= 1000.0: 1.0,
#  0 <= 23PDE2pp_reverse_9b346 <= 0: 1.0,
#  0.0 <= 23PDE4pp <= 1000.0: 1.0,
#  0 <= 23PDE4pp_reverse_2a6cf <= 0: 1.0,
#  0.0 <= 23PDE7pp <= 1000.0: 1.0,
#  0 <= 23PDE7pp_reverse_3f150 <= 0: 1.0,
#  0.0 <= 23PDE9pp <= 1000.0: 1.0,
#  0 <= 23PDE9pp_reverse_84c1d <= 0: 1.0,
#  0 <= 26DAHtex <= 1000.0: 1.0,
#  0 <= 26DAHtex_reverse_3953d <= 1000.0: 1.0,
#  0.0 <= 2AGPA120tipp <= 1000.0: 1.0,
#  0 <= 2AGPA120tipp_reverse_16d01 <= 0: 1.0,
#  0.0 <= 2AGPA140tipp <= 1000.0: 1.0,
#  0 <= 2AGPA140tipp_reverse_392f6 <= 0: 1.0,
#  0.0 <= 2AGPA141tipp <= 1000.0: 1.0,
#  0 <= 2AGPA141tipp_reverse_f9714 <= 0: 1.0,
#  0.0 <= 2AGPA160tipp <= 1000.0: 1.0,
#  0 <= 2AGPA160tipp_reverse_dc28a <= 0: 1.0,
#  0.0 <= 2AGPA161tipp <= 1000.0: 1.0,
#  0 <= 2AGPA161tipp_reverse_fa4fb <= 0: 1.0,
#  0.0 <= 2AGPA180tipp <= 1000.0: 1.0,
#  0 <= 2AGPA180tipp_reverse_b48ac <= 0: 1.0,
#  0.0 <= 2AGPA181tipp <= 1000.0: 1.0,
#  0 <= 2AGPA181tipp_reverse_3605a <= 0: 1.0,
#  0.0 <= 2AGPE120tipp <= 1000.0: 1.0,
#  0 <= 2AGPE120tipp_reverse_015fb <= 0: 1.0,
#  0.0 <= 2AGPE140tipp <= 1000.0: 1.0,
#  0 <= 2AGPE140tipp_reverse_d6097 <= 0: 1.0,
#  0.0 <= 2AGPE141tipp <= 1000.0: 1.0,
#  0 <= 2AGPE141tipp_reverse_ae862 <= 0: 1.0,
#  0.0 <= 2AGPE160tipp <= 1000.0: 1.0,
#  0 <= 2AGPE160tipp_reverse_2f53f <= 0: 1.0,
#  0.0 <= 2AGPE161tipp <= 1000.0: 1.0,
#  0 <= 2AGPE161tipp_reverse_39d2b <= 0: 1.0,
#  0.0 <= 2AGPE180tipp <= 1000.0: 1.0,
#  0 <= 2AGPE180tipp_reverse_242d6 <= 0: 1.0,
#  0.0 <= 2AGPE181tipp <= 1000.0: 1.0,
#  0 <= 2AGPE181tipp_reverse_a5fc9 <= 0: 1.0,
#  0.0 <= 2AGPEAT120 <= 1000.0: 1.0,
#  0 <= 2AGPEAT120_reverse_cbf7b <= 0: 1.0,
#  0.0 <= 2AGPEAT140 <= 1000.0: 1.0,
#  0 <= 2AGPEAT140_reverse_195ed <= 0: 1.0,
#  0.0 <= 2AGPEAT141 <= 1000.0: 1.0,
#  0 <= 2AGPEAT141_reverse_0e3c9 <= 0: 1.0,
#  0.0 <= 2AGPEAT160 <= 1000.0: 1.0,
#  0 <= 2AGPEAT160_reverse_16239 <= 0: 1.0,
#  0.0 <= 2AGPEAT161 <= 1000.0: 1.0,
#  0 <= 2AGPEAT161_reverse_5858e <= 0: 1.0,
#  0.0 <= 2AGPEAT180 <= 1000.0: 1.0,
#  0 <= 2AGPEAT180_reverse_47e42 <= 0: 1.0,
#  0.0 <= 2AGPEAT181 <= 1000.0: 1.0,
#  0 <= 2AGPEAT181_reverse_450ec <= 0: 1.0,
#  0.0 <= 2AGPG120tipp <= 1000.0: 1.0,
#  0 <= 2AGPG120tipp_reverse_16620 <= 0: 1.0,
#  0.0 <= 2AGPG140tipp <= 1000.0: 1.0,
#  0 <= 2AGPG140tipp_reverse_2834e <= 0: 1.0,
#  0.0 <= 2AGPG141tipp <= 1000.0: 1.0,
#  0 <= 2AGPG141tipp_reverse_44e94 <= 0: 1.0,
#  0.0 <= 2AGPG160tipp <= 1000.0: 1.0,
#  0 <= 2AGPG160tipp_reverse_a1e99 <= 0: 1.0,
#  0.0 <= 2AGPG161tipp <= 1000.0: 1.0,
#  0 <= 2AGPG161tipp_reverse_4c821 <= 0: 1.0,
#  0.0 <= 2AGPG180tipp <= 1000.0: 1.0,
#  0 <= 2AGPG180tipp_reverse_148cb <= 0: 1.0,
#  0.0 <= 2AGPG181tipp <= 1000.0: 1.0,
#  0 <= 2AGPG181tipp_reverse_7596e <= 0: 1.0,
#  0.0 <= 2AGPGAT120 <= 1000.0: 1.0,
#  0 <= 2AGPGAT120_reverse_83703 <= 0: 1.0,
#  0.0 <= 2AGPGAT140 <= 1000.0: 1.0,
#  0 <= 2AGPGAT140_reverse_94092 <= 0: 1.0,
#  0.0 <= 2AGPGAT141 <= 1000.0: 1.0,
#  0 <= 2AGPGAT141_reverse_82d91 <= 0: 1.0,
#  0.0 <= 2AGPGAT160 <= 1000.0: 1.0,
#  0 <= 2AGPGAT160_reverse_2888d <= 0: 1.0,
#  0.0 <= 2AGPGAT161 <= 1000.0: 1.0,
#  0 <= 2AGPGAT161_reverse_529fb <= 0: 1.0,
#  0.0 <= 2AGPGAT180 <= 1000.0: 1.0,
#  0 <= 2AGPGAT180_reverse_9d3e5 <= 0: 1.0,
#  0.0 <= 2AGPGAT181 <= 1000.0: 1.0,
#  0 <= 2AGPGAT181_reverse_802a9 <= 0: 1.0,
#  0.0 <= 2DGULRGx <= 1000.0: 1.0,
#  0 <= 2DGULRGx_reverse_a7f46 <= 0: 1.0,
#  0.0 <= 2DGULRGy <= 1000.0: 1.0,
#  0 <= 2DGULRGy_reverse_cbff4 <= 0: 1.0,
#  0.0 <= 2DGULRx <= 1000.0: 1.0,
#  0 <= 2DGULRx_reverse_d1a03 <= 0: 1.0,
#  0.0 <= 2DGULRy <= 1000.0: 1.0,
#  0 <= 2DGULRy_reverse_5d02d <= 0: 1.0,
#  0.0 <= 2MAHMP <= 1000.0: 1.0,
#  0 <= 2MAHMP_reverse_e4fd2 <= 0: 1.0,
#  0 <= 34dhpactex <= 1000.0: 1.0,
#  0 <= 34dhpactex_reverse_51d40 <= 1000.0: 1.0,
#  0.0 <= 3AMACHYD <= 1000.0: 1.0,
#  0 <= 3AMACHYD_reverse_1adff <= 0: 1.0,
#  0 <= 3AMPtex <= 1000.0: 1.0,
#  0 <= 3AMPtex_reverse_62a3f <= 1000.0: 1.0,
#  0 <= 3CMPtex <= 1000.0: 1.0,
#  0 <= 3CMPtex_reverse_25d68 <= 1000.0: 1.0,
#  0 <= 3GMPtex <= 1000.0: 1.0,
#  0 <= 3GMPtex_reverse_c1214 <= 1000.0: 1.0,
#  0.0 <= 3HAD100 <= 1000.0: 1.0,
#  0 <= 3HAD100_reverse_ca00f <= 0: 1.0,
#  0.0 <= 3HAD120 <= 1000.0: 1.0,
#  0 <= 3HAD120_reverse_82f09 <= 0: 1.0,
#  0.0 <= 3HAD121 <= 1000.0: 1.0,
#  0 <= 3HAD121_reverse_7ae0d <= 0: 1.0,
#  0.0 <= 3HAD140 <= 1000.0: 1.0,
#  0 <= 3HAD140_reverse_13958 <= 0: 1.0,
#  0.0 <= 3HAD141 <= 1000.0: 1.0,
#  0 <= 3HAD141_reverse_5738f <= 0: 1.0,
#  0.0 <= 3HAD160 <= 1000.0: 1.0,
#  0 <= 3HAD160_reverse_c0da0 <= 0: 1.0,
#  0.0 <= 3HAD161 <= 1000.0: 1.0,
#  0 <= 3HAD161_reverse_384de <= 0: 1.0,
#  0.0 <= 3HAD180 <= 1000.0: 1.0,
#  0 <= 3HAD180_reverse_c801d <= 0: 1.0,
#  0.0 <= 3HAD181 <= 1000.0: 1.0,
#  0 <= 3HAD181_reverse_63f21 <= 0: 1.0,
#  0.0 <= 3HAD40 <= 1000.0: 1.0,
#  0 <= 3HAD40_reverse_bc17f <= 0: 1.0,
#  0.0 <= 3HAD60 <= 1000.0: 1.0,
#  0 <= 3HAD60_reverse_d7fb5 <= 0: 1.0,
#  0.0 <= 3HAD80 <= 1000.0: 1.0,
#  0 <= 3HAD80_reverse_29891 <= 0: 1.0,
#  0.0 <= 3HCINNMH <= 1000.0: 1.0,
#  0 <= 3HCINNMH_reverse_e3e52 <= 0: 1.0,
#  0.0 <= 3HPPPNH <= 1000.0: 1.0,
#  0 <= 3HPPPNH_reverse_b005a <= 0: 1.0,
#  0 <= 3HPPtex <= 1000.0: 1.0,
#  0 <= 3HPPtex_reverse_49e02 <= 1000.0: 1.0,
#  0.0 <= 3HPPtpp <= 1000.0: 1.0,
#  0 <= 3HPPtpp_reverse_f463c <= 0: 1.0,
#  0.0 <= 3KGK <= 1000.0: 1.0,
#  0 <= 3KGK_reverse_d559b <= 0: 1.0,
#  0.0 <= 3NTD2pp <= 1000.0: 1.0,
#  0 <= 3NTD2pp_reverse_6ebac <= 0: 1.0,
#  0.0 <= 3NTD4pp <= 1000.0: 1.0,
#  0 <= 3NTD4pp_reverse_51bb5 <= 0: 1.0,
#  0.0 <= 3NTD7pp <= 1000.0: 1.0,
#  0 <= 3NTD7pp_reverse_9ab3e <= 0: 1.0,
#  0.0 <= 3NTD9pp <= 1000.0: 1.0,
#  0 <= 3NTD9pp_reverse_6286c <= 0: 1.0,
#  0 <= 3OAR100 <= 1000.0: 1.0,
#  0 <= 3OAR100_reverse_d47e7 <= 1000.0: 1.0,
#  0 <= 3OAR120 <= 1000.0: 1.0,
#  0 <= 3OAR120_reverse_5a2b4 <= 1000.0: 1.0,
#  0.0 <= 3OAR121 <= 1000.0: 1.0,
#  0 <= 3OAR121_reverse_82b84 <= 0: 1.0,
#  0 <= 3OAR140 <= 1000.0: 1.0,
#  0 <= 3OAR140_reverse_4eb2a <= 1000.0: 1.0,
#  0.0 <= 3OAR141 <= 1000.0: 1.0,
#  0 <= 3OAR141_reverse_755ec <= 0: 1.0,
#  0 <= 3OAR160 <= 1000.0: 1.0,
#  0 <= 3OAR160_reverse_15066 <= 1000.0: 1.0,
#  0.0 <= 3OAR161 <= 1000.0: 1.0,
#  0 <= 3OAR161_reverse_fc9b4 <= 0: 1.0,
#  0 <= 3OAR180 <= 1000.0: 1.0,
#  0 <= 3OAR180_reverse_e234c <= 1000.0: 1.0,
#  0.0 <= 3OAR181 <= 1000.0: 1.0,
#  0 <= 3OAR181_reverse_f8559 <= 0: 1.0,
#  0 <= 3OAR40 <= 1000.0: 1.0,
#  0 <= 3OAR40_reverse_e075e <= 1000.0: 1.0,
#  0 <= 3OAR60 <= 1000.0: 1.0,
#  0 <= 3OAR60_reverse_40a5c <= 1000.0: 1.0,
#  0 <= 3OAR80 <= 1000.0: 1.0,
#  0 <= 3OAR80_reverse_fe338 <= 1000.0: 1.0,
#  0.0 <= 3OAS100 <= 1000.0: 1.0,
#  0 <= 3OAS100_reverse_bfd7d <= 0: 1.0,
#  0.0 <= 3OAS120 <= 1000.0: 1.0,
#  0 <= 3OAS120_reverse_06658 <= 0: 1.0,
#  0.0 <= 3OAS121 <= 1000.0: 1.0,
#  0 <= 3OAS121_reverse_e6125 <= 0: 1.0,
#  0.0 <= 3OAS140 <= 1000.0: 1.0,
#  0 <= 3OAS140_reverse_65ddc <= 0: 1.0,
#  0.0 <= 3OAS141 <= 1000.0: 1.0,
#  0 <= 3OAS141_reverse_7f7b2 <= 0: 1.0,
#  0.0 <= 3OAS160 <= 1000.0: 1.0,
#  0 <= 3OAS160_reverse_08317 <= 0: 1.0,
#  0.0 <= 3OAS161 <= 1000.0: 1.0,
#  0 <= 3OAS161_reverse_ca056 <= 0: 1.0,
#  0.0 <= 3OAS180 <= 1000.0: 1.0,
#  0 <= 3OAS180_reverse_3d9f8 <= 0: 1.0,
#  0.0 <= 3OAS181 <= 1000.0: 1.0,
#  0 <= 3OAS181_reverse_2c21d <= 0: 1.0,
#  0.0 <= 3OAS60 <= 1000.0: 1.0,
#  0 <= 3OAS60_reverse_bff6a <= 0: 1.0,
#  0.0 <= 3OAS80 <= 1000.0: 1.0,
#  0 <= 3OAS80_reverse_c6446 <= 0: 1.0,
#  0.0 <= 3OXCOAT <= 1000.0: 1.0,
#  0 <= 3OXCOAT_reverse_2bb18 <= 0: 1.0,
#  0.0 <= 3PEPTabcpp <= 1000.0: 1.0,
#  0 <= 3PEPTabcpp_reverse_d34e9 <= 0: 1.0,
#  0 <= 3PEPTtex <= 1000.0: 1.0,
#  0 <= 3PEPTtex_reverse_45a83 <= 1000.0: 1.0,
#  0 <= 3UMPtex <= 1000.0: 1.0,
#  0 <= 3UMPtex_reverse_c4def <= 1000.0: 1.0,
#  0.0 <= 42A12BOOXpp <= 1000.0: 1.0,
#  0 <= 42A12BOOXpp_reverse_a8a8a <= 0: 1.0,
#  0 <= 4HOXPACDtex <= 1000.0: 1.0,
#  0 <= 4HOXPACDtex_reverse_3798d <= 1000.0: 1.0,
#  0.0 <= 4HTHRS <= 1000.0: 1.0,
#  0 <= 4HTHRS_reverse_6e403 <= 0: 1.0,
#  0.0 <= 4PCP <= 1000.0: 1.0,
#  0 <= 4PCP_reverse_c7c51 <= 0: 1.0,
#  0.0 <= 4PCPpp <= 1000.0: 1.0,
#  0 <= 4PCPpp_reverse_87e32 <= 0: 1.0,
#  0.0 <= 4PEPTabcpp <= 1000.0: 1.0,
#  0 <= 4PEPTabcpp_reverse_c63ab <= 0: 1.0,
#  0 <= 4PEPTtex <= 1000.0: 1.0,
#  0 <= 4PEPTtex_reverse_025c0 <= 1000.0: 1.0,
#  0 <= 5DGLCNR <= 1000.0: 1.0,
#  0 <= 5DGLCNR_reverse_fbc12 <= 1000.0: 1.0,
#  0 <= 5DGLCNt2rpp <= 1000.0: 1.0,
#  0 <= 5DGLCNt2rpp_reverse_32e75 <= 1000.0: 1.0,
#  0 <= 5DGLCNtex <= 1000.0: 1.0,
#  0 <= 5DGLCNtex_reverse_d721b <= 1000.0: 1.0,
#  0.0 <= 5DOAN <= 1000.0: 1.0,
#  0 <= 5DOAN_reverse_c8e7d <= 0: 1.0,
#  0 <= 5MTRtex <= 1000.0: 1.0,
#  0 <= 5MTRtex_reverse_79096 <= 1000.0: 1.0,
#  0.0 <= 5MTRtpp <= 1000.0: 1.0,
#  0 <= 5MTRtpp_reverse_d6113 <= 0: 1.0,
#  0 <= A5PISO <= 1000.0: 1.0,
#  0 <= A5PISO_reverse_3adc0 <= 1000.0: 1.0,
#  0.0 <= AACPS1 <= 1000.0: 1.0,
#  0 <= AACPS1_reverse_74228 <= 0: 1.0,
#  0.0 <= AACPS2 <= 1000.0: 1.0,
#  0 <= AACPS2_reverse_4df8a <= 0: 1.0,
#  0.0 <= AACPS3 <= 1000.0: 1.0,
#  0 <= AACPS3_reverse_de1e6 <= 0: 1.0,
#  0.0 <= AACPS4 <= 1000.0: 1.0,
#  0 <= AACPS4_reverse_2b927 <= 0: 1.0,
#  0.0 <= AACPS5 <= 1000.0: 1.0,
#  0 <= AACPS5_reverse_2077f <= 0: 1.0,
#  0.0 <= AACPS6 <= 1000.0: 1.0,
#  0 <= AACPS6_reverse_8fda3 <= 0: 1.0,
#  0.0 <= AACPS7 <= 1000.0: 1.0,
#  0 <= AACPS7_reverse_c7dd9 <= 0: 1.0,
#  0.0 <= AACPS8 <= 1000.0: 1.0,
#  0 <= AACPS8_reverse_375dc <= 0: 1.0,
#  0.0 <= AACPS9 <= 1000.0: 1.0,
#  0 <= AACPS9_reverse_c03ad <= 0: 1.0,
#  0.0 <= AACTOOR <= 1000.0: 1.0,
#  0 <= AACTOOR_reverse_e897c <= 0: 1.0,
#  0.0 <= AADDGT <= 1000.0: 1.0,
#  0 <= AADDGT_reverse_01165 <= 0: 1.0,
#  0.0 <= AAMYL <= 1000.0: 1.0,
#  0 <= AAMYL_reverse_58557 <= 0: 1.0,
#  0.0 <= AAMYLpp <= 1000.0: 1.0,
#  0 <= AAMYLpp_reverse_813aa <= 0: 1.0,
#  0.0 <= AB6PGH <= 1000.0: 1.0,
#  0 <= AB6PGH_reverse_9c1a3 <= 0: 1.0,
#  0.0 <= ABTA <= 1000.0: 1.0,
#  0 <= ABTA_reverse_48ba6 <= 0: 1.0,
#  0.0 <= ABUTD <= 1000.0: 1.0,
#  0 <= ABUTD_reverse_a69d2 <= 0: 1.0,
#  0.0 <= ABUTt2pp <= 1000.0: 1.0,
#  0 <= ABUTt2pp_reverse_b7c2d <= 0: 1.0,
#  0 <= ABUTtex <= 1000.0: 1.0,
#  0 <= ABUTtex_reverse_f1b1f <= 1000.0: 1.0,
#  0.0 <= ACACCT <= 1000.0: 1.0,
#  0 <= ACACCT_reverse_94e1e <= 0: 1.0,
#  0 <= ACACT1r <= 1000.0: 1.0,
#  0 <= ACACT1r_reverse_7e2ab <= 1000.0: 1.0,
#  0 <= ACACT2r <= 1000.0: 1.0,
#  0 <= ACACT2r_reverse_b794d <= 1000.0: 1.0,
#  0 <= ACACT3r <= 1000.0: 1.0,
#  0 <= ACACT3r_reverse_b8079 <= 1000.0: 1.0,
#  0 <= ACACT4r <= 1000.0: 1.0,
#  0 <= ACACT4r_reverse_36b94 <= 1000.0: 1.0,
#  0 <= ACACT5r <= 1000.0: 1.0,
#  0 <= ACACT5r_reverse_49fec <= 1000.0: 1.0,
#  0 <= ACACT6r <= 1000.0: 1.0,
#  0 <= ACACT6r_reverse_a3ce9 <= 1000.0: 1.0,
#  0 <= ACACT7r <= 1000.0: 1.0,
#  0 <= ACACT7r_reverse_b44b4 <= 1000.0: 1.0,
#  0 <= ACACT8r <= 1000.0: 1.0,
#  0 <= ACACT8r_reverse_54705 <= 1000.0: 1.0,
#  0 <= ACACt2pp <= 1000.0: 1.0,
#  0 <= ACACt2pp_reverse_06302 <= 1000.0: 1.0,
#  0 <= ACACtex <= 1000.0: 1.0,
#  0 <= ACACtex_reverse_cc949 <= 1000.0: 1.0,
#  0 <= ACALD <= 1000.0: 1.0,
#  0 <= ACALD_reverse_fda2b <= 1000.0: 1.0,
#  0 <= ACALDtex <= 1000.0: 1.0,
#  0 <= ACALDtex_reverse_75f7f <= 1000.0: 1.0,
#  0 <= ACALDtpp <= 1000.0: 1.0,
#  0 <= ACALDtpp_reverse_52ae6 <= 1000.0: 1.0,
#  0.0 <= ACANTHAT <= 1000.0: 1.0,
#  0 <= ACANTHAT_reverse_9fe7b <= 0: 1.0,
#  0.0 <= ACBIPGT <= 1000.0: 1.0,
#  0 <= ACBIPGT_reverse_bcc45 <= 0: 1.0,
#  0.0 <= ACCOAC <= 1000.0: 1.0,
#  0 <= ACCOAC_reverse_9d1cd <= 0: 1.0,
#  0.0 <= ACCOAL <= 1000.0: 1.0,
#  0 <= ACCOAL_reverse_ea444 <= 0: 1.0,
#  0.0 <= ACGAL1PPpp <= 1000.0: 1.0,
#  0 <= ACGAL1PPpp_reverse_88026 <= 0: 1.0,
#  ...}

# %%
from optlang import Variable, Constraint, Objective, Model

variables = {}
constraints = {}
for condition in conditions: # 0 = Control, 1 = Experimental
    variables[condition] = {}
    constraints[condition] = {}
    for gene in model.genes:
        var = Variable(name="{}_state".format(gene.id), lb=0, type="integer")
        variables[condition][gene.id] = var

        if gene.id in increased:
            const = Constraint((-log(pval[gene.id]))*(variables[conditions[0]][gene.id] - variables[conditions[1]][gene.id])
                               lb = 0,
                               name = '{}_'.format(gene.id))
        if gene.id in decreased:
            const = Constraint((-log(pval[gene.id]))*(variables[conditions[1]][gene.id] - variables[conditions[0]][gene.id])
                               lb = 0,
                               name = '{}_'.format(gene.id))
        constraints[condition][gene.id] = const
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bc99a670de3d> in <module>()
#      41 # Define the objective
#      42 obj = Objective(
# ---> 43     sum((1-log(pvalues[condition][gene])) * variables[condition][gene] for condition in conditions for gene in genes),
#      44     direction="min"
#      45 )
#
# <ipython-input-6-bc99a670de3d> in <genexpr>(.0)
#      41 # Define the objective
#      42 obj = Objective(
# ---> 43     sum((1-log(pvalues[condition][gene])) * variables[condition][gene] for condition in conditions for gene in genes),
#      44     direction="min"
#      45 )
#
# NameError: name 'log' is not defined

# %%
# We can print the objective and constraints
print(obj)
print("")
for const in constraints:
    print(const)

print("")

# Put everything together in a Model
model = Model()
model.add(constraints)  # Variables are added implicitly
model.objective = obj

# Optimize and print the solution
status = model.optimize()
print("Status:", status)
print("Objective value:", model.objective.value)
print("")
for var in model.variables:
    print(var.name, ":", var.primal)

# %%
from optlang import Model, Variable, Constraint, Objective

# All the (symbolic) variables are declared, with a name and optionally a lower and/or upper bound.
for gene in model.genes:
    x = Variable('gene_state'+gene.id, lb = 0)
    c1 = Constraint(abs(x-exp_dif), ub = 1)
    c2 = Constraint((1-log(pval))*(abs(x-exp_dif)))
    
    
x1 = Variable('gene_state_1', lb=0)
x2 = Variable('gene_state_2', lb=0)
x3 = Variable('gene_state_3', lb=0)



# A constraint is constructed from an expression of variables and a lower and/or upper bound (lb and ub).
c1 = Constraint(x1 + x2 + x3, ub=100)
c2 = Constraint(10 * x1 + 4 * x2 + 5 * x3, ub=600)
c3 = Constraint(2 * x1 + 2 * x2 + 6 * x3, ub=300)

# An objective can be formulated
obj = Objective(10 * x1 + 6 * x2 + 4 * x3, direction='max')

# Variables, constraints and objective are combined in a Model object, which can subsequently be optimized.
model = Model(name='Simple model')
model.objective = obj
model.add([c1, c2, c3])
status = model.optimize()

# %%
# add constraint framework
add_pfba(model)

# examine constraints
coef = model.objective.get_linear_coefficients(model.variables)
coef
# Out:
# {0.0 <= DM_4CRSOL <= 1000.0: 1.0,
#  0 <= DM_4CRSOL_reverse_50477 <= 0: 1.0,
#  0.0 <= DM_5DRIB <= 1000.0: 1.0,
#  0 <= DM_5DRIB_reverse_0b428 <= 0: 1.0,
#  0.0 <= DM_AACALD <= 1000.0: 1.0,
#  0 <= DM_AACALD_reverse_73112 <= 0: 1.0,
#  0.0 <= DM_AMOB <= 1000.0: 1.0,
#  0 <= DM_AMOB_reverse_9e172 <= 0: 1.0,
#  0.0 <= DM_MTHTHF <= 1000.0: 1.0,
#  0 <= DM_MTHTHF_reverse_78338 <= 0: 1.0,
#  0.0 <= DM_OXAM <= 1000.0: 1.0,
#  0 <= DM_OXAM_reverse_7c3e7 <= 0: 1.0,
#  0.0 <= Ec_biomass_iJO1366_WT_53p95M <= 1000.0: 1.0,
#  0 <= Ec_biomass_iJO1366_WT_53p95M_reverse_55db7 <= 0: 1.0,
#  0.0 <= Ec_biomass_iJO1366_core_53p95M <= 1000.0: 1.0,
#  0 <= Ec_biomass_iJO1366_core_53p95M_reverse_e94eb <= 0: 1.0,
#  0.0 <= EX_12ppd__R_e <= 1000.0: 1.0,
#  0 <= EX_12ppd__R_e_reverse_cb334 <= 0: 1.0,
#  0.0 <= EX_12ppd__S_e <= 1000.0: 1.0,
#  0 <= EX_12ppd__S_e_reverse_6f659 <= 0: 1.0,
#  0.0 <= EX_14glucan_e <= 1000.0: 1.0,
#  0 <= EX_14glucan_e_reverse_4b919 <= 0: 1.0,
#  0.0 <= EX_15dap_e <= 1000.0: 1.0,
#  0 <= EX_15dap_e_reverse_020d4 <= 0: 1.0,
#  0.0 <= EX_23camp_e <= 1000.0: 1.0,
#  0 <= EX_23camp_e_reverse_60590 <= 0: 1.0,
#  0.0 <= EX_23ccmp_e <= 1000.0: 1.0,
#  0 <= EX_23ccmp_e_reverse_3700b <= 0: 1.0,
#  0.0 <= EX_23cgmp_e <= 1000.0: 1.0,
#  0 <= EX_23cgmp_e_reverse_48b5f <= 0: 1.0,
#  0.0 <= EX_23cump_e <= 1000.0: 1.0,
#  0 <= EX_23cump_e_reverse_f767c <= 0: 1.0,
#  0.0 <= EX_23dappa_e <= 1000.0: 1.0,
#  0 <= EX_23dappa_e_reverse_dfe54 <= 0: 1.0,
#  0.0 <= EX_26dap__M_e <= 1000.0: 1.0,
#  0 <= EX_26dap__M_e_reverse_a7bf0 <= 0: 1.0,
#  0.0 <= EX_2ddglcn_e <= 1000.0: 1.0,
#  0 <= EX_2ddglcn_e_reverse_e7cfb <= 0: 1.0,
#  0.0 <= EX_34dhpac_e <= 1000.0: 1.0,
#  0 <= EX_34dhpac_e_reverse_01c3a <= 0: 1.0,
#  0.0 <= EX_3amp_e <= 1000.0: 1.0,
#  0 <= EX_3amp_e_reverse_5699b <= 0: 1.0,
#  0.0 <= EX_3cmp_e <= 1000.0: 1.0,
#  0 <= EX_3cmp_e_reverse_4c45a <= 0: 1.0,
#  0.0 <= EX_3gmp_e <= 1000.0: 1.0,
#  0 <= EX_3gmp_e_reverse_00dd4 <= 0: 1.0,
#  0.0 <= EX_3hcinnm_e <= 1000.0: 1.0,
#  0 <= EX_3hcinnm_e_reverse_2f2b9 <= 0: 1.0,
#  0.0 <= EX_3hpp_e <= 1000.0: 1.0,
#  0 <= EX_3hpp_e_reverse_0d47d <= 0: 1.0,
#  0.0 <= EX_3hpppn_e <= 1000.0: 1.0,
#  0 <= EX_3hpppn_e_reverse_d4e4c <= 0: 1.0,
#  0.0 <= EX_3ump_e <= 1000.0: 1.0,
#  0 <= EX_3ump_e_reverse_f1b20 <= 0: 1.0,
#  0.0 <= EX_4abut_e <= 1000.0: 1.0,
#  0 <= EX_4abut_e_reverse_82295 <= 0: 1.0,
#  0.0 <= EX_4hoxpacd_e <= 1000.0: 1.0,
#  0 <= EX_4hoxpacd_e_reverse_7a05b <= 0: 1.0,
#  0.0 <= EX_5dglcn_e <= 1000.0: 1.0,
#  0 <= EX_5dglcn_e_reverse_af9e8 <= 0: 1.0,
#  0.0 <= EX_5mtr_e <= 1000.0: 1.0,
#  0 <= EX_5mtr_e_reverse_0c671 <= 0: 1.0,
#  0.0 <= EX_LalaDglu_e <= 1000.0: 1.0,
#  0 <= EX_LalaDglu_e_reverse_e27e3 <= 0: 1.0,
#  0.0 <= EX_LalaDgluMdap_e <= 1000.0: 1.0,
#  0 <= EX_LalaDgluMdap_e_reverse_1661a <= 0: 1.0,
#  0.0 <= EX_LalaDgluMdapDala_e <= 1000.0: 1.0,
#  0 <= EX_LalaDgluMdapDala_e_reverse_8fceb <= 0: 1.0,
#  0.0 <= EX_LalaLglu_e <= 1000.0: 1.0,
#  0 <= EX_LalaLglu_e_reverse_d1493 <= 0: 1.0,
#  0.0 <= EX_ac_e <= 1000.0: 1.0,
#  0 <= EX_ac_e_reverse_0be96 <= 0: 1.0,
#  0.0 <= EX_acac_e <= 1000.0: 1.0,
#  0 <= EX_acac_e_reverse_c46d5 <= 0: 1.0,
#  0.0 <= EX_acald_e <= 1000.0: 1.0,
#  0 <= EX_acald_e_reverse_c096e <= 0: 1.0,
#  0.0 <= EX_acgal_e <= 1000.0: 1.0,
#  0 <= EX_acgal_e_reverse_abd5a <= 0: 1.0,
#  0.0 <= EX_acgal1p_e <= 1000.0: 1.0,
#  0 <= EX_acgal1p_e_reverse_bcbdf <= 0: 1.0,
#  0.0 <= EX_acgam_e <= 1000.0: 1.0,
#  0 <= EX_acgam_e_reverse_da887 <= 0: 1.0,
#  0.0 <= EX_acgam1p_e <= 1000.0: 1.0,
#  0 <= EX_acgam1p_e_reverse_c1eb9 <= 0: 1.0,
#  0.0 <= EX_acmana_e <= 1000.0: 1.0,
#  0 <= EX_acmana_e_reverse_ae727 <= 0: 1.0,
#  0.0 <= EX_acmum_e <= 1000.0: 1.0,
#  0 <= EX_acmum_e_reverse_d42f2 <= 0: 1.0,
#  0.0 <= EX_acnam_e <= 1000.0: 1.0,
#  0 <= EX_acnam_e_reverse_7701a <= 0: 1.0,
#  0.0 <= EX_acolipa_e <= 1000.0: 1.0,
#  0 <= EX_acolipa_e_reverse_df5a1 <= 0: 1.0,
#  0.0 <= EX_acser_e <= 1000.0: 1.0,
#  0 <= EX_acser_e_reverse_f0c22 <= 0: 1.0,
#  0.0 <= EX_ade_e <= 1000.0: 1.0,
#  0 <= EX_ade_e_reverse_ea308 <= 0: 1.0,
#  0.0 <= EX_adn_e <= 1000.0: 1.0,
#  0 <= EX_adn_e_reverse_dffe8 <= 0: 1.0,
#  0.0 <= EX_adocbl_e <= 1000.0: 1.0,
#  0 <= EX_adocbl_e_reverse_70f85 <= 0: 1.0,
#  0.0 <= EX_ag_e <= 1000.0: 1.0,
#  0 <= EX_ag_e_reverse_4d026 <= 0: 1.0,
#  0.0 <= EX_agm_e <= 1000.0: 1.0,
#  0 <= EX_agm_e_reverse_86b3b <= 0: 1.0,
#  0.0 <= EX_akg_e <= 1000.0: 1.0,
#  0 <= EX_akg_e_reverse_70d85 <= 0: 1.0,
#  0.0 <= EX_ala__B_e <= 1000.0: 1.0,
#  0 <= EX_ala__B_e_reverse_1729c <= 0: 1.0,
#  0.0 <= EX_ala__D_e <= 1000.0: 1.0,
#  0 <= EX_ala__D_e_reverse_15447 <= 0: 1.0,
#  0.0 <= EX_ala__L_e <= 1000.0: 1.0,
#  0 <= EX_ala__L_e_reverse_1eb4b <= 0: 1.0,
#  0.0 <= EX_alaala_e <= 1000.0: 1.0,
#  0 <= EX_alaala_e_reverse_fad8b <= 0: 1.0,
#  0.0 <= EX_all__D_e <= 1000.0: 1.0,
#  0 <= EX_all__D_e_reverse_3d5f1 <= 0: 1.0,
#  0.0 <= EX_alltn_e <= 1000.0: 1.0,
#  0 <= EX_alltn_e_reverse_6592a <= 0: 1.0,
#  0.0 <= EX_amp_e <= 1000.0: 1.0,
#  0 <= EX_amp_e_reverse_ed5eb <= 0: 1.0,
#  0.0 <= EX_anhgm_e <= 1000.0: 1.0,
#  0 <= EX_anhgm_e_reverse_87c70 <= 0: 1.0,
#  0.0 <= EX_arab__L_e <= 1000.0: 1.0,
#  0 <= EX_arab__L_e_reverse_d0f5e <= 0: 1.0,
#  0.0 <= EX_arbt_e <= 1000.0: 1.0,
#  0 <= EX_arbt_e_reverse_87033 <= 0: 1.0,
#  0.0 <= EX_arbtn_e <= 1000.0: 1.0,
#  0 <= EX_arbtn_e_reverse_f3f32 <= 0: 1.0,
#  0.0 <= EX_arbtn__fe3_e <= 1000.0: 1.0,
#  0 <= EX_arbtn__fe3_e_reverse_dfaee <= 0: 1.0,
#  0.0 <= EX_arg__L_e <= 1000.0: 1.0,
#  0 <= EX_arg__L_e_reverse_d8799 <= 0: 1.0,
#  0.0 <= EX_ascb__L_e <= 1000.0: 1.0,
#  0 <= EX_ascb__L_e_reverse_75b41 <= 0: 1.0,
#  0.0 <= EX_asn__L_e <= 1000.0: 1.0,
#  0 <= EX_asn__L_e_reverse_460df <= 0: 1.0,
#  0.0 <= EX_aso3_e <= 1000.0: 1.0,
#  0 <= EX_aso3_e_reverse_32104 <= 0: 1.0,
#  0.0 <= EX_asp__L_e <= 1000.0: 1.0,
#  0 <= EX_asp__L_e_reverse_742f6 <= 0: 1.0,
#  0.0 <= EX_btn_e <= 1000.0: 1.0,
#  0 <= EX_btn_e_reverse_f2678 <= 0: 1.0,
#  0.0 <= EX_but_e <= 1000.0: 1.0,
#  0 <= EX_but_e_reverse_35eb9 <= 0: 1.0,
#  0.0 <= EX_butso3_e <= 1000.0: 1.0,
#  0 <= EX_butso3_e_reverse_31183 <= 0: 1.0,
#  0 <= EX_ca2_e <= 1000.0: 1.0,
#  0 <= EX_ca2_e_reverse_aac13 <= 1000.0: 1.0,
#  0.0 <= EX_cbi_e <= 1000.0: 1.0,
#  0 <= EX_cbi_e_reverse_207cf <= 0: 1.0,
#  0 <= EX_cbl1_e <= 1000.0: 1.0,
#  0 <= EX_cbl1_e_reverse_1093e <= 0.01: 1.0,
#  0.0 <= EX_cd2_e <= 1000.0: 1.0,
#  0 <= EX_cd2_e_reverse_0e8ba <= 0: 1.0,
#  0.0 <= EX_cgly_e <= 1000.0: 1.0,
#  0 <= EX_cgly_e_reverse_12551 <= 0: 1.0,
#  0.0 <= EX_chol_e <= 1000.0: 1.0,
#  0 <= EX_chol_e_reverse_b6b50 <= 0: 1.0,
#  0.0 <= EX_chtbs_e <= 1000.0: 1.0,
#  0 <= EX_chtbs_e_reverse_bbe59 <= 0: 1.0,
#  0.0 <= EX_cit_e <= 1000.0: 1.0,
#  0 <= EX_cit_e_reverse_0835e <= 0: 1.0,
#  0 <= EX_cl_e <= 1000.0: 1.0,
#  0 <= EX_cl_e_reverse_2429b <= 1000.0: 1.0,
#  0.0 <= EX_cm_e <= 1000.0: 1.0,
#  0 <= EX_cm_e_reverse_d60e9 <= 0: 1.0,
#  0.0 <= EX_cmp_e <= 1000.0: 1.0,
#  0 <= EX_cmp_e_reverse_e7a73 <= 0: 1.0,
#  0 <= EX_co2_e <= 1000.0: 1.0,
#  0 <= EX_co2_e_reverse_d0466 <= 1000.0: 1.0,
#  0 <= EX_cobalt2_e <= 1000.0: 1.0,
#  0 <= EX_cobalt2_e_reverse_2bf0e <= 1000.0: 1.0,
#  0.0 <= EX_colipa_e <= 1000.0: 1.0,
#  0 <= EX_colipa_e_reverse_f9125 <= 0: 1.0,
#  0.0 <= EX_colipap_e <= 1000.0: 1.0,
#  0 <= EX_colipap_e_reverse_c02be <= 0: 1.0,
#  0.0 <= EX_cpgn_e <= 1000.0: 1.0,
#  0 <= EX_cpgn_e_reverse_a1559 <= 0: 1.0,
#  0.0 <= EX_cpgn__un_e <= 1000.0: 1.0,
#  0 <= EX_cpgn__un_e_reverse_a7fcb <= 0: 1.0,
#  0.0 <= EX_crn_e <= 1000.0: 1.0,
#  0 <= EX_crn_e_reverse_a19eb <= 0: 1.0,
#  0.0 <= EX_crn__D_e <= 1000.0: 1.0,
#  0 <= EX_crn__D_e_reverse_fbfeb <= 0: 1.0,
#  0.0 <= EX_csn_e <= 1000.0: 1.0,
#  0 <= EX_csn_e_reverse_80cf5 <= 0: 1.0,
#  0.0 <= EX_cu_e <= 1000.0: 1.0,
#  0 <= EX_cu_e_reverse_829ec <= 0: 1.0,
#  0 <= EX_cu2_e <= 1000.0: 1.0,
#  0 <= EX_cu2_e_reverse_02682 <= 1000.0: 1.0,
#  0.0 <= EX_cyan_e <= 1000.0: 1.0,
#  0 <= EX_cyan_e_reverse_7cb7e <= 0: 1.0,
#  0.0 <= EX_cynt_e <= 1000.0: 1.0,
#  0 <= EX_cynt_e_reverse_b53e8 <= 0: 1.0,
#  0.0 <= EX_cys__D_e <= 1000.0: 1.0,
#  0 <= EX_cys__D_e_reverse_fd0d3 <= 0: 1.0,
#  0.0 <= EX_cys__L_e <= 1000.0: 1.0,
#  0 <= EX_cys__L_e_reverse_41339 <= 0: 1.0,
#  0.0 <= EX_cytd_e <= 1000.0: 1.0,
#  0 <= EX_cytd_e_reverse_5950b <= 0: 1.0,
#  0.0 <= EX_dad__2_e <= 1000.0: 1.0,
#  0 <= EX_dad__2_e_reverse_30ab9 <= 0: 1.0,
#  0.0 <= EX_damp_e <= 1000.0: 1.0,
#  0 <= EX_damp_e_reverse_2e1bd <= 0: 1.0,
#  0.0 <= EX_dca_e <= 1000.0: 1.0,
#  0 <= EX_dca_e_reverse_4575c <= 0: 1.0,
#  0.0 <= EX_dcmp_e <= 1000.0: 1.0,
#  0 <= EX_dcmp_e_reverse_83ed5 <= 0: 1.0,
#  0.0 <= EX_dcyt_e <= 1000.0: 1.0,
#  0 <= EX_dcyt_e_reverse_13102 <= 0: 1.0,
#  0.0 <= EX_ddca_e <= 1000.0: 1.0,
#  0 <= EX_ddca_e_reverse_6b9d2 <= 0: 1.0,
#  0.0 <= EX_dgmp_e <= 1000.0: 1.0,
#  0 <= EX_dgmp_e_reverse_88fd2 <= 0: 1.0,
#  0.0 <= EX_dgsn_e <= 1000.0: 1.0,
#  0 <= EX_dgsn_e_reverse_1b175 <= 0: 1.0,
#  0.0 <= EX_dha_e <= 1000.0: 1.0,
#  0 <= EX_dha_e_reverse_63f6d <= 0: 1.0,
#  0.0 <= EX_dimp_e <= 1000.0: 1.0,
#  0 <= EX_dimp_e_reverse_7aa5e <= 0: 1.0,
#  0.0 <= EX_din_e <= 1000.0: 1.0,
#  0 <= EX_din_e_reverse_f97eb <= 0: 1.0,
#  0.0 <= EX_dms_e <= 1000.0: 1.0,
#  0 <= EX_dms_e_reverse_51567 <= 0: 1.0,
#  0.0 <= EX_dmso_e <= 1000.0: 1.0,
#  0 <= EX_dmso_e_reverse_f4576 <= 0: 1.0,
#  0.0 <= EX_dopa_e <= 1000.0: 1.0,
#  0 <= EX_dopa_e_reverse_71ff0 <= 0: 1.0,
#  0.0 <= EX_doxrbcn_e <= 1000.0: 1.0,
#  0 <= EX_doxrbcn_e_reverse_d7e41 <= 0: 1.0,
#  0.0 <= EX_dtmp_e <= 1000.0: 1.0,
#  0 <= EX_dtmp_e_reverse_7a713 <= 0: 1.0,
#  0.0 <= EX_dump_e <= 1000.0: 1.0,
#  0 <= EX_dump_e_reverse_2c836 <= 0: 1.0,
#  0.0 <= EX_duri_e <= 1000.0: 1.0,
#  0 <= EX_duri_e_reverse_d0523 <= 0: 1.0,
#  0.0 <= EX_eca4colipa_e <= 1000.0: 1.0,
#  0 <= EX_eca4colipa_e_reverse_579ab <= 0: 1.0,
#  0.0 <= EX_enlipa_e <= 1000.0: 1.0,
#  0 <= EX_enlipa_e_reverse_2dd41 <= 0: 1.0,
#  0.0 <= EX_enter_e <= 1000.0: 1.0,
#  0 <= EX_enter_e_reverse_7bf45 <= 0: 1.0,
#  0.0 <= EX_etha_e <= 1000.0: 1.0,
#  0 <= EX_etha_e_reverse_a3984 <= 0: 1.0,
#  0.0 <= EX_ethso3_e <= 1000.0: 1.0,
#  0 <= EX_ethso3_e_reverse_d2ed7 <= 0: 1.0,
#  0.0 <= EX_etoh_e <= 1000.0: 1.0,
#  0 <= EX_etoh_e_reverse_cc64f <= 0: 1.0,
#  0.0 <= EX_f6p_e <= 1000.0: 1.0,
#  0 <= EX_f6p_e_reverse_e362f <= 0: 1.0,
#  0.0 <= EX_fald_e <= 1000.0: 1.0,
#  0 <= EX_fald_e_reverse_57d26 <= 0: 1.0,
#  0 <= EX_fe2_e <= 1000.0: 1.0,
#  0 <= EX_fe2_e_reverse_25e68 <= 1000.0: 1.0,
#  0 <= EX_fe3_e <= 1000.0: 1.0,
#  0 <= EX_fe3_e_reverse_8b617 <= 1000.0: 1.0,
#  0.0 <= EX_fe3dcit_e <= 1000.0: 1.0,
#  0 <= EX_fe3dcit_e_reverse_a5939 <= 0: 1.0,
#  0.0 <= EX_fe3dhbzs_e <= 1000.0: 1.0,
#  0 <= EX_fe3dhbzs_e_reverse_93deb <= 0: 1.0,
#  0.0 <= EX_fe3hox_e <= 1000.0: 1.0,
#  0 <= EX_fe3hox_e_reverse_e323a <= 0: 1.0,
#  0.0 <= EX_fe3hox__un_e <= 1000.0: 1.0,
#  0 <= EX_fe3hox__un_e_reverse_342fd <= 0: 1.0,
#  0.0 <= EX_fecrm_e <= 1000.0: 1.0,
#  0 <= EX_fecrm_e_reverse_26983 <= 0: 1.0,
#  0.0 <= EX_fecrm__un_e <= 1000.0: 1.0,
#  0 <= EX_fecrm__un_e_reverse_a4187 <= 0: 1.0,
#  0.0 <= EX_feenter_e <= 1000.0: 1.0,
#  0 <= EX_feenter_e_reverse_73fde <= 0: 1.0,
#  0.0 <= EX_feoxam_e <= 1000.0: 1.0,
#  0 <= EX_feoxam_e_reverse_97348 <= 0: 1.0,
#  0.0 <= EX_feoxam__un_e <= 1000.0: 1.0,
#  0 <= EX_feoxam__un_e_reverse_411be <= 0: 1.0,
#  0.0 <= EX_for_e <= 1000.0: 1.0,
#  0 <= EX_for_e_reverse_23269 <= 0: 1.0,
#  0.0 <= EX_fru_e <= 1000.0: 1.0,
#  0 <= EX_fru_e_reverse_c3828 <= 0: 1.0,
#  0.0 <= EX_frulys_e <= 1000.0: 1.0,
#  0 <= EX_frulys_e_reverse_379f1 <= 0: 1.0,
#  0.0 <= EX_fruur_e <= 1000.0: 1.0,
#  0 <= EX_fruur_e_reverse_2763f <= 0: 1.0,
#  0.0 <= EX_fuc__L_e <= 1000.0: 1.0,
#  0 <= EX_fuc__L_e_reverse_e70a8 <= 0: 1.0,
#  0.0 <= EX_fum_e <= 1000.0: 1.0,
#  0 <= EX_fum_e_reverse_e3432 <= 0: 1.0,
#  0.0 <= EX_fusa_e <= 1000.0: 1.0,
#  0 <= EX_fusa_e_reverse_bf5b5 <= 0: 1.0,
#  0.0 <= EX_g1p_e <= 1000.0: 1.0,
#  0 <= EX_g1p_e_reverse_350fc <= 0: 1.0,
#  0.0 <= EX_g3pc_e <= 1000.0: 1.0,
#  0 <= EX_g3pc_e_reverse_ffe85 <= 0: 1.0,
#  0.0 <= EX_g3pe_e <= 1000.0: 1.0,
#  0 <= EX_g3pe_e_reverse_8f39b <= 0: 1.0,
#  0.0 <= EX_g3pg_e <= 1000.0: 1.0,
#  0 <= EX_g3pg_e_reverse_5e370 <= 0: 1.0,
#  0.0 <= EX_g3pi_e <= 1000.0: 1.0,
#  0 <= EX_g3pi_e_reverse_f11b2 <= 0: 1.0,
#  0.0 <= EX_g3ps_e <= 1000.0: 1.0,
#  0 <= EX_g3ps_e_reverse_70d70 <= 0: 1.0,
#  0.0 <= EX_g6p_e <= 1000.0: 1.0,
#  0 <= EX_g6p_e_reverse_c15e5 <= 0: 1.0,
#  0.0 <= EX_gal_e <= 1000.0: 1.0,
#  0 <= EX_gal_e_reverse_d166c <= 0: 1.0,
#  0.0 <= EX_gal__bD_e <= 1000.0: 1.0,
#  0 <= EX_gal__bD_e_reverse_6cde3 <= 0: 1.0,
#  0.0 <= EX_gal1p_e <= 1000.0: 1.0,
#  0 <= EX_gal1p_e_reverse_aab63 <= 0: 1.0,
#  0.0 <= EX_galct__D_e <= 1000.0: 1.0,
#  0 <= EX_galct__D_e_reverse_ff408 <= 0: 1.0,
#  0.0 <= EX_galctn__D_e <= 1000.0: 1.0,
#  0 <= EX_galctn__D_e_reverse_c58a3 <= 0: 1.0,
#  0.0 <= EX_galctn__L_e <= 1000.0: 1.0,
#  0 <= EX_galctn__L_e_reverse_998c0 <= 0: 1.0,
#  0.0 <= EX_galt_e <= 1000.0: 1.0,
#  0 <= EX_galt_e_reverse_4d1d0 <= 0: 1.0,
#  0.0 <= EX_galur_e <= 1000.0: 1.0,
#  0 <= EX_galur_e_reverse_f6a10 <= 0: 1.0,
#  0.0 <= EX_gam_e <= 1000.0: 1.0,
#  0 <= EX_gam_e_reverse_3d249 <= 0: 1.0,
#  0.0 <= EX_gam6p_e <= 1000.0: 1.0,
#  0 <= EX_gam6p_e_reverse_be0d8 <= 0: 1.0,
#  0.0 <= EX_gbbtn_e <= 1000.0: 1.0,
#  0 <= EX_gbbtn_e_reverse_767c1 <= 0: 1.0,
#  0.0 <= EX_gdp_e <= 1000.0: 1.0,
#  0 <= EX_gdp_e_reverse_950ab <= 0: 1.0,
#  0 <= EX_glc_e <= 1000.0: 1.0,
#  0 <= EX_glc_e_reverse_6226d <= 10.0: 1.0,
#  0.0 <= EX_glcn_e <= 1000.0: 1.0,
#  0 <= EX_glcn_e_reverse_9e36b <= 0: 1.0,
#  0.0 <= EX_glcr_e <= 1000.0: 1.0,
#  0 <= EX_glcr_e_reverse_ea55f <= 0: 1.0,
#  0.0 <= EX_glcur_e <= 1000.0: 1.0,
#  0 <= EX_glcur_e_reverse_0ab2d <= 0: 1.0,
#  0.0 <= EX_glcur1p_e <= 1000.0: 1.0,
#  0 <= EX_glcur1p_e_reverse_7a2e5 <= 0: 1.0,
#  0.0 <= EX_gln__L_e <= 1000.0: 1.0,
#  0 <= EX_gln__L_e_reverse_6a1a1 <= 0: 1.0,
#  0.0 <= EX_glu__L_e <= 1000.0: 1.0,
#  0 <= EX_glu__L_e_reverse_42f6c <= 0: 1.0,
#  0.0 <= EX_gly_e <= 1000.0: 1.0,
#  0 <= EX_gly_e_reverse_6956b <= 0: 1.0,
#  0.0 <= EX_glyald_e <= 1000.0: 1.0,
#  0 <= EX_glyald_e_reverse_f761f <= 0: 1.0,
#  0.0 <= EX_glyb_e <= 1000.0: 1.0,
#  0 <= EX_glyb_e_reverse_0bd65 <= 0: 1.0,
#  0.0 <= EX_glyc_e <= 1000.0: 1.0,
#  0 <= EX_glyc_e_reverse_c3ec2 <= 0: 1.0,
#  0.0 <= EX_glyc__R_e <= 1000.0: 1.0,
#  0 <= EX_glyc__R_e_reverse_91560 <= 0: 1.0,
#  0.0 <= EX_glyc2p_e <= 1000.0: 1.0,
#  0 <= EX_glyc2p_e_reverse_7a57e <= 0: 1.0,
#  0.0 <= EX_glyc3p_e <= 1000.0: 1.0,
#  0 <= EX_glyc3p_e_reverse_74e5f <= 0: 1.0,
#  0.0 <= EX_glyclt_e <= 1000.0: 1.0,
#  0 <= EX_glyclt_e_reverse_395e1 <= 0: 1.0,
#  0.0 <= EX_gmp_e <= 1000.0: 1.0,
#  0 <= EX_gmp_e_reverse_f6d0a <= 0: 1.0,
#  0.0 <= EX_gsn_e <= 1000.0: 1.0,
#  0 <= EX_gsn_e_reverse_cb307 <= 0: 1.0,
#  0.0 <= EX_gthox_e <= 1000.0: 1.0,
#  0 <= EX_gthox_e_reverse_ca051 <= 0: 1.0,
#  0.0 <= EX_gthrd_e <= 1000.0: 1.0,
#  0 <= EX_gthrd_e_reverse_be1ab <= 0: 1.0,
#  0.0 <= EX_gtp_e <= 1000.0: 1.0,
#  0 <= EX_gtp_e_reverse_9f3aa <= 0: 1.0,
#  0.0 <= EX_gua_e <= 1000.0: 1.0,
#  0 <= EX_gua_e_reverse_11317 <= 0: 1.0,
#  0 <= EX_h_e <= 1000.0: 1.0,
#  0 <= EX_h_e_reverse_3e0c5 <= 1000.0: 1.0,
#  0.0 <= EX_h2_e <= 1000.0: 1.0,
#  0 <= EX_h2_e_reverse_f55e9 <= 0: 1.0,
#  0 <= EX_h2o_e <= 1000.0: 1.0,
#  0 <= EX_h2o_e_reverse_3ced4 <= 1000.0: 1.0,
#  0.0 <= EX_h2o2_e <= 1000.0: 1.0,
#  0 <= EX_h2o2_e_reverse_d52c5 <= 0: 1.0,
#  0.0 <= EX_h2s_e <= 1000.0: 1.0,
#  0 <= EX_h2s_e_reverse_c847c <= 0: 1.0,
#  0.0 <= EX_hacolipa_e <= 1000.0: 1.0,
#  0 <= EX_hacolipa_e_reverse_4a785 <= 0: 1.0,
#  0.0 <= EX_halipa_e <= 1000.0: 1.0,
#  0 <= EX_halipa_e_reverse_f6505 <= 0: 1.0,
#  0.0 <= EX_hdca_e <= 1000.0: 1.0,
#  0 <= EX_hdca_e_reverse_9ab38 <= 0: 1.0,
#  0.0 <= EX_hdcea_e <= 1000.0: 1.0,
#  0 <= EX_hdcea_e_reverse_e9406 <= 0: 1.0,
#  0.0 <= EX_hg2_e <= 1000.0: 1.0,
#  0 <= EX_hg2_e_reverse_fc882 <= 0: 1.0,
#  0.0 <= EX_his__L_e <= 1000.0: 1.0,
#  0 <= EX_his__L_e_reverse_33439 <= 0: 1.0,
#  0.0 <= EX_hom__L_e <= 1000.0: 1.0,
#  0 <= EX_hom__L_e_reverse_3e4e5 <= 0: 1.0,
#  0.0 <= EX_hxa_e <= 1000.0: 1.0,
#  0 <= EX_hxa_e_reverse_e1287 <= 0: 1.0,
#  0.0 <= EX_hxan_e <= 1000.0: 1.0,
#  0 <= EX_hxan_e_reverse_90f99 <= 0: 1.0,
#  0.0 <= EX_idon__L_e <= 1000.0: 1.0,
#  0 <= EX_idon__L_e_reverse_54aa6 <= 0: 1.0,
#  0.0 <= EX_ile__L_e <= 1000.0: 1.0,
#  0 <= EX_ile__L_e_reverse_e862a <= 0: 1.0,
#  0.0 <= EX_imp_e <= 1000.0: 1.0,
#  0 <= EX_imp_e_reverse_a877a <= 0: 1.0,
#  0.0 <= EX_indole_e <= 1000.0: 1.0,
#  0 <= EX_indole_e_reverse_3cb9c <= 0: 1.0,
#  0.0 <= EX_inost_e <= 1000.0: 1.0,
#  0 <= EX_inost_e_reverse_4d21d <= 0: 1.0,
#  0.0 <= EX_ins_e <= 1000.0: 1.0,
#  0 <= EX_ins_e_reverse_989e1 <= 0: 1.0,
#  0.0 <= EX_isetac_e <= 1000.0: 1.0,
#  0 <= EX_isetac_e_reverse_62d58 <= 0: 1.0,
#  0 <= EX_k_e <= 1000.0: 1.0,
#  0 <= EX_k_e_reverse_42613 <= 1000.0: 1.0,
#  0.0 <= EX_kdo2lipid4_e <= 1000.0: 1.0,
#  0 <= EX_kdo2lipid4_e_reverse_fb486 <= 0: 1.0,
#  0.0 <= EX_lac__D_e <= 1000.0: 1.0,
#  0 <= EX_lac__D_e_reverse_f95b4 <= 0: 1.0,
#  0.0 <= EX_lac__L_e <= 1000.0: 1.0,
#  0 <= EX_lac__L_e_reverse_8586b <= 0: 1.0,
#  0.0 <= EX_lcts_e <= 1000.0: 1.0,
#  0 <= EX_lcts_e_reverse_13088 <= 0: 1.0,
#  0.0 <= EX_leu__L_e <= 1000.0: 1.0,
#  0 <= EX_leu__L_e_reverse_d40a5 <= 0: 1.0,
#  0.0 <= EX_lipa_e <= 1000.0: 1.0,
#  0 <= EX_lipa_e_reverse_1cc13 <= 0: 1.0,
#  0.0 <= EX_lipa_cold_e <= 1000.0: 1.0,
#  0 <= EX_lipa_cold_e_reverse_ce98e <= 0: 1.0,
#  0.0 <= EX_lipoate_e <= 1000.0: 1.0,
#  0 <= EX_lipoate_e_reverse_4faad <= 0: 1.0,
#  0.0 <= EX_lys__L_e <= 1000.0: 1.0,
#  0 <= EX_lys__L_e_reverse_4f08c <= 0: 1.0,
#  0.0 <= EX_lyx__L_e <= 1000.0: 1.0,
#  0 <= EX_lyx__L_e_reverse_693d8 <= 0: 1.0,
#  0.0 <= EX_mal__D_e <= 1000.0: 1.0,
#  0 <= EX_mal__D_e_reverse_ce476 <= 0: 1.0,
#  0.0 <= EX_mal__L_e <= 1000.0: 1.0,
#  0 <= EX_mal__L_e_reverse_af154 <= 0: 1.0,
#  0.0 <= EX_malt_e <= 1000.0: 1.0,
#  0 <= EX_malt_e_reverse_ab2d1 <= 0: 1.0,
#  0.0 <= EX_malthx_e <= 1000.0: 1.0,
#  0 <= EX_malthx_e_reverse_73b54 <= 0: 1.0,
#  0.0 <= EX_maltpt_e <= 1000.0: 1.0,
#  0 <= EX_maltpt_e_reverse_f82d5 <= 0: 1.0,
#  0.0 <= EX_malttr_e <= 1000.0: 1.0,
#  0 <= EX_malttr_e_reverse_241c6 <= 0: 1.0,
#  0.0 <= EX_maltttr_e <= 1000.0: 1.0,
#  0 <= EX_maltttr_e_reverse_90d23 <= 0: 1.0,
#  0.0 <= EX_man_e <= 1000.0: 1.0,
#  0 <= EX_man_e_reverse_48020 <= 0: 1.0,
#  0.0 <= EX_man6p_e <= 1000.0: 1.0,
#  0 <= EX_man6p_e_reverse_b160c <= 0: 1.0,
#  0.0 <= EX_manglyc_e <= 1000.0: 1.0,
#  0 <= EX_manglyc_e_reverse_51b57 <= 0: 1.0,
#  0.0 <= EX_melib_e <= 1000.0: 1.0,
#  0 <= EX_melib_e_reverse_68f2f <= 0: 1.0,
#  0.0 <= EX_meoh_e <= 1000.0: 1.0,
#  0 <= EX_meoh_e_reverse_45228 <= 0: 1.0,
#  0.0 <= EX_met__D_e <= 1000.0: 1.0,
#  0 <= EX_met__D_e_reverse_6e944 <= 0: 1.0,
#  0.0 <= EX_met__L_e <= 1000.0: 1.0,
#  0 <= EX_met__L_e_reverse_14908 <= 0: 1.0,
#  0.0 <= EX_metsox__R__L_e <= 1000.0: 1.0,
#  0 <= EX_metsox__R__L_e_reverse_424e5 <= 0: 1.0,
#  0.0 <= EX_metsox__S__L_e <= 1000.0: 1.0,
#  0 <= EX_metsox__S__L_e_reverse_6a3fe <= 0: 1.0,
#  0 <= EX_mg2_e <= 1000.0: 1.0,
#  0 <= EX_mg2_e_reverse_b1c98 <= 1000.0: 1.0,
#  0.0 <= EX_mincyc_e <= 1000.0: 1.0,
#  0 <= EX_mincyc_e_reverse_10267 <= 0: 1.0,
#  0.0 <= EX_minohp_e <= 1000.0: 1.0,
#  0 <= EX_minohp_e_reverse_3ce45 <= 0: 1.0,
#  0.0 <= EX_mmet_e <= 1000.0: 1.0,
#  0 <= EX_mmet_e_reverse_b6b96 <= 0: 1.0,
#  0 <= EX_mn2_e <= 1000.0: 1.0,
#  0 <= EX_mn2_e_reverse_48316 <= 1000.0: 1.0,
#  0.0 <= EX_mnl_e <= 1000.0: 1.0,
#  0 <= EX_mnl_e_reverse_c8f2a <= 0: 1.0,
#  0 <= EX_mobd_e <= 1000.0: 1.0,
#  0 <= EX_mobd_e_reverse_c6396 <= 1000.0: 1.0,
#  0.0 <= EX_mso3_e <= 1000.0: 1.0,
#  0 <= EX_mso3_e_reverse_b23ed <= 0: 1.0,
#  0.0 <= EX_n2o_e <= 1000.0: 1.0,
#  0 <= EX_n2o_e_reverse_33405 <= 0: 1.0,
#  0 <= EX_na1_e <= 1000.0: 1.0,
#  0 <= EX_na1_e_reverse_c64df <= 1000.0: 1.0,
#  0.0 <= EX_nac_e <= 1000.0: 1.0,
#  0 <= EX_nac_e_reverse_23356 <= 0: 1.0,
#  0 <= EX_nh4_e <= 1000.0: 1.0,
#  0 <= EX_nh4_e_reverse_f9cc6 <= 1000.0: 1.0,
#  0 <= EX_ni2_e <= 1000.0: 1.0,
#  0 <= EX_ni2_e_reverse_7ba33 <= 1000.0: 1.0,
#  0.0 <= EX_nmn_e <= 1000.0: 1.0,
#  0 <= EX_nmn_e_reverse_59f7d <= 0: 1.0,
#  0.0 <= EX_no_e <= 1000.0: 1.0,
#  0 <= EX_no_e_reverse_ffd01 <= 0: 1.0,
#  0.0 <= EX_no2_e <= 1000.0: 1.0,
#  0 <= EX_no2_e_reverse_1ddec <= 0: 1.0,
#  0.0 <= EX_no3_e <= 1000.0: 1.0,
#  0 <= EX_no3_e_reverse_98d30 <= 0: 1.0,
#  0.0 <= EX_novbcn_e <= 1000.0: 1.0,
#  0 <= EX_novbcn_e_reverse_14cc2 <= 0: 1.0,
#  0.0 <= EX_o16a4colipa_e <= 1000.0: 1.0,
#  0 <= EX_o16a4colipa_e_reverse_48f50 <= 0: 1.0,
#  0 <= EX_o2_e <= 1000.0: 1.0,
#  0 <= EX_o2_e_reverse_efa94 <= 1000.0: 1.0,
#  0.0 <= EX_o2s_e <= 1000.0: 1.0,
#  0 <= EX_o2s_e_reverse_82732 <= 0: 1.0,
#  0.0 <= EX_ocdca_e <= 1000.0: 1.0,
#  0 <= EX_ocdca_e_reverse_86d1d <= 0: 1.0,
#  0.0 <= EX_ocdcea_e <= 1000.0: 1.0,
#  0 <= EX_ocdcea_e_reverse_5ebe2 <= 0: 1.0,
#  0.0 <= EX_octa_e <= 1000.0: 1.0,
#  0 <= EX_octa_e_reverse_38d1e <= 0: 1.0,
#  0.0 <= EX_orn_e <= 1000.0: 1.0,
#  0 <= EX_orn_e_reverse_269bb <= 0: 1.0,
#  0.0 <= EX_orot_e <= 1000.0: 1.0,
#  0 <= EX_orot_e_reverse_032e7 <= 0: 1.0,
#  0.0 <= EX_pacald_e <= 1000.0: 1.0,
#  0 <= EX_pacald_e_reverse_54b80 <= 0: 1.0,
#  0.0 <= EX_peamn_e <= 1000.0: 1.0,
#  0 <= EX_peamn_e_reverse_34c33 <= 0: 1.0,
#  0.0 <= EX_phe__L_e <= 1000.0: 1.0,
#  0 <= EX_phe__L_e_reverse_10066 <= 0: 1.0,
#  0.0 <= EX_pheme_e <= 1000.0: 1.0,
#  0 <= EX_pheme_e_reverse_8e123 <= 0: 1.0,
#  0 <= EX_pi_e <= 1000.0: 1.0,
#  0 <= EX_pi_e_reverse_1fb09 <= 1000.0: 1.0,
#  0.0 <= EX_pnto__R_e <= 1000.0: 1.0,
#  0 <= EX_pnto__R_e_reverse_a498c <= 0: 1.0,
#  0.0 <= EX_ppa_e <= 1000.0: 1.0,
#  0 <= EX_ppa_e_reverse_1faa3 <= 0: 1.0,
#  0.0 <= EX_ppal_e <= 1000.0: 1.0,
#  0 <= EX_ppal_e_reverse_bb983 <= 0: 1.0,
#  0.0 <= EX_pppn_e <= 1000.0: 1.0,
#  0 <= EX_pppn_e_reverse_4f187 <= 0: 1.0,
#  0.0 <= EX_ppt_e <= 1000.0: 1.0,
#  0 <= EX_ppt_e_reverse_b97a7 <= 0: 1.0,
#  0.0 <= EX_pro__L_e <= 1000.0: 1.0,
#  0 <= EX_pro__L_e_reverse_5f8c5 <= 0: 1.0,
#  0.0 <= EX_progly_e <= 1000.0: 1.0,
#  0 <= EX_progly_e_reverse_cccb4 <= 0: 1.0,
#  0.0 <= EX_psclys_e <= 1000.0: 1.0,
#  0 <= EX_psclys_e_reverse_4686a <= 0: 1.0,
#  0.0 <= EX_pser__L_e <= 1000.0: 1.0,
#  0 <= EX_pser__L_e_reverse_164b6 <= 0: 1.0,
#  0.0 <= EX_ptrc_e <= 1000.0: 1.0,
#  0 <= EX_ptrc_e_reverse_6c850 <= 0: 1.0,
#  0.0 <= EX_pydam_e <= 1000.0: 1.0,
#  0 <= EX_pydam_e_reverse_b5003 <= 0: 1.0,
#  0.0 <= EX_pydx_e <= 1000.0: 1.0,
#  0 <= EX_pydx_e_reverse_9cc71 <= 0: 1.0,
#  0.0 <= EX_pydxn_e <= 1000.0: 1.0,
#  0 <= EX_pydxn_e_reverse_ce451 <= 0: 1.0,
#  0.0 <= EX_pyr_e <= 1000.0: 1.0,
#  0 <= EX_pyr_e_reverse_1f6de <= 0: 1.0,
#  0.0 <= EX_quin_e <= 1000.0: 1.0,
#  0 <= EX_quin_e_reverse_45058 <= 0: 1.0,
#  0.0 <= EX_r5p_e <= 1000.0: 1.0,
#  0 <= EX_r5p_e_reverse_383fe <= 0: 1.0,
#  0.0 <= EX_rfamp_e <= 1000.0: 1.0,
#  0 <= EX_rfamp_e_reverse_6d14f <= 0: 1.0,
#  0.0 <= EX_rib__D_e <= 1000.0: 1.0,
#  0 <= EX_rib__D_e_reverse_4a19a <= 0: 1.0,
#  0.0 <= EX_rmn_e <= 1000.0: 1.0,
#  0 <= EX_rmn_e_reverse_b3160 <= 0: 1.0,
#  0.0 <= EX_sbt__D_e <= 1000.0: 1.0,
#  0 <= EX_sbt__D_e_reverse_52f23 <= 0: 1.0,
#  0 <= EX_sel_e <= 1000.0: 1.0,
#  0 <= EX_sel_e_reverse_ffc35 <= 1000.0: 1.0,
#  0.0 <= EX_ser__D_e <= 1000.0: 1.0,
#  0 <= EX_ser__D_e_reverse_99725 <= 0: 1.0,
#  0.0 <= EX_ser__L_e <= 1000.0: 1.0,
#  0 <= EX_ser__L_e_reverse_b0b37 <= 0: 1.0,
#  0.0 <= EX_skm_e <= 1000.0: 1.0,
#  0 <= EX_skm_e_reverse_ed122 <= 0: 1.0,
#  0 <= EX_slnt_e <= 1000.0: 1.0,
#  0 <= EX_slnt_e_reverse_97bba <= 1000.0: 1.0,
#  0.0 <= EX_so2_e <= 1000.0: 1.0,
#  0 <= EX_so2_e_reverse_de12f <= 0: 1.0,
#  0.0 <= EX_so3_e <= 1000.0: 1.0,
#  0 <= EX_so3_e_reverse_116a1 <= 0: 1.0,
#  0 <= EX_so4_e <= 1000.0: 1.0,
#  0 <= EX_so4_e_reverse_5c8ed <= 1000.0: 1.0,
#  0.0 <= EX_spmd_e <= 1000.0: 1.0,
#  0 <= EX_spmd_e_reverse_761ad <= 0: 1.0,
#  0.0 <= EX_succ_e <= 1000.0: 1.0,
#  0 <= EX_succ_e_reverse_a9039 <= 0: 1.0,
#  0.0 <= EX_sucr_e <= 1000.0: 1.0,
#  0 <= EX_sucr_e_reverse_0215c <= 0: 1.0,
#  0.0 <= EX_sulfac_e <= 1000.0: 1.0,
#  0 <= EX_sulfac_e_reverse_2695d <= 0: 1.0,
#  0.0 <= EX_tartr__D_e <= 1000.0: 1.0,
#  0 <= EX_tartr__D_e_reverse_93e71 <= 0: 1.0,
#  0.0 <= EX_tartr__L_e <= 1000.0: 1.0,
#  0 <= EX_tartr__L_e_reverse_6023a <= 0: 1.0,
#  0.0 <= EX_taur_e <= 1000.0: 1.0,
#  0 <= EX_taur_e_reverse_69949 <= 0: 1.0,
#  0.0 <= EX_tcynt_e <= 1000.0: 1.0,
#  0 <= EX_tcynt_e_reverse_739e6 <= 0: 1.0,
#  0.0 <= EX_thm_e <= 1000.0: 1.0,
#  0 <= EX_thm_e_reverse_96547 <= 0: 1.0,
#  0.0 <= EX_thr__L_e <= 1000.0: 1.0,
#  0 <= EX_thr__L_e_reverse_ddaf9 <= 0: 1.0,
#  0.0 <= EX_thrp_e <= 1000.0: 1.0,
#  0 <= EX_thrp_e_reverse_51d63 <= 0: 1.0,
#  0.0 <= EX_thym_e <= 1000.0: 1.0,
#  0 <= EX_thym_e_reverse_84e99 <= 0: 1.0,
#  0.0 <= EX_thymd_e <= 1000.0: 1.0,
#  0 <= EX_thymd_e_reverse_94c6c <= 0: 1.0,
#  0.0 <= EX_tma_e <= 1000.0: 1.0,
#  0 <= EX_tma_e_reverse_1429d <= 0: 1.0,
#  0.0 <= EX_tmao_e <= 1000.0: 1.0,
#  0 <= EX_tmao_e_reverse_18ba4 <= 0: 1.0,
#  0.0 <= EX_tre_e <= 1000.0: 1.0,
#  0 <= EX_tre_e_reverse_fb5f1 <= 0: 1.0,
#  0.0 <= EX_trp__L_e <= 1000.0: 1.0,
#  0 <= EX_trp__L_e_reverse_d9983 <= 0: 1.0,
#  0.0 <= EX_tsul_e <= 1000.0: 1.0,
#  0 <= EX_tsul_e_reverse_22ca1 <= 0: 1.0,
#  0.0 <= EX_ttdca_e <= 1000.0: 1.0,
#  0 <= EX_ttdca_e_reverse_c67f4 <= 0: 1.0,
#  0.0 <= EX_ttdcea_e <= 1000.0: 1.0,
#  0 <= EX_ttdcea_e_reverse_e3700 <= 0: 1.0,
#  0.0 <= EX_ttrcyc_e <= 1000.0: 1.0,
#  0 <= EX_ttrcyc_e_reverse_0d8fb <= 0: 1.0,
#  0 <= EX_tungs_e <= 1000.0: 1.0,
#  0 <= EX_tungs_e_reverse_6ffff <= 1000.0: 1.0,
#  0.0 <= EX_tym_e <= 1000.0: 1.0,
#  0 <= EX_tym_e_reverse_e1acb <= 0: 1.0,
#  0.0 <= EX_tyr__L_e <= 1000.0: 1.0,
#  0 <= EX_tyr__L_e_reverse_516d2 <= 0: 1.0,
#  0.0 <= EX_tyrp_e <= 1000.0: 1.0,
#  0 <= EX_tyrp_e_reverse_36480 <= 0: 1.0,
#  0.0 <= EX_uacgam_e <= 1000.0: 1.0,
#  0 <= EX_uacgam_e_reverse_abfb0 <= 0: 1.0,
#  0.0 <= EX_udpacgal_e <= 1000.0: 1.0,
#  0 <= EX_udpacgal_e_reverse_a02b1 <= 0: 1.0,
#  0.0 <= EX_udpg_e <= 1000.0: 1.0,
#  0 <= EX_udpg_e_reverse_a3f02 <= 0: 1.0,
#  0.0 <= EX_udpgal_e <= 1000.0: 1.0,
#  0 <= EX_udpgal_e_reverse_9c019 <= 0: 1.0,
#  0.0 <= EX_udpglcur_e <= 1000.0: 1.0,
#  0 <= EX_udpglcur_e_reverse_baf0e <= 0: 1.0,
#  0.0 <= EX_ump_e <= 1000.0: 1.0,
#  0 <= EX_ump_e_reverse_58471 <= 0: 1.0,
#  0.0 <= EX_ura_e <= 1000.0: 1.0,
#  0 <= EX_ura_e_reverse_98cbe <= 0: 1.0,
#  0.0 <= EX_urea_e <= 1000.0: 1.0,
#  0 <= EX_urea_e_reverse_02f51 <= 0: 1.0,
#  0.0 <= EX_uri_e <= 1000.0: 1.0,
#  0 <= EX_uri_e_reverse_019f3 <= 0: 1.0,
#  0.0 <= EX_val__L_e <= 1000.0: 1.0,
#  0 <= EX_val__L_e_reverse_9e0f7 <= 0: 1.0,
#  0.0 <= EX_xan_e <= 1000.0: 1.0,
#  0 <= EX_xan_e_reverse_7bb40 <= 0: 1.0,
#  0.0 <= EX_xmp_e <= 1000.0: 1.0,
#  0 <= EX_xmp_e_reverse_5fd31 <= 0: 1.0,
#  0.0 <= EX_xtsn_e <= 1000.0: 1.0,
#  0 <= EX_xtsn_e_reverse_33417 <= 0: 1.0,
#  0.0 <= EX_xyl__D_e <= 1000.0: 1.0,
#  0 <= EX_xyl__D_e_reverse_e202a <= 0: 1.0,
#  0.0 <= EX_xylu__L_e <= 1000.0: 1.0,
#  0 <= EX_xylu__L_e_reverse_a93ff <= 0: 1.0,
#  0 <= EX_zn2_e <= 1000.0: 1.0,
#  0 <= EX_zn2_e_reverse_3c725 <= 1000.0: 1.0,
#  0.0 <= 12DGR120tipp <= 1000.0: 1.0,
#  0 <= 12DGR120tipp_reverse_757ef <= 0: 1.0,
#  0.0 <= 12DGR140tipp <= 1000.0: 1.0,
#  0 <= 12DGR140tipp_reverse_aea46 <= 0: 1.0,
#  0.0 <= 12DGR141tipp <= 1000.0: 1.0,
#  0 <= 12DGR141tipp_reverse_a0957 <= 0: 1.0,
#  0.0 <= 12DGR160tipp <= 1000.0: 1.0,
#  0 <= 12DGR160tipp_reverse_eac16 <= 0: 1.0,
#  0.0 <= 12DGR161tipp <= 1000.0: 1.0,
#  0 <= 12DGR161tipp_reverse_dcd80 <= 0: 1.0,
#  0.0 <= 12DGR180tipp <= 1000.0: 1.0,
#  0 <= 12DGR180tipp_reverse_7a012 <= 0: 1.0,
#  0.0 <= 12DGR181tipp <= 1000.0: 1.0,
#  0 <= 12DGR181tipp_reverse_34fd5 <= 0: 1.0,
#  0 <= 12PPDRtex <= 1000.0: 1.0,
#  0 <= 12PPDRtex_reverse_1d688 <= 1000.0: 1.0,
#  0 <= 12PPDRtpp <= 1000.0: 1.0,
#  0 <= 12PPDRtpp_reverse_c5519 <= 1000.0: 1.0,
#  0 <= 12PPDStex <= 1000.0: 1.0,
#  0 <= 12PPDStex_reverse_ec7d6 <= 1000.0: 1.0,
#  0 <= 12PPDStpp <= 1000.0: 1.0,
#  0 <= 12PPDStpp_reverse_81431 <= 1000.0: 1.0,
#  0.0 <= 14GLUCANabcpp <= 1000.0: 1.0,
#  0 <= 14GLUCANabcpp_reverse_c6351 <= 0: 1.0,
#  0.0 <= 14GLUCANtexi <= 1000.0: 1.0,
#  0 <= 14GLUCANtexi_reverse_2d4f8 <= 0: 1.0,
#  0 <= 23CAMPtex <= 1000.0: 1.0,
#  0 <= 23CAMPtex_reverse_1c6db <= 1000.0: 1.0,
#  0 <= 23CCMPtex <= 1000.0: 1.0,
#  0 <= 23CCMPtex_reverse_e7e14 <= 1000.0: 1.0,
#  0 <= 23CGMPtex <= 1000.0: 1.0,
#  0 <= 23CGMPtex_reverse_d266a <= 1000.0: 1.0,
#  0 <= 23CUMPtex <= 1000.0: 1.0,
#  0 <= 23CUMPtex_reverse_7c421 <= 1000.0: 1.0,
#  0.0 <= 23DAPPAt2pp <= 1000.0: 1.0,
#  0 <= 23DAPPAt2pp_reverse_59b55 <= 0: 1.0,
#  0 <= 23DAPPAtex <= 1000.0: 1.0,
#  0 <= 23DAPPAtex_reverse_0c987 <= 1000.0: 1.0,
#  0.0 <= 23PDE2pp <= 1000.0: 1.0,
#  0 <= 23PDE2pp_reverse_9b346 <= 0: 1.0,
#  0.0 <= 23PDE4pp <= 1000.0: 1.0,
#  0 <= 23PDE4pp_reverse_2a6cf <= 0: 1.0,
#  0.0 <= 23PDE7pp <= 1000.0: 1.0,
#  0 <= 23PDE7pp_reverse_3f150 <= 0: 1.0,
#  0.0 <= 23PDE9pp <= 1000.0: 1.0,
#  0 <= 23PDE9pp_reverse_84c1d <= 0: 1.0,
#  0 <= 26DAHtex <= 1000.0: 1.0,
#  0 <= 26DAHtex_reverse_3953d <= 1000.0: 1.0,
#  0.0 <= 2AGPA120tipp <= 1000.0: 1.0,
#  0 <= 2AGPA120tipp_reverse_16d01 <= 0: 1.0,
#  0.0 <= 2AGPA140tipp <= 1000.0: 1.0,
#  0 <= 2AGPA140tipp_reverse_392f6 <= 0: 1.0,
#  0.0 <= 2AGPA141tipp <= 1000.0: 1.0,
#  0 <= 2AGPA141tipp_reverse_f9714 <= 0: 1.0,
#  0.0 <= 2AGPA160tipp <= 1000.0: 1.0,
#  0 <= 2AGPA160tipp_reverse_dc28a <= 0: 1.0,
#  0.0 <= 2AGPA161tipp <= 1000.0: 1.0,
#  0 <= 2AGPA161tipp_reverse_fa4fb <= 0: 1.0,
#  0.0 <= 2AGPA180tipp <= 1000.0: 1.0,
#  0 <= 2AGPA180tipp_reverse_b48ac <= 0: 1.0,
#  0.0 <= 2AGPA181tipp <= 1000.0: 1.0,
#  0 <= 2AGPA181tipp_reverse_3605a <= 0: 1.0,
#  0.0 <= 2AGPE120tipp <= 1000.0: 1.0,
#  0 <= 2AGPE120tipp_reverse_015fb <= 0: 1.0,
#  0.0 <= 2AGPE140tipp <= 1000.0: 1.0,
#  0 <= 2AGPE140tipp_reverse_d6097 <= 0: 1.0,
#  0.0 <= 2AGPE141tipp <= 1000.0: 1.0,
#  0 <= 2AGPE141tipp_reverse_ae862 <= 0: 1.0,
#  0.0 <= 2AGPE160tipp <= 1000.0: 1.0,
#  0 <= 2AGPE160tipp_reverse_2f53f <= 0: 1.0,
#  0.0 <= 2AGPE161tipp <= 1000.0: 1.0,
#  0 <= 2AGPE161tipp_reverse_39d2b <= 0: 1.0,
#  0.0 <= 2AGPE180tipp <= 1000.0: 1.0,
#  0 <= 2AGPE180tipp_reverse_242d6 <= 0: 1.0,
#  0.0 <= 2AGPE181tipp <= 1000.0: 1.0,
#  0 <= 2AGPE181tipp_reverse_a5fc9 <= 0: 1.0,
#  0.0 <= 2AGPEAT120 <= 1000.0: 1.0,
#  0 <= 2AGPEAT120_reverse_cbf7b <= 0: 1.0,
#  0.0 <= 2AGPEAT140 <= 1000.0: 1.0,
#  0 <= 2AGPEAT140_reverse_195ed <= 0: 1.0,
#  0.0 <= 2AGPEAT141 <= 1000.0: 1.0,
#  0 <= 2AGPEAT141_reverse_0e3c9 <= 0: 1.0,
#  0.0 <= 2AGPEAT160 <= 1000.0: 1.0,
#  0 <= 2AGPEAT160_reverse_16239 <= 0: 1.0,
#  0.0 <= 2AGPEAT161 <= 1000.0: 1.0,
#  0 <= 2AGPEAT161_reverse_5858e <= 0: 1.0,
#  0.0 <= 2AGPEAT180 <= 1000.0: 1.0,
#  0 <= 2AGPEAT180_reverse_47e42 <= 0: 1.0,
#  0.0 <= 2AGPEAT181 <= 1000.0: 1.0,
#  0 <= 2AGPEAT181_reverse_450ec <= 0: 1.0,
#  0.0 <= 2AGPG120tipp <= 1000.0: 1.0,
#  0 <= 2AGPG120tipp_reverse_16620 <= 0: 1.0,
#  0.0 <= 2AGPG140tipp <= 1000.0: 1.0,
#  0 <= 2AGPG140tipp_reverse_2834e <= 0: 1.0,
#  0.0 <= 2AGPG141tipp <= 1000.0: 1.0,
#  0 <= 2AGPG141tipp_reverse_44e94 <= 0: 1.0,
#  0.0 <= 2AGPG160tipp <= 1000.0: 1.0,
#  0 <= 2AGPG160tipp_reverse_a1e99 <= 0: 1.0,
#  0.0 <= 2AGPG161tipp <= 1000.0: 1.0,
#  0 <= 2AGPG161tipp_reverse_4c821 <= 0: 1.0,
#  0.0 <= 2AGPG180tipp <= 1000.0: 1.0,
#  0 <= 2AGPG180tipp_reverse_148cb <= 0: 1.0,
#  0.0 <= 2AGPG181tipp <= 1000.0: 1.0,
#  0 <= 2AGPG181tipp_reverse_7596e <= 0: 1.0,
#  0.0 <= 2AGPGAT120 <= 1000.0: 1.0,
#  0 <= 2AGPGAT120_reverse_83703 <= 0: 1.0,
#  0.0 <= 2AGPGAT140 <= 1000.0: 1.0,
#  0 <= 2AGPGAT140_reverse_94092 <= 0: 1.0,
#  0.0 <= 2AGPGAT141 <= 1000.0: 1.0,
#  0 <= 2AGPGAT141_reverse_82d91 <= 0: 1.0,
#  0.0 <= 2AGPGAT160 <= 1000.0: 1.0,
#  0 <= 2AGPGAT160_reverse_2888d <= 0: 1.0,
#  0.0 <= 2AGPGAT161 <= 1000.0: 1.0,
#  0 <= 2AGPGAT161_reverse_529fb <= 0: 1.0,
#  0.0 <= 2AGPGAT180 <= 1000.0: 1.0,
#  0 <= 2AGPGAT180_reverse_9d3e5 <= 0: 1.0,
#  0.0 <= 2AGPGAT181 <= 1000.0: 1.0,
#  0 <= 2AGPGAT181_reverse_802a9 <= 0: 1.0,
#  0.0 <= 2DGULRGx <= 1000.0: 1.0,
#  0 <= 2DGULRGx_reverse_a7f46 <= 0: 1.0,
#  0.0 <= 2DGULRGy <= 1000.0: 1.0,
#  0 <= 2DGULRGy_reverse_cbff4 <= 0: 1.0,
#  0.0 <= 2DGULRx <= 1000.0: 1.0,
#  0 <= 2DGULRx_reverse_d1a03 <= 0: 1.0,
#  0.0 <= 2DGULRy <= 1000.0: 1.0,
#  0 <= 2DGULRy_reverse_5d02d <= 0: 1.0,
#  0.0 <= 2MAHMP <= 1000.0: 1.0,
#  0 <= 2MAHMP_reverse_e4fd2 <= 0: 1.0,
#  0 <= 34dhpactex <= 1000.0: 1.0,
#  0 <= 34dhpactex_reverse_51d40 <= 1000.0: 1.0,
#  0.0 <= 3AMACHYD <= 1000.0: 1.0,
#  0 <= 3AMACHYD_reverse_1adff <= 0: 1.0,
#  0 <= 3AMPtex <= 1000.0: 1.0,
#  0 <= 3AMPtex_reverse_62a3f <= 1000.0: 1.0,
#  0 <= 3CMPtex <= 1000.0: 1.0,
#  0 <= 3CMPtex_reverse_25d68 <= 1000.0: 1.0,
#  0 <= 3GMPtex <= 1000.0: 1.0,
#  0 <= 3GMPtex_reverse_c1214 <= 1000.0: 1.0,
#  0.0 <= 3HAD100 <= 1000.0: 1.0,
#  0 <= 3HAD100_reverse_ca00f <= 0: 1.0,
#  0.0 <= 3HAD120 <= 1000.0: 1.0,
#  0 <= 3HAD120_reverse_82f09 <= 0: 1.0,
#  0.0 <= 3HAD121 <= 1000.0: 1.0,
#  0 <= 3HAD121_reverse_7ae0d <= 0: 1.0,
#  0.0 <= 3HAD140 <= 1000.0: 1.0,
#  0 <= 3HAD140_reverse_13958 <= 0: 1.0,
#  0.0 <= 3HAD141 <= 1000.0: 1.0,
#  0 <= 3HAD141_reverse_5738f <= 0: 1.0,
#  0.0 <= 3HAD160 <= 1000.0: 1.0,
#  0 <= 3HAD160_reverse_c0da0 <= 0: 1.0,
#  0.0 <= 3HAD161 <= 1000.0: 1.0,
#  0 <= 3HAD161_reverse_384de <= 0: 1.0,
#  0.0 <= 3HAD180 <= 1000.0: 1.0,
#  0 <= 3HAD180_reverse_c801d <= 0: 1.0,
#  0.0 <= 3HAD181 <= 1000.0: 1.0,
#  0 <= 3HAD181_reverse_63f21 <= 0: 1.0,
#  0.0 <= 3HAD40 <= 1000.0: 1.0,
#  0 <= 3HAD40_reverse_bc17f <= 0: 1.0,
#  0.0 <= 3HAD60 <= 1000.0: 1.0,
#  0 <= 3HAD60_reverse_d7fb5 <= 0: 1.0,
#  0.0 <= 3HAD80 <= 1000.0: 1.0,
#  0 <= 3HAD80_reverse_29891 <= 0: 1.0,
#  0.0 <= 3HCINNMH <= 1000.0: 1.0,
#  0 <= 3HCINNMH_reverse_e3e52 <= 0: 1.0,
#  0.0 <= 3HPPPNH <= 1000.0: 1.0,
#  0 <= 3HPPPNH_reverse_b005a <= 0: 1.0,
#  0 <= 3HPPtex <= 1000.0: 1.0,
#  0 <= 3HPPtex_reverse_49e02 <= 1000.0: 1.0,
#  0.0 <= 3HPPtpp <= 1000.0: 1.0,
#  0 <= 3HPPtpp_reverse_f463c <= 0: 1.0,
#  0.0 <= 3KGK <= 1000.0: 1.0,
#  0 <= 3KGK_reverse_d559b <= 0: 1.0,
#  0.0 <= 3NTD2pp <= 1000.0: 1.0,
#  0 <= 3NTD2pp_reverse_6ebac <= 0: 1.0,
#  0.0 <= 3NTD4pp <= 1000.0: 1.0,
#  0 <= 3NTD4pp_reverse_51bb5 <= 0: 1.0,
#  0.0 <= 3NTD7pp <= 1000.0: 1.0,
#  0 <= 3NTD7pp_reverse_9ab3e <= 0: 1.0,
#  0.0 <= 3NTD9pp <= 1000.0: 1.0,
#  0 <= 3NTD9pp_reverse_6286c <= 0: 1.0,
#  0 <= 3OAR100 <= 1000.0: 1.0,
#  0 <= 3OAR100_reverse_d47e7 <= 1000.0: 1.0,
#  0 <= 3OAR120 <= 1000.0: 1.0,
#  0 <= 3OAR120_reverse_5a2b4 <= 1000.0: 1.0,
#  0.0 <= 3OAR121 <= 1000.0: 1.0,
#  0 <= 3OAR121_reverse_82b84 <= 0: 1.0,
#  0 <= 3OAR140 <= 1000.0: 1.0,
#  0 <= 3OAR140_reverse_4eb2a <= 1000.0: 1.0,
#  0.0 <= 3OAR141 <= 1000.0: 1.0,
#  0 <= 3OAR141_reverse_755ec <= 0: 1.0,
#  0 <= 3OAR160 <= 1000.0: 1.0,
#  0 <= 3OAR160_reverse_15066 <= 1000.0: 1.0,
#  0.0 <= 3OAR161 <= 1000.0: 1.0,
#  0 <= 3OAR161_reverse_fc9b4 <= 0: 1.0,
#  0 <= 3OAR180 <= 1000.0: 1.0,
#  0 <= 3OAR180_reverse_e234c <= 1000.0: 1.0,
#  0.0 <= 3OAR181 <= 1000.0: 1.0,
#  0 <= 3OAR181_reverse_f8559 <= 0: 1.0,
#  0 <= 3OAR40 <= 1000.0: 1.0,
#  0 <= 3OAR40_reverse_e075e <= 1000.0: 1.0,
#  0 <= 3OAR60 <= 1000.0: 1.0,
#  0 <= 3OAR60_reverse_40a5c <= 1000.0: 1.0,
#  0 <= 3OAR80 <= 1000.0: 1.0,
#  0 <= 3OAR80_reverse_fe338 <= 1000.0: 1.0,
#  0.0 <= 3OAS100 <= 1000.0: 1.0,
#  0 <= 3OAS100_reverse_bfd7d <= 0: 1.0,
#  0.0 <= 3OAS120 <= 1000.0: 1.0,
#  0 <= 3OAS120_reverse_06658 <= 0: 1.0,
#  0.0 <= 3OAS121 <= 1000.0: 1.0,
#  0 <= 3OAS121_reverse_e6125 <= 0: 1.0,
#  0.0 <= 3OAS140 <= 1000.0: 1.0,
#  0 <= 3OAS140_reverse_65ddc <= 0: 1.0,
#  0.0 <= 3OAS141 <= 1000.0: 1.0,
#  0 <= 3OAS141_reverse_7f7b2 <= 0: 1.0,
#  0.0 <= 3OAS160 <= 1000.0: 1.0,
#  0 <= 3OAS160_reverse_08317 <= 0: 1.0,
#  0.0 <= 3OAS161 <= 1000.0: 1.0,
#  0 <= 3OAS161_reverse_ca056 <= 0: 1.0,
#  0.0 <= 3OAS180 <= 1000.0: 1.0,
#  0 <= 3OAS180_reverse_3d9f8 <= 0: 1.0,
#  0.0 <= 3OAS181 <= 1000.0: 1.0,
#  0 <= 3OAS181_reverse_2c21d <= 0: 1.0,
#  0.0 <= 3OAS60 <= 1000.0: 1.0,
#  0 <= 3OAS60_reverse_bff6a <= 0: 1.0,
#  0.0 <= 3OAS80 <= 1000.0: 1.0,
#  0 <= 3OAS80_reverse_c6446 <= 0: 1.0,
#  0.0 <= 3OXCOAT <= 1000.0: 1.0,
#  0 <= 3OXCOAT_reverse_2bb18 <= 0: 1.0,
#  0.0 <= 3PEPTabcpp <= 1000.0: 1.0,
#  0 <= 3PEPTabcpp_reverse_d34e9 <= 0: 1.0,
#  0 <= 3PEPTtex <= 1000.0: 1.0,
#  0 <= 3PEPTtex_reverse_45a83 <= 1000.0: 1.0,
#  0 <= 3UMPtex <= 1000.0: 1.0,
#  0 <= 3UMPtex_reverse_c4def <= 1000.0: 1.0,
#  0.0 <= 42A12BOOXpp <= 1000.0: 1.0,
#  0 <= 42A12BOOXpp_reverse_a8a8a <= 0: 1.0,
#  0 <= 4HOXPACDtex <= 1000.0: 1.0,
#  0 <= 4HOXPACDtex_reverse_3798d <= 1000.0: 1.0,
#  0.0 <= 4HTHRS <= 1000.0: 1.0,
#  0 <= 4HTHRS_reverse_6e403 <= 0: 1.0,
#  0.0 <= 4PCP <= 1000.0: 1.0,
#  0 <= 4PCP_reverse_c7c51 <= 0: 1.0,
#  0.0 <= 4PCPpp <= 1000.0: 1.0,
#  0 <= 4PCPpp_reverse_87e32 <= 0: 1.0,
#  0.0 <= 4PEPTabcpp <= 1000.0: 1.0,
#  0 <= 4PEPTabcpp_reverse_c63ab <= 0: 1.0,
#  0 <= 4PEPTtex <= 1000.0: 1.0,
#  0 <= 4PEPTtex_reverse_025c0 <= 1000.0: 1.0,
#  0 <= 5DGLCNR <= 1000.0: 1.0,
#  0 <= 5DGLCNR_reverse_fbc12 <= 1000.0: 1.0,
#  0 <= 5DGLCNt2rpp <= 1000.0: 1.0,
#  0 <= 5DGLCNt2rpp_reverse_32e75 <= 1000.0: 1.0,
#  0 <= 5DGLCNtex <= 1000.0: 1.0,
#  0 <= 5DGLCNtex_reverse_d721b <= 1000.0: 1.0,
#  0.0 <= 5DOAN <= 1000.0: 1.0,
#  0 <= 5DOAN_reverse_c8e7d <= 0: 1.0,
#  0 <= 5MTRtex <= 1000.0: 1.0,
#  0 <= 5MTRtex_reverse_79096 <= 1000.0: 1.0,
#  0.0 <= 5MTRtpp <= 1000.0: 1.0,
#  0 <= 5MTRtpp_reverse_d6113 <= 0: 1.0,
#  0 <= A5PISO <= 1000.0: 1.0,
#  0 <= A5PISO_reverse_3adc0 <= 1000.0: 1.0,
#  0.0 <= AACPS1 <= 1000.0: 1.0,
#  0 <= AACPS1_reverse_74228 <= 0: 1.0,
#  0.0 <= AACPS2 <= 1000.0: 1.0,
#  0 <= AACPS2_reverse_4df8a <= 0: 1.0,
#  0.0 <= AACPS3 <= 1000.0: 1.0,
#  0 <= AACPS3_reverse_de1e6 <= 0: 1.0,
#  0.0 <= AACPS4 <= 1000.0: 1.0,
#  0 <= AACPS4_reverse_2b927 <= 0: 1.0,
#  0.0 <= AACPS5 <= 1000.0: 1.0,
#  0 <= AACPS5_reverse_2077f <= 0: 1.0,
#  0.0 <= AACPS6 <= 1000.0: 1.0,
#  0 <= AACPS6_reverse_8fda3 <= 0: 1.0,
#  0.0 <= AACPS7 <= 1000.0: 1.0,
#  0 <= AACPS7_reverse_c7dd9 <= 0: 1.0,
#  0.0 <= AACPS8 <= 1000.0: 1.0,
#  0 <= AACPS8_reverse_375dc <= 0: 1.0,
#  0.0 <= AACPS9 <= 1000.0: 1.0,
#  0 <= AACPS9_reverse_c03ad <= 0: 1.0,
#  0.0 <= AACTOOR <= 1000.0: 1.0,
#  0 <= AACTOOR_reverse_e897c <= 0: 1.0,
#  0.0 <= AADDGT <= 1000.0: 1.0,
#  0 <= AADDGT_reverse_01165 <= 0: 1.0,
#  0.0 <= AAMYL <= 1000.0: 1.0,
#  0 <= AAMYL_reverse_58557 <= 0: 1.0,
#  0.0 <= AAMYLpp <= 1000.0: 1.0,
#  0 <= AAMYLpp_reverse_813aa <= 0: 1.0,
#  0.0 <= AB6PGH <= 1000.0: 1.0,
#  0 <= AB6PGH_reverse_9c1a3 <= 0: 1.0,
#  0.0 <= ABTA <= 1000.0: 1.0,
#  0 <= ABTA_reverse_48ba6 <= 0: 1.0,
#  0.0 <= ABUTD <= 1000.0: 1.0,
#  0 <= ABUTD_reverse_a69d2 <= 0: 1.0,
#  0.0 <= ABUTt2pp <= 1000.0: 1.0,
#  0 <= ABUTt2pp_reverse_b7c2d <= 0: 1.0,
#  0 <= ABUTtex <= 1000.0: 1.0,
#  0 <= ABUTtex_reverse_f1b1f <= 1000.0: 1.0,
#  0.0 <= ACACCT <= 1000.0: 1.0,
#  0 <= ACACCT_reverse_94e1e <= 0: 1.0,
#  0 <= ACACT1r <= 1000.0: 1.0,
#  0 <= ACACT1r_reverse_7e2ab <= 1000.0: 1.0,
#  0 <= ACACT2r <= 1000.0: 1.0,
#  0 <= ACACT2r_reverse_b794d <= 1000.0: 1.0,
#  0 <= ACACT3r <= 1000.0: 1.0,
#  0 <= ACACT3r_reverse_b8079 <= 1000.0: 1.0,
#  0 <= ACACT4r <= 1000.0: 1.0,
#  0 <= ACACT4r_reverse_36b94 <= 1000.0: 1.0,
#  0 <= ACACT5r <= 1000.0: 1.0,
#  0 <= ACACT5r_reverse_49fec <= 1000.0: 1.0,
#  0 <= ACACT6r <= 1000.0: 1.0,
#  0 <= ACACT6r_reverse_a3ce9 <= 1000.0: 1.0,
#  0 <= ACACT7r <= 1000.0: 1.0,
#  0 <= ACACT7r_reverse_b44b4 <= 1000.0: 1.0,
#  0 <= ACACT8r <= 1000.0: 1.0,
#  0 <= ACACT8r_reverse_54705 <= 1000.0: 1.0,
#  0 <= ACACt2pp <= 1000.0: 1.0,
#  0 <= ACACt2pp_reverse_06302 <= 1000.0: 1.0,
#  0 <= ACACtex <= 1000.0: 1.0,
#  0 <= ACACtex_reverse_cc949 <= 1000.0: 1.0,
#  0 <= ACALD <= 1000.0: 1.0,
#  0 <= ACALD_reverse_fda2b <= 1000.0: 1.0,
#  0 <= ACALDtex <= 1000.0: 1.0,
#  0 <= ACALDtex_reverse_75f7f <= 1000.0: 1.0,
#  0 <= ACALDtpp <= 1000.0: 1.0,
#  0 <= ACALDtpp_reverse_52ae6 <= 1000.0: 1.0,
#  0.0 <= ACANTHAT <= 1000.0: 1.0,
#  0 <= ACANTHAT_reverse_9fe7b <= 0: 1.0,
#  0.0 <= ACBIPGT <= 1000.0: 1.0,
#  0 <= ACBIPGT_reverse_bcc45 <= 0: 1.0,
#  0.0 <= ACCOAC <= 1000.0: 1.0,
#  0 <= ACCOAC_reverse_9d1cd <= 0: 1.0,
#  0.0 <= ACCOAL <= 1000.0: 1.0,
#  0 <= ACCOAL_reverse_ea444 <= 0: 1.0,
#  0.0 <= ACGAL1PPpp <= 1000.0: 1.0,
#  0 <= ACGAL1PPpp_reverse_88026 <= 0: 1.0,
#  ...}

# %%
for rxn in model.reactions:
    if rxn is expressed:
        expression_constraints[rxn] = {'expression': expression_change,
                                      'p_val' : expression_pval}
    else:
        expression_constraints[rxn] = {'expression': 1,
                                      'p_val' : 1}
        
for key,value in coef.items():
    print(key.name)
    print(value)
    minimize this: (1-log(expression_constraints[key.name][p_val]))*(abs(state- expression_constraints[key.name][expression]))
#     if key.name.startswith('DM_') or key.name.startswith('SK_'):
#             coef[key] = 1000.
# Out:
# DM_4CRSOL
# 1.0
# DM_4CRSOL_reverse_50477
# 1.0
# DM_5DRIB
# 1.0
# DM_5DRIB_reverse_0b428
# 1.0
# DM_AACALD
# 1.0
# DM_AACALD_reverse_73112
# 1.0
# DM_AMOB
# 1.0
# DM_AMOB_reverse_9e172
# 1.0
# DM_MTHTHF
# 1.0
# DM_MTHTHF_reverse_78338
# 1.0
# DM_OXAM
# 1.0
# DM_OXAM_reverse_7c3e7
# 1.0
# Ec_biomass_iJO1366_WT_53p95M
# 1.0
# Ec_biomass_iJO1366_WT_53p95M_reverse_55db7
# 1.0
# Ec_biomass_iJO1366_core_53p95M
# 1.0
# Ec_biomass_iJO1366_core_53p95M_reverse_e94eb
# 1.0
# EX_12ppd__R_e
# 1.0
# EX_12ppd__R_e_reverse_cb334
# 1.0
# EX_12ppd__S_e
# 1.0
# EX_12ppd__S_e_reverse_6f659
# 1.0
# EX_14glucan_e
# 1.0
# EX_14glucan_e_reverse_4b919
# 1.0
# EX_15dap_e
# 1.0
# EX_15dap_e_reverse_020d4
# 1.0
# EX_23camp_e
# 1.0
# EX_23camp_e_reverse_60590
# 1.0
# EX_23ccmp_e
# 1.0
# EX_23ccmp_e_reverse_3700b
# 1.0
# EX_23cgmp_e
# 1.0
# EX_23cgmp_e_reverse_48b5f
# 1.0
# EX_23cump_e
# 1.0
# EX_23cump_e_reverse_f767c
# 1.0
# EX_23dappa_e
# 1.0
# EX_23dappa_e_reverse_dfe54
# 1.0
# EX_26dap__M_e
# 1.0
# EX_26dap__M_e_reverse_a7bf0
# 1.0
# EX_2ddglcn_e
# 1.0
# EX_2ddglcn_e_reverse_e7cfb
# 1.0
# EX_34dhpac_e
# 1.0
# EX_34dhpac_e_reverse_01c3a
# 1.0
# EX_3amp_e
# 1.0
# EX_3amp_e_reverse_5699b
# 1.0
# EX_3cmp_e
# 1.0
# EX_3cmp_e_reverse_4c45a
# 1.0
# EX_3gmp_e
# 1.0
# EX_3gmp_e_reverse_00dd4
# 1.0
# EX_3hcinnm_e
# 1.0
# EX_3hcinnm_e_reverse_2f2b9
# 1.0
# EX_3hpp_e
# 1.0
# EX_3hpp_e_reverse_0d47d
# 1.0
# EX_3hpppn_e
# 1.0
# EX_3hpppn_e_reverse_d4e4c
# 1.0
# EX_3ump_e
# 1.0
# EX_3ump_e_reverse_f1b20
# 1.0
# EX_4abut_e
# 1.0
# EX_4abut_e_reverse_82295
# 1.0
# EX_4hoxpacd_e
# 1.0
# EX_4hoxpacd_e_reverse_7a05b
# 1.0
# EX_5dglcn_e
# 1.0
# EX_5dglcn_e_reverse_af9e8
# 1.0
# EX_5mtr_e
# 1.0
# EX_5mtr_e_reverse_0c671
# 1.0
# EX_LalaDglu_e
# 1.0
# EX_LalaDglu_e_reverse_e27e3
# 1.0
# EX_LalaDgluMdap_e
# 1.0
# EX_LalaDgluMdap_e_reverse_1661a
# 1.0
# EX_LalaDgluMdapDala_e
# 1.0
# EX_LalaDgluMdapDala_e_reverse_8fceb
# 1.0
# EX_LalaLglu_e
# 1.0
# EX_LalaLglu_e_reverse_d1493
# 1.0
# EX_ac_e
# 1.0
# EX_ac_e_reverse_0be96
# 1.0
# EX_acac_e
# 1.0
# EX_acac_e_reverse_c46d5
# 1.0
# EX_acald_e
# 1.0
# EX_acald_e_reverse_c096e
# 1.0
# EX_acgal_e
# 1.0
# EX_acgal_e_reverse_abd5a
# 1.0
# EX_acgal1p_e
# 1.0
# EX_acgal1p_e_reverse_bcbdf
# 1.0
# EX_acgam_e
# 1.0
# EX_acgam_e_reverse_da887
# 1.0
# EX_acgam1p_e
# 1.0
# EX_acgam1p_e_reverse_c1eb9
# 1.0
# EX_acmana_e
# 1.0
# EX_acmana_e_reverse_ae727
# 1.0
# EX_acmum_e
# 1.0
# EX_acmum_e_reverse_d42f2
# 1.0
# EX_acnam_e
# 1.0
# EX_acnam_e_reverse_7701a
# 1.0
# EX_acolipa_e
# 1.0
# EX_acolipa_e_reverse_df5a1
# 1.0
# EX_acser_e
# 1.0
# EX_acser_e_reverse_f0c22
# 1.0
# EX_ade_e
# 1.0
# EX_ade_e_reverse_ea308
# 1.0
# EX_adn_e
# 1.0
# EX_adn_e_reverse_dffe8
# 1.0
# EX_adocbl_e
# 1.0
# EX_adocbl_e_reverse_70f85
# 1.0
# EX_ag_e
# 1.0
# EX_ag_e_reverse_4d026
# 1.0
# EX_agm_e
# 1.0
# EX_agm_e_reverse_86b3b
# 1.0
# EX_akg_e
# 1.0
# EX_akg_e_reverse_70d85
# 1.0
# EX_ala__B_e
# 1.0
# EX_ala__B_e_reverse_1729c
# 1.0
# EX_ala__D_e
# 1.0
# EX_ala__D_e_reverse_15447
# 1.0
# EX_ala__L_e
# 1.0
# EX_ala__L_e_reverse_1eb4b
# 1.0
# EX_alaala_e
# 1.0
# EX_alaala_e_reverse_fad8b
# 1.0
# EX_all__D_e
# 1.0
# EX_all__D_e_reverse_3d5f1
# 1.0
# EX_alltn_e
# 1.0
# EX_alltn_e_reverse_6592a
# 1.0
# EX_amp_e
# 1.0
# EX_amp_e_reverse_ed5eb
# 1.0
# EX_anhgm_e
# 1.0
# EX_anhgm_e_reverse_87c70
# 1.0
# EX_arab__L_e
# 1.0
# EX_arab__L_e_reverse_d0f5e
# 1.0
# EX_arbt_e
# 1.0
# EX_arbt_e_reverse_87033
# 1.0
# EX_arbtn_e
# 1.0
# EX_arbtn_e_reverse_f3f32
# 1.0
# EX_arbtn__fe3_e
# 1.0
# EX_arbtn__fe3_e_reverse_dfaee
# 1.0
# EX_arg__L_e
# 1.0
# EX_arg__L_e_reverse_d8799
# 1.0
# EX_ascb__L_e
# 1.0
# EX_ascb__L_e_reverse_75b41
# 1.0
# EX_asn__L_e
# 1.0
# EX_asn__L_e_reverse_460df
# 1.0
# EX_aso3_e
# 1.0
# EX_aso3_e_reverse_32104
# 1.0
# EX_asp__L_e
# 1.0
# EX_asp__L_e_reverse_742f6
# 1.0
# EX_btn_e
# 1.0
# EX_btn_e_reverse_f2678
# 1.0
# EX_but_e
# 1.0
# EX_but_e_reverse_35eb9
# 1.0
# EX_butso3_e
# 1.0
# EX_butso3_e_reverse_31183
# 1.0
# EX_ca2_e
# 1.0
# EX_ca2_e_reverse_aac13
# 1.0
# EX_cbi_e
# 1.0
# EX_cbi_e_reverse_207cf
# 1.0
# EX_cbl1_e
# 1.0
# EX_cbl1_e_reverse_1093e
# 1.0
# EX_cd2_e
# 1.0
# EX_cd2_e_reverse_0e8ba
# 1.0
# EX_cgly_e
# 1.0
# EX_cgly_e_reverse_12551
# 1.0
# EX_chol_e
# 1.0
# EX_chol_e_reverse_b6b50
# 1.0
# EX_chtbs_e
# 1.0
# EX_chtbs_e_reverse_bbe59
# 1.0
# EX_cit_e
# 1.0
# EX_cit_e_reverse_0835e
# 1.0
# EX_cl_e
# 1.0
# EX_cl_e_reverse_2429b
# 1.0
# EX_cm_e
# 1.0
# EX_cm_e_reverse_d60e9
# 1.0
# EX_cmp_e
# 1.0
# EX_cmp_e_reverse_e7a73
# 1.0
# EX_co2_e
# 1.0
# EX_co2_e_reverse_d0466
# 1.0
# EX_cobalt2_e
# 1.0
# EX_cobalt2_e_reverse_2bf0e
# 1.0
# EX_colipa_e
# 1.0
# EX_colipa_e_reverse_f9125
# 1.0
# EX_colipap_e
# 1.0
# EX_colipap_e_reverse_c02be
# 1.0
# EX_cpgn_e
# 1.0
# EX_cpgn_e_reverse_a1559
# 1.0
# EX_cpgn__un_e
# 1.0
# EX_cpgn__un_e_reverse_a7fcb
# 1.0
# EX_crn_e
# 1.0
# EX_crn_e_reverse_a19eb
# 1.0
# EX_crn__D_e
# 1.0
# EX_crn__D_e_reverse_fbfeb
# 1.0
# EX_csn_e
# 1.0
# EX_csn_e_reverse_80cf5
# 1.0
# EX_cu_e
# 1.0
# EX_cu_e_reverse_829ec
# 1.0
# EX_cu2_e
# 1.0
# EX_cu2_e_reverse_02682
# 1.0
# EX_cyan_e
# 1.0
# EX_cyan_e_reverse_7cb7e
# 1.0
# EX_cynt_e
# 1.0
# EX_cynt_e_reverse_b53e8
# 1.0
# EX_cys__D_e
# 1.0
# EX_cys__D_e_reverse_fd0d3
# 1.0
# EX_cys__L_e
# 1.0
# EX_cys__L_e_reverse_41339
# 1.0
# EX_cytd_e
# 1.0
# EX_cytd_e_reverse_5950b
# 1.0
# EX_dad__2_e
# 1.0
# EX_dad__2_e_reverse_30ab9
# 1.0
# EX_damp_e
# 1.0
# EX_damp_e_reverse_2e1bd
# 1.0
# EX_dca_e
# 1.0
# EX_dca_e_reverse_4575c
# 1.0
# EX_dcmp_e
# 1.0
# EX_dcmp_e_reverse_83ed5
# 1.0
# EX_dcyt_e
# 1.0
# EX_dcyt_e_reverse_13102
# 1.0
# EX_ddca_e
# 1.0
# EX_ddca_e_reverse_6b9d2
# 1.0
# EX_dgmp_e
# 1.0
# EX_dgmp_e_reverse_88fd2
# 1.0
# EX_dgsn_e
# 1.0
# EX_dgsn_e_reverse_1b175
# 1.0
# EX_dha_e
# 1.0
# EX_dha_e_reverse_63f6d
# 1.0
# EX_dimp_e
# 1.0
# EX_dimp_e_reverse_7aa5e
# 1.0
# EX_din_e
# 1.0
# EX_din_e_reverse_f97eb
# 1.0
# EX_dms_e
# 1.0
# EX_dms_e_reverse_51567
# 1.0
# EX_dmso_e
# 1.0
# EX_dmso_e_reverse_f4576
# 1.0
# EX_dopa_e
# 1.0
# EX_dopa_e_reverse_71ff0
# 1.0
# EX_doxrbcn_e
# 1.0
# EX_doxrbcn_e_reverse_d7e41
# 1.0
# EX_dtmp_e
# 1.0
# EX_dtmp_e_reverse_7a713
# 1.0
# EX_dump_e
# 1.0
# EX_dump_e_reverse_2c836
# 1.0
# EX_duri_e
# 1.0
# EX_duri_e_reverse_d0523
# 1.0
# EX_eca4colipa_e
# 1.0
# EX_eca4colipa_e_reverse_579ab
# 1.0
# EX_enlipa_e
# 1.0
# EX_enlipa_e_reverse_2dd41
# 1.0
# EX_enter_e
# 1.0
# EX_enter_e_reverse_7bf45
# 1.0
# EX_etha_e
# 1.0
# EX_etha_e_reverse_a3984
# 1.0
# EX_ethso3_e
# 1.0
# EX_ethso3_e_reverse_d2ed7
# 1.0
# EX_etoh_e
# 1.0
# EX_etoh_e_reverse_cc64f
# 1.0
# EX_f6p_e
# 1.0
# EX_f6p_e_reverse_e362f
# 1.0
# EX_fald_e
# 1.0
# EX_fald_e_reverse_57d26
# 1.0
# EX_fe2_e
# 1.0
# EX_fe2_e_reverse_25e68
# 1.0
# EX_fe3_e
# 1.0
# EX_fe3_e_reverse_8b617
# 1.0
# EX_fe3dcit_e
# 1.0
# EX_fe3dcit_e_reverse_a5939
# 1.0
# EX_fe3dhbzs_e
# 1.0
# EX_fe3dhbzs_e_reverse_93deb
# 1.0
# EX_fe3hox_e
# 1.0
# EX_fe3hox_e_reverse_e323a
# 1.0
# EX_fe3hox__un_e
# 1.0
# EX_fe3hox__un_e_reverse_342fd
# 1.0
# EX_fecrm_e
# 1.0
# EX_fecrm_e_reverse_26983
# 1.0
# EX_fecrm__un_e
# 1.0
# EX_fecrm__un_e_reverse_a4187
# 1.0
# EX_feenter_e
# 1.0
# EX_feenter_e_reverse_73fde
# 1.0
# EX_feoxam_e
# 1.0
# EX_feoxam_e_reverse_97348
# 1.0
# EX_feoxam__un_e
# 1.0
# EX_feoxam__un_e_reverse_411be
# 1.0
# EX_for_e
# 1.0
# EX_for_e_reverse_23269
# 1.0
# EX_fru_e
# 1.0
# EX_fru_e_reverse_c3828
# 1.0
# EX_frulys_e
# 1.0
# EX_frulys_e_reverse_379f1
# 1.0
# EX_fruur_e
# 1.0
# EX_fruur_e_reverse_2763f
# 1.0
# EX_fuc__L_e
# 1.0
# EX_fuc__L_e_reverse_e70a8
# 1.0
# EX_fum_e
# 1.0
# EX_fum_e_reverse_e3432
# 1.0
# EX_fusa_e
# 1.0
# EX_fusa_e_reverse_bf5b5
# 1.0
# EX_g1p_e
# 1.0
# EX_g1p_e_reverse_350fc
# 1.0
# EX_g3pc_e
# 1.0
# EX_g3pc_e_reverse_ffe85
# 1.0
# EX_g3pe_e
# 1.0
# EX_g3pe_e_reverse_8f39b
# 1.0
# EX_g3pg_e
# 1.0
# EX_g3pg_e_reverse_5e370
# 1.0
# EX_g3pi_e
# 1.0
# EX_g3pi_e_reverse_f11b2
# 1.0
# EX_g3ps_e
# 1.0
# EX_g3ps_e_reverse_70d70
# 1.0
# EX_g6p_e
# 1.0
# EX_g6p_e_reverse_c15e5
# 1.0
# EX_gal_e
# 1.0
# EX_gal_e_reverse_d166c
# 1.0
# EX_gal__bD_e
# 1.0
# EX_gal__bD_e_reverse_6cde3
# 1.0
# EX_gal1p_e
# 1.0
# EX_gal1p_e_reverse_aab63
# 1.0
# EX_galct__D_e
# 1.0
# EX_galct__D_e_reverse_ff408
# 1.0
# EX_galctn__D_e
# 1.0
# EX_galctn__D_e_reverse_c58a3
# 1.0
# EX_galctn__L_e
# 1.0
# EX_galctn__L_e_reverse_998c0
# 1.0
# EX_galt_e
# 1.0
# EX_galt_e_reverse_4d1d0
# 1.0
# EX_galur_e
# 1.0
# EX_galur_e_reverse_f6a10
# 1.0
# EX_gam_e
# 1.0
# EX_gam_e_reverse_3d249
# 1.0
# EX_gam6p_e
# 1.0
# EX_gam6p_e_reverse_be0d8
# 1.0
# EX_gbbtn_e
# 1.0
# EX_gbbtn_e_reverse_767c1
# 1.0
# EX_gdp_e
# 1.0
# EX_gdp_e_reverse_950ab
# 1.0
# EX_glc_e
# 1.0
# EX_glc_e_reverse_6226d
# 1.0
# EX_glcn_e
# 1.0
# EX_glcn_e_reverse_9e36b
# 1.0
# EX_glcr_e
# 1.0
# EX_glcr_e_reverse_ea55f
# 1.0
# EX_glcur_e
# 1.0
# EX_glcur_e_reverse_0ab2d
# 1.0
# EX_glcur1p_e
# 1.0
# EX_glcur1p_e_reverse_7a2e5
# 1.0
# EX_gln__L_e
# 1.0
# EX_gln__L_e_reverse_6a1a1
# 1.0
# EX_glu__L_e
# 1.0
# EX_glu__L_e_reverse_42f6c
# 1.0
# EX_gly_e
# 1.0
# EX_gly_e_reverse_6956b
# 1.0
# EX_glyald_e
# 1.0
# EX_glyald_e_reverse_f761f
# 1.0
# EX_glyb_e
# 1.0
# EX_glyb_e_reverse_0bd65
# 1.0
# EX_glyc_e
# 1.0
# EX_glyc_e_reverse_c3ec2
# 1.0
# EX_glyc__R_e
# 1.0
# EX_glyc__R_e_reverse_91560
# 1.0
# EX_glyc2p_e
# 1.0
# EX_glyc2p_e_reverse_7a57e
# 1.0
# EX_glyc3p_e
# 1.0
# EX_glyc3p_e_reverse_74e5f
# 1.0
# EX_glyclt_e
# 1.0
# EX_glyclt_e_reverse_395e1
# 1.0
# EX_gmp_e
# 1.0
# EX_gmp_e_reverse_f6d0a
# 1.0
# EX_gsn_e
# 1.0
# EX_gsn_e_reverse_cb307
# 1.0
# EX_gthox_e
# 1.0
# EX_gthox_e_reverse_ca051
# 1.0
# EX_gthrd_e
# 1.0
# EX_gthrd_e_reverse_be1ab
# 1.0
# EX_gtp_e
# 1.0
# EX_gtp_e_reverse_9f3aa
# 1.0
# EX_gua_e
# 1.0
# EX_gua_e_reverse_11317
# 1.0
# EX_h_e
# 1.0
# EX_h_e_reverse_3e0c5
# 1.0
# EX_h2_e
# 1.0
# EX_h2_e_reverse_f55e9
# 1.0
# EX_h2o_e
# 1.0
# EX_h2o_e_reverse_3ced4
# 1.0
# EX_h2o2_e
# 1.0
# EX_h2o2_e_reverse_d52c5
# 1.0
# EX_h2s_e
# 1.0
# EX_h2s_e_reverse_c847c
# 1.0
# EX_hacolipa_e
# 1.0
# EX_hacolipa_e_reverse_4a785
# 1.0
# EX_halipa_e
# 1.0
# EX_halipa_e_reverse_f6505
# 1.0
# EX_hdca_e
# 1.0
# EX_hdca_e_reverse_9ab38
# 1.0
# EX_hdcea_e
# 1.0
# EX_hdcea_e_reverse_e9406
# 1.0
# EX_hg2_e
# 1.0
# EX_hg2_e_reverse_fc882
# 1.0
# EX_his__L_e
# 1.0
# EX_his__L_e_reverse_33439
# 1.0
# EX_hom__L_e
# 1.0
# EX_hom__L_e_reverse_3e4e5
# 1.0
# EX_hxa_e
# 1.0
# EX_hxa_e_reverse_e1287
# 1.0
# EX_hxan_e
# 1.0
# EX_hxan_e_reverse_90f99
# 1.0
# EX_idon__L_e
# 1.0
# EX_idon__L_e_reverse_54aa6
# 1.0
# EX_ile__L_e
# 1.0
# EX_ile__L_e_reverse_e862a
# 1.0
# EX_imp_e
# 1.0
# EX_imp_e_reverse_a877a
# 1.0
# EX_indole_e
# 1.0
# EX_indole_e_reverse_3cb9c
# 1.0
# EX_inost_e
# 1.0
# EX_inost_e_reverse_4d21d
# 1.0
# EX_ins_e
# 1.0
# EX_ins_e_reverse_989e1
# 1.0
# EX_isetac_e
# 1.0
# EX_isetac_e_reverse_62d58
# 1.0
# EX_k_e
# 1.0
# EX_k_e_reverse_42613
# 1.0
# EX_kdo2lipid4_e
# 1.0
# EX_kdo2lipid4_e_reverse_fb486
# 1.0
# EX_lac__D_e
# 1.0
# EX_lac__D_e_reverse_f95b4
# 1.0
# EX_lac__L_e
# 1.0
# EX_lac__L_e_reverse_8586b
# 1.0
# EX_lcts_e
# 1.0
# EX_lcts_e_reverse_13088
# 1.0
# EX_leu__L_e
# 1.0
# EX_leu__L_e_reverse_d40a5
# 1.0
# EX_lipa_e
# 1.0
# EX_lipa_e_reverse_1cc13
# 1.0
# EX_lipa_cold_e
# 1.0
# EX_lipa_cold_e_reverse_ce98e
# 1.0
# EX_lipoate_e
# 1.0
# EX_lipoate_e_reverse_4faad
# 1.0
# EX_lys__L_e
# 1.0
# EX_lys__L_e_reverse_4f08c
# 1.0
# EX_lyx__L_e
# 1.0
# EX_lyx__L_e_reverse_693d8
# 1.0
# EX_mal__D_e
# 1.0
# EX_mal__D_e_reverse_ce476
# 1.0
# EX_mal__L_e
# 1.0
# EX_mal__L_e_reverse_af154
# 1.0
# EX_malt_e
# 1.0
# EX_malt_e_reverse_ab2d1
# 1.0
# EX_malthx_e
# 1.0
# EX_malthx_e_reverse_73b54
# 1.0
# EX_maltpt_e
# 1.0
# EX_maltpt_e_reverse_f82d5
# 1.0
# EX_malttr_e
# 1.0
# EX_malttr_e_reverse_241c6
# 1.0
# EX_maltttr_e
# 1.0
# EX_maltttr_e_reverse_90d23
# 1.0
# EX_man_e
# 1.0
# EX_man_e_reverse_48020
# 1.0
# EX_man6p_e
# 1.0
# EX_man6p_e_reverse_b160c
# 1.0
# EX_manglyc_e
# 1.0
# EX_manglyc_e_reverse_51b57
# 1.0
# EX_melib_e
# 1.0
# EX_melib_e_reverse_68f2f
# 1.0
# EX_meoh_e
# 1.0
# EX_meoh_e_reverse_45228
# 1.0
# EX_met__D_e
# 1.0
# EX_met__D_e_reverse_6e944
# 1.0
# EX_met__L_e
# 1.0
# EX_met__L_e_reverse_14908
# 1.0
# EX_metsox__R__L_e
# 1.0
# EX_metsox__R__L_e_reverse_424e5
# 1.0
# EX_metsox__S__L_e
# 1.0
# EX_metsox__S__L_e_reverse_6a3fe
# 1.0
# EX_mg2_e
# 1.0
# EX_mg2_e_reverse_b1c98
# 1.0
# EX_mincyc_e
# 1.0
# EX_mincyc_e_reverse_10267
# 1.0
# EX_minohp_e
# 1.0
# EX_minohp_e_reverse_3ce45
# 1.0
# EX_mmet_e
# 1.0
# EX_mmet_e_reverse_b6b96
# 1.0
# EX_mn2_e
# 1.0
# EX_mn2_e_reverse_48316
# 1.0
# EX_mnl_e
# 1.0
# EX_mnl_e_reverse_c8f2a
# 1.0
# EX_mobd_e
# 1.0
# EX_mobd_e_reverse_c6396
# 1.0
# EX_mso3_e
# 1.0
# EX_mso3_e_reverse_b23ed
# 1.0
# EX_n2o_e
# 1.0
# EX_n2o_e_reverse_33405
# 1.0
# EX_na1_e
# 1.0
# EX_na1_e_reverse_c64df
# 1.0
# EX_nac_e
# 1.0
# EX_nac_e_reverse_23356
# 1.0
# EX_nh4_e
# 1.0
# EX_nh4_e_reverse_f9cc6
# 1.0
# EX_ni2_e
# 1.0
# EX_ni2_e_reverse_7ba33
# 1.0
# EX_nmn_e
# 1.0
# EX_nmn_e_reverse_59f7d
# 1.0
# EX_no_e
# 1.0
# EX_no_e_reverse_ffd01
# 1.0
# EX_no2_e
# 1.0
# EX_no2_e_reverse_1ddec
# 1.0
# EX_no3_e
# 1.0
# EX_no3_e_reverse_98d30
# 1.0
# EX_novbcn_e
# 1.0
# EX_novbcn_e_reverse_14cc2
# 1.0
# EX_o16a4colipa_e
# 1.0
# EX_o16a4colipa_e_reverse_48f50
# 1.0
# EX_o2_e
# 1.0
# EX_o2_e_reverse_efa94
# 1.0
# EX_o2s_e
# 1.0
# EX_o2s_e_reverse_82732
# 1.0
# EX_ocdca_e
# 1.0
# EX_ocdca_e_reverse_86d1d
# 1.0
# EX_ocdcea_e
# 1.0
# EX_ocdcea_e_reverse_5ebe2
# 1.0
# EX_octa_e
# 1.0
# EX_octa_e_reverse_38d1e
# 1.0
# EX_orn_e
# 1.0
# EX_orn_e_reverse_269bb
# 1.0
# EX_orot_e
# 1.0
# EX_orot_e_reverse_032e7
# 1.0
# EX_pacald_e
# 1.0
# EX_pacald_e_reverse_54b80
# 1.0
# EX_peamn_e
# 1.0
# EX_peamn_e_reverse_34c33
# 1.0
# EX_phe__L_e
# 1.0
# EX_phe__L_e_reverse_10066
# 1.0
# EX_pheme_e
# 1.0
# EX_pheme_e_reverse_8e123
# 1.0
# EX_pi_e
# 1.0
# EX_pi_e_reverse_1fb09
# 1.0
# EX_pnto__R_e
# 1.0
# EX_pnto__R_e_reverse_a498c
# 1.0
# EX_ppa_e
# 1.0
# EX_ppa_e_reverse_1faa3
# 1.0
# EX_ppal_e
# 1.0
# EX_ppal_e_reverse_bb983
# 1.0
# EX_pppn_e
# 1.0
# EX_pppn_e_reverse_4f187
# 1.0
# EX_ppt_e
# 1.0
# EX_ppt_e_reverse_b97a7
# 1.0
# EX_pro__L_e
# 1.0
# EX_pro__L_e_reverse_5f8c5
# 1.0
# EX_progly_e
# 1.0
# EX_progly_e_reverse_cccb4
# 1.0
# EX_psclys_e
# 1.0
# EX_psclys_e_reverse_4686a
# 1.0
# EX_pser__L_e
# 1.0
# EX_pser__L_e_reverse_164b6
# 1.0
# EX_ptrc_e
# 1.0
# EX_ptrc_e_reverse_6c850
# 1.0
# EX_pydam_e
# 1.0
# EX_pydam_e_reverse_b5003
# 1.0
# EX_pydx_e
# 1.0
# EX_pydx_e_reverse_9cc71
# 1.0
# EX_pydxn_e
# 1.0
# EX_pydxn_e_reverse_ce451
# 1.0
# EX_pyr_e
# 1.0
# EX_pyr_e_reverse_1f6de
# 1.0
# EX_quin_e
# 1.0
# EX_quin_e_reverse_45058
# 1.0
# EX_r5p_e
# 1.0
# EX_r5p_e_reverse_383fe
# 1.0
# EX_rfamp_e
# 1.0
# EX_rfamp_e_reverse_6d14f
# 1.0
# EX_rib__D_e
# 1.0
# EX_rib__D_e_reverse_4a19a
# 1.0
# EX_rmn_e
# 1.0
# EX_rmn_e_reverse_b3160
# 1.0
# EX_sbt__D_e
# 1.0
# EX_sbt__D_e_reverse_52f23
# 1.0
# EX_sel_e
# 1.0
# EX_sel_e_reverse_ffc35
# 1.0
# EX_ser__D_e
# 1.0
# EX_ser__D_e_reverse_99725
# 1.0
# EX_ser__L_e
# 1.0
# EX_ser__L_e_reverse_b0b37
# 1.0
# EX_skm_e
# 1.0
# EX_skm_e_reverse_ed122
# 1.0
# EX_slnt_e
# 1.0
# EX_slnt_e_reverse_97bba
# 1.0
# EX_so2_e
# 1.0
# EX_so2_e_reverse_de12f
# 1.0
# EX_so3_e
# 1.0
# EX_so3_e_reverse_116a1
# 1.0
# EX_so4_e
# 1.0
# EX_so4_e_reverse_5c8ed
# 1.0
# EX_spmd_e
# 1.0
# EX_spmd_e_reverse_761ad
# 1.0
# EX_succ_e
# 1.0
# EX_succ_e_reverse_a9039
# 1.0
# EX_sucr_e
# 1.0
# EX_sucr_e_reverse_0215c
# 1.0
# EX_sulfac_e
# 1.0
# EX_sulfac_e_reverse_2695d
# 1.0
# EX_tartr__D_e
# 1.0
# EX_tartr__D_e_reverse_93e71
# 1.0
# EX_tartr__L_e
# 1.0
# EX_tartr__L_e_reverse_6023a
# 1.0
# EX_taur_e
# 1.0
# EX_taur_e_reverse_69949
# 1.0
# EX_tcynt_e
# 1.0
# EX_tcynt_e_reverse_739e6
# 1.0
# EX_thm_e
# 1.0
# EX_thm_e_reverse_96547
# 1.0
# EX_thr__L_e
# 1.0
# EX_thr__L_e_reverse_ddaf9
# 1.0
# EX_thrp_e
# 1.0
# EX_thrp_e_reverse_51d63
# 1.0
# EX_thym_e
# 1.0
# EX_thym_e_reverse_84e99
# 1.0
# EX_thymd_e
# 1.0
# EX_thymd_e_reverse_94c6c
# 1.0
# EX_tma_e
# 1.0
# EX_tma_e_reverse_1429d
# 1.0
# EX_tmao_e
# 1.0
# EX_tmao_e_reverse_18ba4
# 1.0
# EX_tre_e
# 1.0
# EX_tre_e_reverse_fb5f1
# 1.0
# EX_trp__L_e
# 1.0
# EX_trp__L_e_reverse_d9983
# 1.0
# EX_tsul_e
# 1.0
# EX_tsul_e_reverse_22ca1
# 1.0
# EX_ttdca_e
# 1.0
# EX_ttdca_e_reverse_c67f4
# 1.0
# EX_ttdcea_e
# 1.0
# EX_ttdcea_e_reverse_e3700
# 1.0
# EX_ttrcyc_e
# 1.0
# EX_ttrcyc_e_reverse_0d8fb
# 1.0
# EX_tungs_e
# 1.0
# EX_tungs_e_reverse_6ffff
# 1.0
# EX_tym_e
# 1.0
# EX_tym_e_reverse_e1acb
# 1.0
# EX_tyr__L_e
# 1.0
# EX_tyr__L_e_reverse_516d2
# 1.0
# EX_tyrp_e
# 1.0
# EX_tyrp_e_reverse_36480
# 1.0
# EX_uacgam_e
# 1.0
# EX_uacgam_e_reverse_abfb0
# 1.0
# EX_udpacgal_e
# 1.0
# EX_udpacgal_e_reverse_a02b1
# 1.0
# EX_udpg_e
# 1.0
# EX_udpg_e_reverse_a3f02
# 1.0
# EX_udpgal_e
# 1.0
# EX_udpgal_e_reverse_9c019
# 1.0
# EX_udpglcur_e
# 1.0
# EX_udpglcur_e_reverse_baf0e
# 1.0
# EX_ump_e
# 1.0
# EX_ump_e_reverse_58471
# 1.0
# EX_ura_e
# 1.0
# EX_ura_e_reverse_98cbe
# 1.0
# EX_urea_e
# 1.0
# EX_urea_e_reverse_02f51
# 1.0
# EX_uri_e
# 1.0
# EX_uri_e_reverse_019f3
# 1.0
# EX_val__L_e
# 1.0
# EX_val__L_e_reverse_9e0f7
# 1.0
# EX_xan_e
# 1.0
# EX_xan_e_reverse_7bb40
# 1.0
# EX_xmp_e
# 1.0
# EX_xmp_e_reverse_5fd31
# 1.0
# EX_xtsn_e
# 1.0
# EX_xtsn_e_reverse_33417
# 1.0
# EX_xyl__D_e
# 1.0
# EX_xyl__D_e_reverse_e202a
# 1.0
# EX_xylu__L_e
# 1.0
# EX_xylu__L_e_reverse_a93ff
# 1.0
# EX_zn2_e
# 1.0
# EX_zn2_e_reverse_3c725
# 1.0
# 12DGR120tipp
# 1.0
# 12DGR120tipp_reverse_757ef
# 1.0
# 12DGR140tipp
# 1.0
# 12DGR140tipp_reverse_aea46
# 1.0
# 12DGR141tipp
# 1.0
# 12DGR141tipp_reverse_a0957
# 1.0
# 12DGR160tipp
# 1.0
# 12DGR160tipp_reverse_eac16
# 1.0
# 12DGR161tipp
# 1.0
# 12DGR161tipp_reverse_dcd80
# 1.0
# 12DGR180tipp
# 1.0
# 12DGR180tipp_reverse_7a012
# 1.0
# 12DGR181tipp
# 1.0
# 12DGR181tipp_reverse_34fd5
# 1.0
# 12PPDRtex
# 1.0
# 12PPDRtex_reverse_1d688
# 1.0
# 12PPDRtpp
# 1.0
# 12PPDRtpp_reverse_c5519
# 1.0
# 12PPDStex
# 1.0
# 12PPDStex_reverse_ec7d6
# 1.0
# 12PPDStpp
# 1.0
# 12PPDStpp_reverse_81431
# 1.0
# 14GLUCANabcpp
# 1.0
# 14GLUCANabcpp_reverse_c6351
# 1.0
# 14GLUCANtexi
# 1.0
# 14GLUCANtexi_reverse_2d4f8
# 1.0
# 23CAMPtex
# 1.0
# 23CAMPtex_reverse_1c6db
# 1.0
# 23CCMPtex
# 1.0
# 23CCMPtex_reverse_e7e14
# 1.0
# 23CGMPtex
# 1.0
# 23CGMPtex_reverse_d266a
# 1.0
# 23CUMPtex
# 1.0
# 23CUMPtex_reverse_7c421
# 1.0
# 23DAPPAt2pp
# 1.0
# 23DAPPAt2pp_reverse_59b55
# 1.0
# 23DAPPAtex
# 1.0
# 23DAPPAtex_reverse_0c987
# 1.0
# 23PDE2pp
# 1.0
# 23PDE2pp_reverse_9b346
# 1.0
# 23PDE4pp
# 1.0
# 23PDE4pp_reverse_2a6cf
# 1.0
# 23PDE7pp
# 1.0
# 23PDE7pp_reverse_3f150
# 1.0
# 23PDE9pp
# 1.0
# 23PDE9pp_reverse_84c1d
# 1.0
# 26DAHtex
# 1.0
# 26DAHtex_reverse_3953d
# 1.0
# 2AGPA120tipp
# 1.0
# 2AGPA120tipp_reverse_16d01
# 1.0
# 2AGPA140tipp
# 1.0
# 2AGPA140tipp_reverse_392f6
# 1.0
# 2AGPA141tipp
# 1.0
# 2AGPA141tipp_reverse_f9714
# 1.0
# 2AGPA160tipp
# 1.0
# 2AGPA160tipp_reverse_dc28a
# 1.0
# 2AGPA161tipp
# 1.0
# 2AGPA161tipp_reverse_fa4fb
# 1.0
# 2AGPA180tipp
# 1.0
# 2AGPA180tipp_reverse_b48ac
# 1.0
# 2AGPA181tipp
# 1.0
# 2AGPA181tipp_reverse_3605a
# 1.0
# 2AGPE120tipp
# 1.0
# 2AGPE120tipp_reverse_015fb
# 1.0
# 2AGPE140tipp
# 1.0
# 2AGPE140tipp_reverse_d6097
# 1.0
# 2AGPE141tipp
# 1.0
# 2AGPE141tipp_reverse_ae862
# 1.0
# 2AGPE160tipp
# 1.0
# 2AGPE160tipp_reverse_2f53f
# 1.0
# 2AGPE161tipp
# 1.0
# 2AGPE161tipp_reverse_39d2b
# 1.0
# 2AGPE180tipp
# 1.0
# 2AGPE180tipp_reverse_242d6
# 1.0
# 2AGPE181tipp
# 1.0
# 2AGPE181tipp_reverse_a5fc9
# 1.0
# 2AGPEAT120
# 1.0
# 2AGPEAT120_reverse_cbf7b
# 1.0
# 2AGPEAT140
# 1.0
# 2AGPEAT140_reverse_195ed
# 1.0
# 2AGPEAT141
# 1.0
# 2AGPEAT141_reverse_0e3c9
# 1.0
# 2AGPEAT160
# 1.0
# 2AGPEAT160_reverse_16239
# 1.0
# 2AGPEAT161
# 1.0
# 2AGPEAT161_reverse_5858e
# 1.0
# 2AGPEAT180
# 1.0
# 2AGPEAT180_reverse_47e42
# 1.0
# 2AGPEAT181
# 1.0
# 2AGPEAT181_reverse_450ec
# 1.0
# 2AGPG120tipp
# 1.0
# 2AGPG120tipp_reverse_16620
# 1.0
# 2AGPG140tipp
# 1.0
# 2AGPG140tipp_reverse_2834e
# 1.0
# 2AGPG141tipp
# 1.0
# 2AGPG141tipp_reverse_44e94
# 1.0
# 2AGPG160tipp
# 1.0
# 2AGPG160tipp_reverse_a1e99
# 1.0
# 2AGPG161tipp
# 1.0
# 2AGPG161tipp_reverse_4c821
# 1.0
# 2AGPG180tipp
# 1.0
# 2AGPG180tipp_reverse_148cb
# 1.0
# 2AGPG181tipp
# 1.0
# 2AGPG181tipp_reverse_7596e
# 1.0
# 2AGPGAT120
# 1.0
# 2AGPGAT120_reverse_83703
# 1.0
# 2AGPGAT140
# 1.0
# 2AGPGAT140_reverse_94092
# 1.0
# 2AGPGAT141
# 1.0
# 2AGPGAT141_reverse_82d91
# 1.0
# 2AGPGAT160
# 1.0
# 2AGPGAT160_reverse_2888d
# 1.0
# 2AGPGAT161
# 1.0
# 2AGPGAT161_reverse_529fb
# 1.0
# 2AGPGAT180
# 1.0
# 2AGPGAT180_reverse_9d3e5
# 1.0
# 2AGPGAT181
# 1.0
# 2AGPGAT181_reverse_802a9
# 1.0
# 2DGULRGx
# 1.0
# 2DGULRGx_reverse_a7f46
# 1.0
# 2DGULRGy
# 1.0
# 2DGULRGy_reverse_cbff4
# 1.0
# 2DGULRx
# 1.0
# 2DGULRx_reverse_d1a03
# 1.0
# 2DGULRy
# 1.0
# 2DGULRy_reverse_5d02d
# 1.0
# 2MAHMP
# 1.0
# 2MAHMP_reverse_e4fd2
# 1.0
# 34dhpactex
# 1.0
# 34dhpactex_reverse_51d40
# 1.0
# 3AMACHYD
# 1.0
# 3AMACHYD_reverse_1adff
# 1.0
# 3AMPtex
# 1.0
# 3AMPtex_reverse_62a3f
# 1.0
# 3CMPtex
# 1.0
# 3CMPtex_reverse_25d68
# 1.0
# 3GMPtex
# 1.0
# 3GMPtex_reverse_c1214
# 1.0
# 3HAD100
# 1.0
# 3HAD100_reverse_ca00f
# 1.0
# 3HAD120
# 1.0
# 3HAD120_reverse_82f09
# 1.0
# 3HAD121
# 1.0
# 3HAD121_reverse_7ae0d
# 1.0
# 3HAD140
# 1.0
# 3HAD140_reverse_13958
# 1.0
# 3HAD141
# 1.0
# 3HAD141_reverse_5738f
# 1.0
# 3HAD160
# 1.0
# 3HAD160_reverse_c0da0
# 1.0
# 3HAD161
# 1.0
# 3HAD161_reverse_384de
# 1.0
# 3HAD180
# 1.0
# 3HAD180_reverse_c801d
# 1.0
# 3HAD181
# 1.0
# 3HAD181_reverse_63f21
# 1.0
# 3HAD40
# 1.0
# 3HAD40_reverse_bc17f
# 1.0
# 3HAD60
# 1.0
# 3HAD60_reverse_d7fb5
# 1.0
# 3HAD80
# 1.0
# 3HAD80_reverse_29891
# 1.0
# 3HCINNMH
# 1.0
# 3HCINNMH_reverse_e3e52
# 1.0
# 3HPPPNH
# 1.0
# 3HPPPNH_reverse_b005a
# 1.0
# 3HPPtex
# 1.0
# 3HPPtex_reverse_49e02
# 1.0
# 3HPPtpp
# 1.0
# 3HPPtpp_reverse_f463c
# 1.0
# 3KGK
# 1.0
# 3KGK_reverse_d559b
# 1.0
# 3NTD2pp
# 1.0
# 3NTD2pp_reverse_6ebac
# 1.0
# 3NTD4pp
# 1.0
# 3NTD4pp_reverse_51bb5
# 1.0
# 3NTD7pp
# 1.0
# 3NTD7pp_reverse_9ab3e
# 1.0
# 3NTD9pp
# 1.0
# 3NTD9pp_reverse_6286c
# 1.0
# 3OAR100
# 1.0
# 3OAR100_reverse_d47e7
# 1.0
# 3OAR120
# 1.0
# 3OAR120_reverse_5a2b4
# 1.0
# 3OAR121
# 1.0
# 3OAR121_reverse_82b84
# 1.0
# 3OAR140
# 1.0
# 3OAR140_reverse_4eb2a
# 1.0
# 3OAR141
# 1.0
# 3OAR141_reverse_755ec
# 1.0
# 3OAR160
# 1.0
# 3OAR160_reverse_15066
# 1.0
# 3OAR161
# 1.0
# 3OAR161_reverse_fc9b4
# 1.0
# 3OAR180
# 1.0
# 3OAR180_reverse_e234c
# 1.0
# 3OAR181
# 1.0
# 3OAR181_reverse_f8559
# 1.0
# 3OAR40
# 1.0
# 3OAR40_reverse_e075e
# 1.0
# 3OAR60
# 1.0
# 3OAR60_reverse_40a5c
# 1.0
# 3OAR80
# 1.0
# 3OAR80_reverse_fe338
# 1.0
# 3OAS100
# 1.0
# 3OAS100_reverse_bfd7d
# 1.0
# 3OAS120
# 1.0
# 3OAS120_reverse_06658
# 1.0
# 3OAS121
# 1.0
# 3OAS121_reverse_e6125
# 1.0
# 3OAS140
# 1.0
# 3OAS140_reverse_65ddc
# 1.0
# 3OAS141
# 1.0
# 3OAS141_reverse_7f7b2
# 1.0
# 3OAS160
# 1.0
# 3OAS160_reverse_08317
# 1.0
# 3OAS161
# 1.0
# 3OAS161_reverse_ca056
# 1.0
# 3OAS180
# 1.0
# 3OAS180_reverse_3d9f8
# 1.0
# 3OAS181
# 1.0
# 3OAS181_reverse_2c21d
# 1.0
# 3OAS60
# 1.0
# 3OAS60_reverse_bff6a
# 1.0
# 3OAS80
# 1.0
# 3OAS80_reverse_c6446
# 1.0
# 3OXCOAT
# 1.0
# 3OXCOAT_reverse_2bb18
# 1.0
# 3PEPTabcpp
# 1.0
# 3PEPTabcpp_reverse_d34e9
# 1.0
# 3PEPTtex
# 1.0
# 3PEPTtex_reverse_45a83
# 1.0
# 3UMPtex
# 1.0
# 3UMPtex_reverse_c4def
# 1.0
# 42A12BOOXpp
# 1.0
# 42A12BOOXpp_reverse_a8a8a
# 1.0
# 4HOXPACDtex
# 1.0
# 4HOXPACDtex_reverse_3798d
# 1.0
# 4HTHRS
# 1.0
# 4HTHRS_reverse_6e403
# 1.0
# 4PCP
# 1.0
# 4PCP_reverse_c7c51
# 1.0
# 4PCPpp
# 1.0
# 4PCPpp_reverse_87e32
# 1.0
# 4PEPTabcpp
# 1.0
# 4PEPTabcpp_reverse_c63ab
# 1.0
# 4PEPTtex
# 1.0
# 4PEPTtex_reverse_025c0
# 1.0
# 5DGLCNR
# 1.0
# 5DGLCNR_reverse_fbc12
# 1.0
# 5DGLCNt2rpp
# 1.0
# 5DGLCNt2rpp_reverse_32e75
# 1.0
# 5DGLCNtex
# 1.0
# 5DGLCNtex_reverse_d721b
# 1.0
# 5DOAN
# 1.0
# 5DOAN_reverse_c8e7d
# 1.0
# 5MTRtex
# 1.0
# 5MTRtex_reverse_79096
# 1.0
# 5MTRtpp
# 1.0
# 5MTRtpp_reverse_d6113
# 1.0
# A5PISO
# 1.0
# A5PISO_reverse_3adc0
# 1.0
# AACPS1
# 1.0
# AACPS1_reverse_74228
# 1.0
# AACPS2
# 1.0
# AACPS2_reverse_4df8a
# 1.0
# AACPS3
# 1.0
# AACPS3_reverse_de1e6
# 1.0
# AACPS4
# 1.0
# AACPS4_reverse_2b927
# 1.0
# AACPS5
# 1.0
# AACPS5_reverse_2077f
# 1.0
# AACPS6
# 1.0
# AACPS6_reverse_8fda3
# 1.0
# AACPS7
# 1.0
# AACPS7_reverse_c7dd9
# 1.0
# AACPS8
# 1.0
# AACPS8_reverse_375dc
# 1.0
# AACPS9
# 1.0
# AACPS9_reverse_c03ad
# 1.0
# AACTOOR
# 1.0
# AACTOOR_reverse_e897c
# 1.0
# AADDGT
# 1.0
# AADDGT_reverse_01165
# 1.0
# AAMYL
# 1.0
# AAMYL_reverse_58557
# 1.0
# AAMYLpp
# 1.0
# AAMYLpp_reverse_813aa
# 1.0
# AB6PGH
# 1.0
# AB6PGH_reverse_9c1a3
# 1.0
# ABTA
# 1.0
# ABTA_reverse_48ba6
# 1.0
# ABUTD
# 1.0
# ABUTD_reverse_a69d2
# 1.0
# ABUTt2pp
# 1.0
# ABUTt2pp_reverse_b7c2d
# 1.0
# ABUTtex
# 1.0
# ABUTtex_reverse_f1b1f
# 1.0
# ACACCT
# 1.0
# ACACCT_reverse_94e1e
# 1.0
# ACACT1r
# 1.0
# ACACT1r_reverse_7e2ab
# 1.0
# ACACT2r
# 1.0
# ACACT2r_reverse_b794d
# 1.0
# ACACT3r
# 1.0
# ACACT3r_reverse_b8079
# 1.0
# ACACT4r
# 1.0
# ACACT4r_reverse_36b94
# 1.0
# ACACT5r
# 1.0
# ACACT5r_reverse_49fec
# 1.0
# ACACT6r
# 1.0
# ACACT6r_reverse_a3ce9
# 1.0
# ACACT7r
# 1.0
# ACACT7r_reverse_b44b4
# 1.0
# ACACT8r
# 1.0
# ACACT8r_reverse_54705
# 1.0
# ACACt2pp
# 1.0
# ACACt2pp_reverse_06302
# 1.0
# ACACtex
# 1.0
# ACACtex_reverse_cc949
# 1.0
# ACALD
# 1.0
# ACALD_reverse_fda2b
# 1.0
# ACALDtex
# 1.0
# ACALDtex_reverse_75f7f
# 1.0
# ACALDtpp
# 1.0
# ACALDtpp_reverse_52ae6
# 1.0
# ACANTHAT
# 1.0
# ACANTHAT_reverse_9fe7b
# 1.0
# ACBIPGT
# 1.0
# ACBIPGT_reverse_bcc45
# 1.0
# ACCOAC
# 1.0
# ACCOAC_reverse_9d1cd
# 1.0
# ACCOAL
# 1.0
# ACCOAL_reverse_ea444
# 1.0
# ACGAL1PPpp
# 1.0
# ACGAL1PPpp_reverse_88026
# 1.0
# ACGAL1Ptex
# 1.0
# ACGAL1Ptex_reverse_c2cd1
# 1.0
# ACGALtex
# 1.0
# ACGALtex_reverse_54263
# 1.0
# ACGAM1PPpp
# 1.0
# ACGAM1PPpp_reverse_fbc31
# 1.0
# ACGAM1Ptex
# 1.0
# ACGAM1Ptex_reverse_d95c0
# 1.0
# ACGAMK
# 1.0
# ACGAMK_reverse_1e7a8
# 1.0
# ACGAMT
# 1.0
# ACGAMT_reverse_2307a
# 1.0
# ACGAptspp
# 1.0
# ACGAptspp_reverse_e1a6e
# 1.0
# ACGAtex
# 1.0
# ACGAtex_reverse_5f438
# 1.0
# ACGK
# 1.0
# ACGK_reverse_684be
# 1.0
# ACGS
# 1.0
# ACGS_reverse_c8939
# 1.0
# ACHBS
# 1.0
# ACHBS_reverse_13e5f
# 1.0
# ACKr
# 1.0
# ACKr_reverse_b49c0
# 1.0
# ACLS
# 1.0
# ACLS_reverse_66503
# 1.0
# ACM6PH
# 1.0
# ACM6PH_reverse_cff51
# 1.0
# ACMAMUT
# 1.0
# ACMAMUT_reverse_cf71b
# 1.0
# ACMANAptspp
# 1.0
# ACMANAptspp_reverse_2111b
# 1.0
# ACMANAtex
# 1.0
# ACMANAtex_reverse_024da
# 1.0
# ACMUMptspp
# 1.0
# ACMUMptspp_reverse_a323d
# 1.0
# ACMUMtex
# 1.0
# ACMUMtex_reverse_17681
# 1.0
# ACNAMt2pp
# 1.0
# ACNAMt2pp_reverse_c08e0
# 1.0
# ACNAMtex
# 1.0
# ACNAMtex_reverse_b7b93
# 1.0
# ACNML
# 1.0
# ACNML_reverse_9634f
# 1.0
# ACOAD1f
# 1.0
# ACOAD1f_reverse_e656c
# 1.0
# ACOAD2f
# 1.0
# ACOAD2f_reverse_6e942
# 1.0
# ACOAD3f
# 1.0
# ACOAD3f_reverse_ba3fe
# 1.0
# ACOAD4f
# 1.0
# ACOAD4f_reverse_4d6cc
# 1.0
# ACOAD5f
# 1.0
# ACOAD5f_reverse_2359c
# 1.0
# ACOAD6f
# 1.0
# ACOAD6f_reverse_11aee
# 1.0
# ACOAD7f
# 1.0
# ACOAD7f_reverse_16a6a
# 1.0
# ACOAD8f
# 1.0
# ACOAD8f_reverse_fb781
# 1.0
# ACOATA
# 1.0
# ACOATA_reverse_8c02f
# 1.0
# ACODA
# 1.0
# ACODA_reverse_504cc
# 1.0
# ACOLIPAabctex
# 1.0
# ACOLIPAabctex_reverse_4e0f1
# 1.0
# ACONIs
# 1.0
# ACONIs_reverse_3e324
# 1.0
# ACONMT
# 1.0
# ACONMT_reverse_5a6e2
# 1.0
# ACONTa
# 1.0
# ACONTa_reverse_cad6d
# 1.0
# ACONTb
# 1.0
# ACONTb_reverse_e198a
# 1.0
# ACOTA
# 1.0
# ACOTA_reverse_c4379
# 1.0
# ACPPAT120
# 1.0
# ACPPAT120_reverse_b878c
# 1.0
# ACPPAT140
# 1.0
# ACPPAT140_reverse_24730
# 1.0
# ACPPAT141
# 1.0
# ACPPAT141_reverse_94594
# 1.0
# ACPPAT160
# 1.0
# ACPPAT160_reverse_620e6
# 1.0
# ACPPAT161
# 1.0
# ACPPAT161_reverse_0a33f
# 1.0
# ACPPAT180
# 1.0
# ACPPAT180_reverse_bf624
# 1.0
# ACPPAT181
# 1.0
# ACPPAT181_reverse_ac461
# 1.0
# ACPS1
# 1.0
# ACPS1_reverse_56be7
# 1.0
# ACS
# 1.0
# ACS_reverse_37635
# 1.0
# ACSERtex
# 1.0
# ACSERtex_reverse_d18a5
# 1.0
# ACSERtpp
# 1.0
# ACSERtpp_reverse_e0a16
# 1.0
# ACt2rpp
# 1.0
# ACt2rpp_reverse_213f1
# 1.0
# ACt4pp
# 1.0
# ACt4pp_reverse_a779a
# 1.0
# ACtex
# 1.0
# ACtex_reverse_c7bfd
# 1.0
# ADA
# 1.0
# ADA_reverse_347cb
# 1.0
# ADCL
# 1.0
# ADCL_reverse_0051f
# 1.0
# ADCS
# 1.0
# ADCS_reverse_5303c
# 1.0
# ADD
# 1.0
# ADD_reverse_9eeb5
# 1.0
# ADEt2rpp
# 1.0
# ADEt2rpp_reverse_6f767
# 1.0
# ADEtex
# 1.0
# ADEtex_reverse_56687
# 1.0
# ADK1
# 1.0
# ADK1_reverse_a6f90
# 1.0
# ADK3
# 1.0
# ADK3_reverse_6b5fb
# 1.0
# ADK4
# 1.0
# ADK4_reverse_dfbdf
# 1.0
# ADMDC
# 1.0
# ADMDC_reverse_e2782
# 1.0
# ADNCYC
# 1.0
# ADNCYC_reverse_013dc
# 1.0
# ADNK1
# 1.0
# ADNK1_reverse_fe466
# 1.0
# ADNUC
# 1.0
# ADNUC_reverse_7ef46
# 1.0
# ADNt2pp
# 1.0
# ADNt2pp_reverse_375d7
# 1.0
# ADNt2rpp
# 1.0
# ADNt2rpp_reverse_0f138
# 1.0
# ADNtex
# 1.0
# ADNtex_reverse_43080
# 1.0
# ADOCBIK
# 1.0
# ADOCBIK_reverse_50143
# 1.0
# ADOCBLS
# 1.0
# ADOCBLS_reverse_005a5
# 1.0
# ADOCBLabcpp
# 1.0
# ADOCBLabcpp_reverse_68dcd
# 1.0
# ADOCBLtonex
# 1.0
# ADOCBLtonex_reverse_baebb
# 1.0
# ADPRDP
# 1.0
# ADPRDP_reverse_6f5d7
# 1.0
# ADPT
# 1.0
# ADPT_reverse_567cf
# 1.0
# ADSK
# 1.0
# ADSK_reverse_6806d
# 1.0
# ADSL1r
# 1.0
# ADSL1r_reverse_2ae14
# 1.0
# ADSL2r
# 1.0
# ADSL2r_reverse_42348
# 1.0
# ADSS
# 1.0
# ADSS_reverse_c75bb
# 1.0
# AGDC
# 1.0
# AGDC_reverse_2ab9d
# 1.0
# AGM3PA
# 1.0
# AGM3PA_reverse_07960
# 1.0
# AGM3PApp
# 1.0
# AGM3PApp_reverse_74a9d
# 1.0
# AGM3PH
# 1.0
# AGM3PH_reverse_3acde
# 1.0
# AGM3Pt2pp
# 1.0
# AGM3Pt2pp_reverse_5e873
# 1.0
# AGM4PA
# 1.0
# AGM4PA_reverse_cc387
# 1.0
# AGM4PApp
# 1.0
# AGM4PApp_reverse_5ec54
# 1.0
# AGM4PCP
# 1.0
# AGM4PCP_reverse_4f872
# 1.0
# AGM4PCPpp
# 1.0
# AGM4PCPpp_reverse_26bad
# 1.0
# AGM4PH
# 1.0
# AGM4PH_reverse_b09ff
# 1.0
# AGM4Pt2pp
# 1.0
# AGM4Pt2pp_reverse_58aad
# 1.0
# AGMH
# 1.0
# AGMH_reverse_d371c
# 1.0
# AGMHE
# 1.0
# AGMHE_reverse_dfad6
# 1.0
# AGMT
# 1.0
# AGMT_reverse_1c107
# 1.0
# AGMt2pp
# 1.0
# AGMt2pp_reverse_23bf9
# 1.0
# AGMtex
# 1.0
# AGMtex_reverse_969a4
# 1.0
# AGPAT120
# 1.0
# AGPAT120_reverse_7811c
# 1.0
# AGPAT140
# 1.0
# AGPAT140_reverse_73ea4
# 1.0
# AGPAT141
# 1.0
# AGPAT141_reverse_fd2b9
# 1.0
# AGPAT160
# 1.0
# AGPAT160_reverse_22d12
# 1.0
# AGPAT161
# 1.0
# AGPAT161_reverse_debc5
# 1.0
# AGPAT180
# 1.0
# AGPAT180_reverse_57c04
# 1.0
# AGPAT181
# 1.0
# AGPAT181_reverse_93f51
# 1.0
# AGPR
# 1.0
# AGPR_reverse_5dce4
# 1.0
# AGt3
# 1.0
# AGt3_reverse_00449
# 1.0
# AHCYSNS
# 1.0
# AHCYSNS_reverse_38446
# 1.0
# AICART
# 1.0
# AICART_reverse_b7b59
# 1.0
# AIRC2
# 1.0
# AIRC2_reverse_50d74
# 1.0
# AIRC3
# 1.0
# AIRC3_reverse_f015f
# 1.0
# AKGDH
# 1.0
# AKGDH_reverse_08bdc
# 1.0
# AKGt2rpp
# 1.0
# AKGt2rpp_reverse_9046e
# 1.0
# AKGtex
# 1.0
# AKGtex_reverse_06c87
# 1.0
# ALAALAD
# 1.0
# ALAALAD_reverse_ddcdd
# 1.0
# ALAALAabcpp
# 1.0
# ALAALAabcpp_reverse_75b27
# 1.0
# ALAALAr
# 1.0
# ALAALAr_reverse_18faa
# 1.0
# ALAALAtex
# 1.0
# ALAALAtex_reverse_2ebb9
# 1.0
# ALAGLUE
# 1.0
# ALAGLUE_reverse_83285
# 1.0
# ALAR
# 1.0
# ALAR_reverse_77133
# 1.0
# ALATA_D2
# 1.0
# ALATA_D2_reverse_13566
# 1.0
# ALATA_L
# 1.0
# ALATA_L_reverse_e54ff
# 1.0
# ALATA_L2
# 1.0
# ALATA_L2_reverse_ef76c
# 1.0
# ALATRS
# 1.0
# ALATRS_reverse_de5e9
# 1.0
# ALAabcpp
# 1.0
# ALAabcpp_reverse_90425
# 1.0
# ALAt2pp
# 1.0
# ALAt2pp_reverse_49759
# 1.0
# ALAt2rpp
# 1.0
# ALAt2rpp_reverse_b7b30
# 1.0
# ALAt4pp
# 1.0
# ALAt4pp_reverse_d9615
# 1.0
# ALAtex
# 1.0
# ALAtex_reverse_33163
# 1.0
# ALCD19
# 1.0
# ALCD19_reverse_d90b5
# 1.0
# ALCD2x
# 1.0
# ALCD2x_reverse_5d107
# 1.0
# ALDD19xr
# 1.0
# ALDD19xr_reverse_1b96d
# 1.0
# ALDD2x
# 1.0
# ALDD2x_reverse_90781
# 1.0
# ALDD2y
# 1.0
# ALDD2y_reverse_03afb
# 1.0
# ALDD3y
# 1.0
# ALDD3y_reverse_27133
# 1.0
# ALDD4
# 1.0
# ALDD4_reverse_3aaf5
# 1.0
# ALLK
# 1.0
# ALLK_reverse_42c6c
# 1.0
# ALLPI
# 1.0
# ALLPI_reverse_0c720
# 1.0
# ALLTAMH
# 1.0
# ALLTAMH_reverse_4519b
# 1.0
# ALLTN
# 1.0
# ALLTN_reverse_d7d9e
# 1.0
# ALLTNt2rpp
# 1.0
# ALLTNt2rpp_reverse_62e9a
# 1.0
# ALLTNtex
# 1.0
# ALLTNtex_reverse_f7ace
# 1.0
# ALLULPE
# 1.0
# ALLULPE_reverse_f154c
# 1.0
# ALLabcpp
# 1.0
# ALLabcpp_reverse_fd443
# 1.0
# ALLtex
# 1.0
# ALLtex_reverse_73b82
# 1.0
# ALPATE160pp
# 1.0
# ALPATE160pp_reverse_39e01
# 1.0
# ALPATG160pp
# 1.0
# ALPATG160pp_reverse_f7766
# 1.0
# ALR2
# 1.0
# ALR2_reverse_10b0a
# 1.0
# ALR4x
# 1.0
# ALR4x_reverse_17ebf
# 1.0
# ALTRH
# 1.0
# ALTRH_reverse_fca7e
# 1.0
# AM3PA
# 1.0
# AM3PA_reverse_086bd
# 1.0
# AM4PA
# 1.0
# AM4PA_reverse_b660b
# 1.0
# AM4PCP
# 1.0
# AM4PCP_reverse_9f67b
# 1.0
# AMALT1
# 1.0
# AMALT1_reverse_f685c
# 1.0
# AMALT2
# 1.0
# AMALT2_reverse_20c24
# 1.0
# AMALT3
# 1.0
# AMALT3_reverse_f2bc2
# 1.0
# AMALT4
# 1.0
# AMALT4_reverse_934fc
# 1.0
# AMANAPEr
# 1.0
# AMANAPEr_reverse_8310c
# 1.0
# AMANK
# 1.0
# AMANK_reverse_8ea5e
# 1.0
# AMAOTr
# 1.0
# AMAOTr_reverse_a5426
# 1.0
# AMMQLT8
# 1.0
# AMMQLT8_reverse_6da73
# 1.0
# AMPMS2
# 1.0
# AMPMS2_reverse_56a45
# 1.0
# AMPN
# 1.0
# AMPN_reverse_1b917
# 1.0
# AMPTASECG
# 1.0
# AMPTASECG_reverse_11d5d
# 1.0
# AMPTASEPG
# 1.0
# AMPTASEPG_reverse_1fe90
# 1.0
# AMPtex
# 1.0
# AMPtex_reverse_bec2c
# 1.0
# ANHGMtex
# 1.0
# ANHGMtex_reverse_89969
# 1.0
# ANHMK
# 1.0
# ANHMK_reverse_f8dfd
# 1.0
# ANPRT
# 1.0
# ANPRT_reverse_e2684
# 1.0
# ANS
# 1.0
# ANS_reverse_4e062
# 1.0
# AOBUTDs
# 1.0
# AOBUTDs_reverse_2ac3d
# 1.0
# AOXSr2
# 1.0
# AOXSr2_reverse_0c982
# 1.0
# AP4AH
# 1.0
# AP4AH_reverse_ccff7
# 1.0
# AP4AS
# 1.0
# AP4AS_reverse_5ff3e
# 1.0
# AP5AH
# 1.0
# AP5AH_reverse_ec0fb
# 1.0
# APCS
# 1.0
# APCS_reverse_d7e40
# 1.0
# APG3PAT120
# 1.0
# APG3PAT120_reverse_36529
# 1.0
# APG3PAT140
# 1.0
# APG3PAT140_reverse_0280f
# 1.0
# APG3PAT141
# 1.0
# APG3PAT141_reverse_f3ee9
# 1.0
# APG3PAT160
# 1.0
# APG3PAT160_reverse_19c9f
# 1.0
# APG3PAT161
# 1.0
# APG3PAT161_reverse_a7b12
# 1.0
# APG3PAT180
# 1.0
# APG3PAT180_reverse_279d3
# 1.0
# APG3PAT181
# 1.0
# APG3PAT181_reverse_ba91b
# 1.0
# APH120
# 1.0
# APH120_reverse_0e75d
# 1.0
# APH140
# 1.0
# APH140_reverse_fdf10
# 1.0
# APH141
# 1.0
# APH141_reverse_10b9f
# 1.0
# APH160
# 1.0
# APH160_reverse_868b2
# 1.0
# APH161
# 1.0
# APH161_reverse_38db8
# 1.0
# APH180
# 1.0
# APH180_reverse_00cc5
# 1.0
# APH181
# 1.0
# APH181_reverse_b327d
# 1.0
# APPLDHr
# 1.0
# APPLDHr_reverse_3ac58
# 1.0
# APRAUR
# 1.0
# APRAUR_reverse_e674d
# 1.0
# ARAI
# 1.0
# ARAI_reverse_f1762
# 1.0
# ARBTNR1
# 1.0
# ARBTNR1_reverse_05ba1
# 1.0
# ARBTNR2
# 1.0
# ARBTNR2_reverse_68a05
# 1.0
# ARBTNR3
# 1.0
# ARBTNR3_reverse_e8402
# 1.0
# ARBTNabcpp
# 1.0
# ARBTNabcpp_reverse_a90a7
# 1.0
# ARBTNexs
# 1.0
# ARBTNexs_reverse_da1bb
# 1.0
# ARBTNtex
# 1.0
# ARBTNtex_reverse_98dad
# 1.0
# ARBTNtonex
# 1.0
# ARBTNtonex_reverse_292f7
# 1.0
# ARBTNtpp
# 1.0
# ARBTNtpp_reverse_6a35a
# 1.0
# ARBTptspp
# 1.0
# ARBTptspp_reverse_7fd6c
# 1.0
# ARBTtex
# 1.0
# ARBTtex_reverse_6822c
# 1.0
# ARBabcpp
# 1.0
# ARBabcpp_reverse_ae03e
# 1.0
# ARBt2rpp
# 1.0
# ARBt2rpp_reverse_7d924
# 1.0
# ARBt3ipp
# 1.0
# ARBt3ipp_reverse_7c622
# 1.0
# ARBtex
# 1.0
# ARBtex_reverse_2c0f8
# 1.0
# ARGAGMt7pp
# 1.0
# ARGAGMt7pp_reverse_135dc
# 1.0
# ARGDC
# 1.0
# ARGDC_reverse_08faf
# 1.0
# ARGDCpp
# 1.0
# ARGDCpp_reverse_54b23
# 1.0
# ARGORNt7pp
# 1.0
# ARGORNt7pp_reverse_eabec
# 1.0
# ARGSL
# 1.0
# ARGSL_reverse_1b949
# 1.0
# ARGSS
# 1.0
# ARGSS_reverse_5760d
# 1.0
# ARGTRS
# 1.0
# ARGTRS_reverse_1ecbf
# 1.0
# ARGabcpp
# 1.0
# ARGabcpp_reverse_2f37a
# 1.0
# ARGt3pp
# 1.0
# ARGt3pp_reverse_a8971
# 1.0
# ARGtex
# 1.0
# ARGtex_reverse_244d5
# 1.0
# ASAD
# 1.0
# ASAD_reverse_39a64
# 1.0
# ASCBPL
# 1.0
# ASCBPL_reverse_f9eb9
# 1.0
# ASCBptspp
# 1.0
# ASCBptspp_reverse_99732
# 1.0
# ASCBtex
# 1.0
# ASCBtex_reverse_b49d4
# 1.0
# ASNN
# 1.0
# ASNN_reverse_515f8
# 1.0
# ASNNpp
# 1.0
# ASNNpp_reverse_dd54e
# 1.0
# ASNS1
# 1.0
# ASNS1_reverse_90309
# 1.0
# ASNS2
# 1.0
# ASNS2_reverse_85dd4
# 1.0
# ASNTRS
# 1.0
# ASNTRS_reverse_ee3aa
# 1.0
# ASNabcpp
# 1.0
# ASNabcpp_reverse_47353
# 1.0
# ASNt2rpp
# 1.0
# ASNt2rpp_reverse_144ff
# 1.0
# ASNtex
# 1.0
# ASNtex_reverse_e8ab8
# 1.0
# ASO3t8pp
# 1.0
# ASO3t8pp_reverse_9efd4
# 1.0
# ASO3tex
# 1.0
# ASO3tex_reverse_eeec8
# 1.0
# ASP1DC
# 1.0
# ASP1DC_reverse_5dad1
# 1.0
# ASPCT
# 1.0
# ASPCT_reverse_c18b9
# 1.0
# ASPK
# 1.0
# ASPK_reverse_115d7
# 1.0
# ASPO3
# 1.0
# ASPO3_reverse_594c1
# 1.0
# ASPO4
# 1.0
# ASPO4_reverse_aacc5
# 1.0
# ASPO5
# 1.0
# ASPO5_reverse_4d759
# 1.0
# ASPO6
# 1.0
# ASPO6_reverse_ec15c
# 1.0
# ASPT
# 1.0
# ASPT_reverse_c6d74
# 1.0
# ASPTA
# 1.0
# ASPTA_reverse_36525
# 1.0
# ASPTRS
# 1.0
# ASPTRS_reverse_8f6e6
# 1.0
# ASPabcpp
# 1.0
# ASPabcpp_reverse_faa73
# 1.0
# ASPt2_2pp
# 1.0
# ASPt2_2pp_reverse_990a0
# 1.0
# ASPt2_3pp
# 1.0
# ASPt2_3pp_reverse_e453b
# 1.0
# ASPt2pp
# 1.0
# ASPt2pp_reverse_54f4e
# 1.0
# ASPt2rpp
# 1.0
# ASPt2rpp_reverse_3e243
# 1.0
# ASPtex
# 1.0
# ASPtex_reverse_35e4c
# 1.0
# ASR
# 1.0
# ASR_reverse_1a3cf
# 1.0
# AST
# 1.0
# AST_reverse_c77bb
# 1.0
# ATHRDHr
# 1.0
# ATHRDHr_reverse_f7ea2
# 1.0
# ATPHs
# 1.0
# ATPHs_reverse_ad499
# 1.0
# ATPM
# 1.0
# ATPM_reverse_5b752
# 1.0
# ATPPRT
# 1.0
# ATPPRT_reverse_00060
# 1.0
# ATPS4rpp
# 1.0
# ATPS4rpp_reverse_18786
# 1.0
# BALAt2pp
# 1.0
# BALAt2pp_reverse_e7f95
# 1.0
# BALAtex
# 1.0
# BALAtex_reverse_10000
# 1.0
# BETALDHx
# 1.0
# BETALDHx_reverse_30760
# 1.0
# BETALDHy
# 1.0
# BETALDHy_reverse_a4dbc
# 1.0
# BMOCOS
# 1.0
# BMOCOS_reverse_a8c6b
# 1.0
# BMOGDS1
# 1.0
# BMOGDS1_reverse_83047
# 1.0
# BMOGDS2
# 1.0
# BMOGDS2_reverse_1d2b7
# 1.0
# BPNT
# 1.0
# BPNT_reverse_53108
# 1.0
# BSORx
# 1.0
# BSORx_reverse_2339f
# 1.0
# BSORy
# 1.0
# BSORy_reverse_89c33
# 1.0
# BTNt2ipp
# 1.0
# BTNt2ipp_reverse_72ae5
# 1.0
# BTNtex
# 1.0
# BTNtex_reverse_cd491
# 1.0
# BTS5
# 1.0
# BTS5_reverse_459c1
# 1.0
# BUTCT
# 1.0
# BUTCT_reverse_64a8b
# 1.0
# BUTSO3abcpp
# 1.0
# BUTSO3abcpp_reverse_6dd1b
# 1.0
# BUTSO3tex
# 1.0
# BUTSO3tex_reverse_90916
# 1.0
# BUTt2rpp
# 1.0
# BUTt2rpp_reverse_571fb
# 1.0
# BUTtex
# 1.0
# BUTtex_reverse_59ad6
# 1.0
# BWCOGDS1
# 1.0
# BWCOGDS1_reverse_0fca6
# 1.0
# BWCOGDS2
# 1.0
# BWCOGDS2_reverse_e74c3
# 1.0
# BWCOS
# 1.0
# BWCOS_reverse_cdbae
# 1.0
# CA2t3pp
# 1.0
# CA2t3pp_reverse_0a9ad
# 1.0
# CA2tex
# 1.0
# CA2tex_reverse_27b69
# 1.0
# CADVtpp
# 1.0
# CADVtpp_reverse_9e7cc
# 1.0
# CAT
# 1.0
# CAT_reverse_c01ae
# 1.0
# CAt6pp
# 1.0
# CAt6pp_reverse_e05ae
# 1.0
# CBIAT
# 1.0
# CBIAT_reverse_1e649
# 1.0
# CBItonex
# 1.0
# CBItonex_reverse_bb4e5
# 1.0
# CBIuabcpp
# 1.0
# CBIuabcpp_reverse_ea68b
# 1.0
# CBL1abcpp
# 1.0
# CBL1abcpp_reverse_18983
# 1.0
# CBL1tonex
# 1.0
# CBL1tonex_reverse_0c490
# 1.0
# CBLAT
# 1.0
# CBLAT_reverse_0bf85
# 1.0
# CBMD
# 1.0
# CBMD_reverse_4f3e7
# 1.0
# CBMKr
# 1.0
# CBMKr_reverse_fe98a
# 1.0
# CBPS
# 1.0
# CBPS_reverse_80907
# 1.0
# CCGS
# 1.0
# CCGS_reverse_3ff79
# 1.0
# CD2abcpp
# 1.0
# CD2abcpp_reverse_d0330
# 1.0
# CD2t3pp
# 1.0
# CD2t3pp_reverse_47616
# 1.0
# CD2tex
# 1.0
# CD2tex_reverse_400a6
# 1.0
# CD2tpp
# 1.0
# CD2tpp_reverse_04be1
# 1.0
# CDAPPA120
# 1.0
# CDAPPA120_reverse_bf679
# 1.0
# CDAPPA140
# 1.0
# CDAPPA140_reverse_00a04
# 1.0
# CDAPPA141
# 1.0
# CDAPPA141_reverse_9da9e
# 1.0
# CDAPPA160
# 1.0
# CDAPPA160_reverse_e2daf
# 1.0
# CDAPPA161
# 1.0
# CDAPPA161_reverse_1276c
# 1.0
# CDAPPA180
# 1.0
# CDAPPA180_reverse_9cd52
# 1.0
# CDAPPA181
# 1.0
# CDAPPA181_reverse_c0aa5
# 1.0
# CDGR
# 1.0
# CDGR_reverse_e4464
# 1.0
# CDGS
# 1.0
# CDGS_reverse_6b7cb
# 1.0
# CDPMEK
# 1.0
# CDPMEK_reverse_01872
# 1.0
# CFAS160E
# 1.0
# CFAS160E_reverse_d8e06
# 1.0
# CFAS160G
# 1.0
# CFAS160G_reverse_ce748
# 1.0
# CFAS180E
# 1.0
# CFAS180E_reverse_6ab2c
# 1.0
# CFAS180G
# 1.0
# CFAS180G_reverse_ab16a
# 1.0
# CGLYabcpp
# 1.0
# CGLYabcpp_reverse_8e5ba
# 1.0
# CGLYtex
# 1.0
# CGLYtex_reverse_c0fb9
# 1.0
# CHLabcpp
# 1.0
# CHLabcpp_reverse_37887
# 1.0
# CHLt2pp
# 1.0
# CHLt2pp_reverse_5e5a5
# 1.0
# CHLtex
# 1.0
# CHLtex_reverse_36af5
# 1.0
# CHOLD
# 1.0
# CHOLD_reverse_a176e
# 1.0
# CHORM
# 1.0
# CHORM_reverse_38aac
# 1.0
# CHORS
# 1.0
# CHORS_reverse_17772
# 1.0
# CHRPL
# 1.0
# CHRPL_reverse_46f50
# 1.0
# CHTBSptspp
# 1.0
# CHTBSptspp_reverse_c1fa2
# 1.0
# CHTBStex
# 1.0
# CHTBStex_reverse_76a7e
# 1.0
# CINNDO
# 1.0
# CINNDO_reverse_2153f
# 1.0
# CITL
# 1.0
# CITL_reverse_4d27f
# 1.0
# CITt3pp
# 1.0
# CITt3pp_reverse_08444
# 1.0
# CITt7pp
# 1.0
# CITt7pp_reverse_75ac8
# 1.0
# CITtex
# 1.0
# CITtex_reverse_2ae27
# 1.0
# CLIPAabctex
# 1.0
# CLIPAabctex_reverse_fd06a
# 1.0
# CLPNH120pp
# 1.0
# CLPNH120pp_reverse_463b7
# 1.0
# CLPNH140pp
# 1.0
# CLPNH140pp_reverse_200c3
# 1.0
# CLPNH141pp
# 1.0
# CLPNH141pp_reverse_c8b31
# 1.0
# CLPNH160pp
# 1.0
# CLPNH160pp_reverse_5a184
# 1.0
# CLPNH161pp
# 1.0
# CLPNH161pp_reverse_9f3a8
# 1.0
# CLPNH180pp
# 1.0
# CLPNH180pp_reverse_14f2a
# 1.0
# CLPNH181pp
# 1.0
# CLPNH181pp_reverse_bcc62
# 1.0
# CLPNS120pp
# 1.0
# CLPNS120pp_reverse_0e640
# 1.0
# CLPNS140pp
# 1.0
# CLPNS140pp_reverse_3811c
# 1.0
# CLPNS141pp
# 1.0
# CLPNS141pp_reverse_2eb8f
# 1.0
# CLPNS160pp
# 1.0
# CLPNS160pp_reverse_2d06f
# 1.0
# CLPNS161pp
# 1.0
# CLPNS161pp_reverse_9806d
# 1.0
# CLPNS180pp
# 1.0
# CLPNS180pp_reverse_937c0
# 1.0
# CLPNS181pp
# 1.0
# CLPNS181pp_reverse_92c7e
# 1.0
# CLt3_2pp
# 1.0
# CLt3_2pp_reverse_e5246
# 1.0
# CLtex
# 1.0
# CLtex_reverse_f6cf5
# 1.0
# CMPN
# 1.0
# CMPN_reverse_7ba04
# 1.0
# CMPtex
# 1.0
# CMPtex_reverse_9db58
# 1.0
# CMtex
# 1.0
# CMtex_reverse_de1ce
# 1.0
# CMtpp
# 1.0
# CMtpp_reverse_be4c6
# 1.0
# CO2tex
# 1.0
# CO2tex_reverse_3d081
# 1.0
# CO2tpp
# 1.0
# CO2tpp_reverse_d9a27
# 1.0
# COBALT2abcpp
# 1.0
# COBALT2abcpp_reverse_76f3d
# 1.0
# COBALT2t3pp
# 1.0
# COBALT2t3pp_reverse_70d7a
# 1.0
# COBALT2tex
# 1.0
# COBALT2tex_reverse_0862d
# 1.0
# COBALT2tpp
# 1.0
# COBALT2tpp_reverse_077ed
# 1.0
# COLIPAKpp
# 1.0
# COLIPAKpp_reverse_a30f0
# 1.0
# COLIPAPabctex
# 1.0
# COLIPAPabctex_reverse_e5b51
# 1.0
# COLIPAabcpp
# 1.0
# COLIPAabcpp_reverse_3d3cf
# 1.0
# COLIPAabctex
# 1.0
# COLIPAabctex_reverse_39037
# 1.0
# CPGNR1
# 1.0
# CPGNR1_reverse_e1a22
# 1.0
# CPGNR2
# 1.0
# CPGNR2_reverse_276e7
# 1.0
# CPGNR3
# 1.0
# CPGNR3_reverse_c6b90
# 1.0
# CPGNUtex
# 1.0
# CPGNUtex_reverse_66ff6
# 1.0
# CPGNUtpp
# 1.0
# CPGNUtpp_reverse_30f4e
# 1.0
# CPGNabcpp
# 1.0
# CPGNabcpp_reverse_958fe
# 1.0
# CPGNexs
# 1.0
# CPGNexs_reverse_93618
# 1.0
# CPGNtonex
# 1.0
# CPGNtonex_reverse_06ef2
# 1.0
# CPH4S
# 1.0
# CPH4S_reverse_542c3
# 1.0
# CPMPS
# 1.0
# CPMPS_reverse_2260b
# 1.0
# CPPPGO
# 1.0
# CPPPGO_reverse_f858f
# 1.0
# CPPPGO2
# 1.0
# CPPPGO2_reverse_e5000
# 1.0
# CRNBTCT
# 1.0
# CRNBTCT_reverse_0fcbb
# 1.0
# CRNCAL2
# 1.0
# CRNCAL2_reverse_800b4
# 1.0
# CRNCAR
# 1.0
# CRNCAR_reverse_9f0cd
# 1.0
# CRNCBCT
# 1.0
# CRNCBCT_reverse_c4ebb
# 1.0
# CRNCDH
# 1.0
# CRNCDH_reverse_9743e
# 1.0
# CRNDCAL2
# 1.0
# CRNDCAL2_reverse_2dbe0
# 1.0
# CRNDabcpp
# 1.0
# CRNDabcpp_reverse_eaa22
# 1.0
# CRNDt2rpp
# 1.0
# CRNDt2rpp_reverse_03da9
# 1.0
# CRNDtex
# 1.0
# CRNDtex_reverse_29215
# 1.0
# CRNabcpp
# 1.0
# CRNabcpp_reverse_603cb
# 1.0
# CRNt2rpp
# 1.0
# CRNt2rpp_reverse_c7737
# 1.0
# CRNt7pp
# 1.0
# CRNt7pp_reverse_71e7f
# 1.0
# CRNt8pp
# 1.0
# CRNt8pp_reverse_0e546
# 1.0
# CRNtex
# 1.0
# CRNtex_reverse_34fd9
# 1.0
# CS
# 1.0
# CS_reverse_8d7e9
# 1.0
# CSND
# 1.0
# CSND_reverse_77bd2
# 1.0
# CSNt2pp
# 1.0
# CSNt2pp_reverse_0d959
# 1.0
# CSNtex
# 1.0
# CSNtex_reverse_be886
# 1.0
# CTBTCAL2
# 1.0
# CTBTCAL2_reverse_21850
# 1.0
# CTBTabcpp
# 1.0
# CTBTabcpp_reverse_299d5
# 1.0
# CTBTt2rpp
# 1.0
# CTBTt2rpp_reverse_d330c
# 1.0
# CTECOAI6
# 1.0
# CTECOAI6_reverse_de0db
# 1.0
# CTECOAI7
# 1.0
# CTECOAI7_reverse_745a0
# 1.0
# CTECOAI8
# 1.0
# CTECOAI8_reverse_0323d
# 1.0
# CTPS2
# 1.0
# CTPS2_reverse_9c0ad
# 1.0
# CU1Opp
# 1.0
# CU1Opp_reverse_50676
# 1.0
# CU1abcpp
# 1.0
# CU1abcpp_reverse_83c5f
# 1.0
# CU2abcpp
# 1.0
# CU2abcpp_reverse_245f3
# 1.0
# CU2tex
# 1.0
# CU2tex_reverse_521e6
# 1.0
# CU2tpp
# 1.0
# CU2tpp_reverse_630ab
# 1.0
# CUt3
# 1.0
# CUt3_reverse_036c0
# 1.0
# CUtex
# 1.0
# CUtex_reverse_6d61f
# 1.0
# CYANST
# 1.0
# CYANST_reverse_46415
# 1.0
# CYANSTpp
# 1.0
# CYANSTpp_reverse_8b1ae
# 1.0
# CYANtex
# 1.0
# CYANtex_reverse_b6a36
# 1.0
# CYNTAH
# 1.0
# CYNTAH_reverse_ca69d
# 1.0
# CYNTt2pp
# 1.0
# CYNTt2pp_reverse_28968
# 1.0
# CYNTtex
# 1.0
# CYNTtex_reverse_8c4ef
# 1.0
# CYSDDS
# 1.0
# CYSDDS_reverse_f19f8
# 1.0
# CYSDS
# 1.0
# CYSDS_reverse_c49c8
# 1.0
# CYSDabcpp
# 1.0
# CYSDabcpp_reverse_07068
# 1.0
# CYSDtex
# 1.0
# CYSDtex_reverse_184ff
# 1.0
# CYSS
# 1.0
# CYSS_reverse_62727
# 1.0
# CYSSADS
# 1.0
# CYSSADS_reverse_c8340
# 1.0
# CYSTL
# 1.0
# CYSTL_reverse_b8b9a
# 1.0
# CYSTRS
# 1.0
# CYSTRS_reverse_08992
# 1.0
# CYSabc2pp
# 1.0
# CYSabc2pp_reverse_285bf
# 1.0
# CYSabcpp
# 1.0
# CYSabcpp_reverse_5f06e
# 1.0
# CYStex
# 1.0
# CYStex_reverse_00cf0
# 1.0
# CYStpp
# 1.0
# CYStpp_reverse_22bd9
# 1.0
# CYTBD2pp
# 1.0
# CYTBD2pp_reverse_d2eae
# 1.0
# CYTBDpp
# 1.0
# CYTBDpp_reverse_79f50
# 1.0
# CYTBO3_4pp
# 1.0
# CYTBO3_4pp_reverse_4d2e1
# 1.0
# CYTD
# 1.0
# CYTD_reverse_256d9
# 1.0
# CYTDH
# 1.0
# CYTDH_reverse_bf08d
# 1.0
# CYTDK2
# 1.0
# CYTDK2_reverse_fd949
# 1.0
# CYTDt2pp
# 1.0
# CYTDt2pp_reverse_8b36d
# 1.0
# CYTDt2rpp
# 1.0
# CYTDt2rpp_reverse_bd96e
# 1.0
# CYTDtex
# 1.0
# CYTDtex_reverse_b7852
# 1.0
# CYTK1
# 1.0
# CYTK1_reverse_2fa21
# 1.0
# CYTK2
# 1.0
# CYTK2_reverse_bee82
# 1.0
# D__LACt2pp
# 1.0
# D__LACt2pp_reverse_7dc4a
# 1.0
# D__LACtex
# 1.0
# D__LACtex_reverse_f6e2a
# 1.0
# DAAD
# 1.0
# DAAD_reverse_c84a4
# 1.0
# DADA
# 1.0
# DADA_reverse_ead02
# 1.0
# DADK
# 1.0
# DADK_reverse_006ea
# 1.0
# DADNt2pp
# 1.0
# DADNt2pp_reverse_fd695
# 1.0
# DADNtex
# 1.0
# DADNtex_reverse_d7a49
# 1.0
# DAGK120
# 1.0
# DAGK120_reverse_7cd00
# 1.0
# DAGK140
# 1.0
# DAGK140_reverse_87f8f
# 1.0
# DAGK141
# 1.0
# DAGK141_reverse_f6e5f
# 1.0
# DAGK160
# 1.0
# DAGK160_reverse_0238d
# 1.0
# DAGK161
# 1.0
# DAGK161_reverse_9bfe7
# 1.0
# DAGK180
# 1.0
# DAGK180_reverse_eb3e3
# 1.0
# DAGK181
# 1.0
# DAGK181_reverse_8c0c8
# 1.0
# DALAt2pp
# 1.0
# DALAt2pp_reverse_2e5f8
# 1.0
# DALAtex
# 1.0
# DALAtex_reverse_8fc1b
# 1.0
# DAMPtex
# 1.0
# DAMPtex_reverse_8dfbc
# 1.0
# DAPAL
# 1.0
# DAPAL_reverse_14901
# 1.0
# DAPDC
# 1.0
# DAPDC_reverse_d3ab8
# 1.0
# DAPE
# 1.0
# DAPE_reverse_e08be
# 1.0
# DAPabcpp
# 1.0
# DAPabcpp_reverse_bfa35
# 1.0
# DAPtex
# 1.0
# DAPtex_reverse_c7721
# 1.0
# DASYN120
# 1.0
# DASYN120_reverse_769b1
# 1.0
# DASYN140
# 1.0
# DASYN140_reverse_791b2
# 1.0
# DASYN141
# 1.0
# DASYN141_reverse_0654c
# 1.0
# DASYN160
# 1.0
# DASYN160_reverse_c2bf4
# 1.0
# DASYN161
# 1.0
# DASYN161_reverse_08434
# 1.0
# DASYN180
# 1.0
# DASYN180_reverse_75973
# 1.0
# DASYN181
# 1.0
# DASYN181_reverse_ebb48
# 1.0
# DATPHs
# 1.0
# DATPHs_reverse_3fb29
# 1.0
# DB4PS
# 1.0
# DB4PS_reverse_43dd1
# 1.0
# DBTS
# 1.0
# DBTS_reverse_b5da6
# 1.0
# DC6PH
# 1.0
# DC6PH_reverse_72b16
# 1.0
# DCAtex
# 1.0
# DCAtex_reverse_5237b
# 1.0
# DCMPtex
# 1.0
# DCMPtex_reverse_6a30a
# 1.0
# DCTPD
# 1.0
# DCTPD_reverse_a48d6
# 1.0
# DCYTD
# 1.0
# DCYTD_reverse_27b45
# 1.0
# DCYTt2pp
# 1.0
# DCYTt2pp_reverse_cbb22
# 1.0
# DCYTtex
# 1.0
# DCYTtex_reverse_cc4b9
# 1.0
# DDCAtexi
# 1.0
# DDCAtexi_reverse_ea0a7
# 1.0
# DDGALK
# 1.0
# DDGALK_reverse_ee6c3
# 1.0
# DDGLCNt2rpp
# 1.0
# DDGLCNt2rpp_reverse_1bf30
# 1.0
# DDGLCNtex
# 1.0
# DDGLCNtex_reverse_cb7f7
# 1.0
# DDGLK
# 1.0
# DDGLK_reverse_9d6e1
# 1.0
# DDPA
# 1.0
# DDPA_reverse_575e8
# 1.0
# DDPGALA
# 1.0
# DDPGALA_reverse_4e5af
# 1.0
# DGK1
# 1.0
# DGK1_reverse_3266e
# 1.0
# DGMPtex
# 1.0
# DGMPtex_reverse_f8176
# 1.0
# DGSNt2pp
# 1.0
# DGSNt2pp_reverse_085fe
# 1.0
# DGSNtex
# 1.0
# DGSNtex_reverse_d8452
# 1.0
# DHACOAH
# 1.0
# DHACOAH_reverse_1376f
# 1.0
# DHAD1
# 1.0
# DHAD1_reverse_39dca
# 1.0
# DHAD2
# 1.0
# DHAD2_reverse_755c6
# 1.0
# DHAPT
# 1.0
# DHAPT_reverse_62f68
# 1.0
# DHAtex
# 1.0
# DHAtex_reverse_b3ad5
# 1.0
# DHAtpp
# 1.0
# DHAtpp_reverse_cfe59
# 1.0
# DHBD
# 1.0
# DHBD_reverse_07e1f
# 1.0
# DHBS
# 1.0
# DHBS_reverse_e570e
# 1.0
# DHBSH
# 1.0
# DHBSH_reverse_e4369
# 1.0
# DHCIND
# 1.0
# DHCIND_reverse_1bec4
# 1.0
# DHCINDO
# 1.0
# DHCINDO_reverse_12b57
# 1.0
# DHDPRy
# 1.0
# DHDPRy_reverse_8346a
# 1.0
# DHDPS
# 1.0
# DHDPS_reverse_e10c0
# 1.0
# DHFR
# 1.0
# DHFR_reverse_65c32
# 1.0
# DHFS
# 1.0
# DHFS_reverse_f7920
# 1.0
# DHMPTR
# 1.0
# DHMPTR_reverse_90b26
# 1.0
# DHNAOT4
# 1.0
# DHNAOT4_reverse_16f9d
# 1.0
# DHNCOAS
# 1.0
# DHNCOAS_reverse_af3a9
# 1.0
# DHNCOAT
# 1.0
# DHNCOAT_reverse_58c26
# 1.0
# DHNPA2r
# 1.0
# DHNPA2r_reverse_475b3
# 1.0
# DHNPTE
# 1.0
# DHNPTE_reverse_0732e
# 1.0
# DHORD2
# 1.0
# DHORD2_reverse_22a13
# 1.0
# DHORD5
# 1.0
# DHORD5_reverse_e7a65
# 1.0
# DHORDfum
# 1.0
# DHORDfum_reverse_d4b11
# 1.0
# DHORTS
# 1.0
# DHORTS_reverse_82d73
# 1.0
# DHPPD
# 1.0
# DHPPD_reverse_f0de8
# 1.0
# DHPPDA2
# 1.0
# DHPPDA2_reverse_9e131
# 1.0
# DHPS2
# 1.0
# DHPS2_reverse_8974a
# 1.0
# DHPTDCs2
# 1.0
# DHPTDCs2_reverse_26a0a
# 1.0
# DHPTDNR
# 1.0
# DHPTDNR_reverse_d97d7
# 1.0
# DHPTDNRN
# 1.0
# DHPTDNRN_reverse_a94c7
# 1.0
# DHPTPE
# 1.0
# DHPTPE_reverse_dd6d2
# 1.0
# DHQS
# 1.0
# DHQS_reverse_3d16b
# 1.0
# DHQTi
# 1.0
# DHQTi_reverse_c4498
# 1.0
# DIMPtex
# 1.0
# DIMPtex_reverse_2bafb
# 1.0
# DINSt2pp
# 1.0
# DINSt2pp_reverse_da91c
# 1.0
# DINStex
# 1.0
# DINStex_reverse_e04be
# 1.0
# DKGLCNR1
# 1.0
# DKGLCNR1_reverse_5f829
# 1.0
# DKGLCNR2x
# 1.0
# DKGLCNR2x_reverse_1e5cd
# 1.0
# DKGLCNR2y
# 1.0
# DKGLCNR2y_reverse_33a59
# 1.0
# DMATT
# 1.0
# DMATT_reverse_3a731
# 1.0
# DMPPS
# 1.0
# DMPPS_reverse_c6082
# 1.0
# DMQMT
# 1.0
# DMQMT_reverse_2490b
# 1.0
# DMSOR1
# 1.0
# DMSOR1_reverse_470fa
# 1.0
# DMSOR1pp
# 1.0
# DMSOR1pp_reverse_8bb05
# 1.0
# DMSOR2
# 1.0
# DMSOR2_reverse_001f6
# 1.0
# DMSOR2pp
# 1.0
# DMSOR2pp_reverse_b876b
# 1.0
# DMSOtex
# 1.0
# DMSOtex_reverse_aff1c
# 1.0
# DMSOtpp
# 1.0
# DMSOtpp_reverse_eddb5
# 1.0
# DMStex
# 1.0
# DMStex_reverse_100fa
# 1.0
# DNMPPA
# 1.0
# DNMPPA_reverse_131b7
# 1.0
# DNTPPA
# 1.0
# DNTPPA_reverse_7e624
# 1.0
# DOGULNR
# 1.0
# DOGULNR_reverse_c4196
# 1.0
# DOPAtex
# 1.0
# DOPAtex_reverse_b578f
# 1.0
# DOXRBCNtex
# 1.0
# DOXRBCNtex_reverse_5ba24
# 1.0
# DOXRBCNtpp
# 1.0
# DOXRBCNtpp_reverse_88f4a
# 1.0
# DPCOAK
# 1.0
# DPCOAK_reverse_56ab9
# 1.0
# DPR
# 1.0
# DPR_reverse_691d8
# 1.0
# DRPA
# 1.0
# DRPA_reverse_66bfb
# 1.0
# DSBAO1
# 1.0
# DSBAO1_reverse_9c7d6
# 1.0
# DSBAO2
# 1.0
# DSBAO2_reverse_f2c04
# 1.0
# DSBCGT
# 1.0
# DSBCGT_reverse_58858
# 1.0
# DSBDR
# 1.0
# DSBDR_reverse_7e26e
# 1.0
# DSBGGT
# 1.0
# DSBGGT_reverse_f8e4c
# 1.0
# DSERDHr
# 1.0
# DSERDHr_reverse_c44ee
# 1.0
# DSERt2pp
# 1.0
# DSERt2pp_reverse_d3685
# 1.0
# DSERtex
# 1.0
# DSERtex_reverse_5ab31
# 1.0
# DTARTD
# 1.0
# DTARTD_reverse_0d68b
# 1.0
# DTMPK
# 1.0
# DTMPK_reverse_44d5a
# 1.0
# DTMPtex
# 1.0
# DTMPtex_reverse_581e0
# 1.0
# DUMPtex
# 1.0
# DUMPtex_reverse_a35ee
# 1.0
# DURADx
# 1.0
# DURADx_reverse_224c5
# 1.0
# DURIK1
# 1.0
# DURIK1_reverse_f4aee
# 1.0
# DURIPP
# 1.0
# DURIPP_reverse_e8f8a
# 1.0
# DURIt2pp
# 1.0
# DURIt2pp_reverse_a9066
# 1.0
# DURItex
# 1.0
# DURItex_reverse_bdbc1
# 1.0
# DUTPDP
# 1.0
# DUTPDP_reverse_1eccd
# 1.0
# DXPRIi
# 1.0
# DXPRIi_reverse_85956
# 1.0
# DXPS
# 1.0
# DXPS_reverse_86aca
# 1.0
# DXYLK
# 1.0
# DXYLK_reverse_fb109
# 1.0
# E4PD
# 1.0
# E4PD_reverse_babdb
# 1.0
# EAR100x
# 1.0
# EAR100x_reverse_d973f
# 1.0
# EAR100y
# 1.0
# EAR100y_reverse_863b6
# 1.0
# EAR120x
# 1.0
# EAR120x_reverse_72a18
# 1.0
# EAR120y
# 1.0
# EAR120y_reverse_c7353
# 1.0
# EAR121x
# 1.0
# EAR121x_reverse_d2e6c
# 1.0
# EAR121y
# 1.0
# EAR121y_reverse_9014d
# 1.0
# EAR140x
# 1.0
# EAR140x_reverse_01529
# 1.0
# EAR140y
# 1.0
# EAR140y_reverse_dff77
# 1.0
# EAR141x
# 1.0
# EAR141x_reverse_3a0ef
# 1.0
# EAR141y
# 1.0
# EAR141y_reverse_496a8
# 1.0
# EAR160x
# 1.0
# EAR160x_reverse_07017
# 1.0
# EAR160y
# 1.0
# EAR160y_reverse_e0622
# 1.0
# EAR161x
# 1.0
# EAR161x_reverse_4d0d0
# 1.0
# EAR161y
# 1.0
# EAR161y_reverse_fb8a8
# 1.0
# EAR180x
# 1.0
# EAR180x_reverse_fbf60
# 1.0
# EAR180y
# 1.0
# EAR180y_reverse_2cedd
# 1.0
# EAR181x
# 1.0
# EAR181x_reverse_3d2a4
# 1.0
# EAR181y
# 1.0
# EAR181y_reverse_6d40a
# 1.0
# EAR40x
# 1.0
# EAR40x_reverse_ebbbc
# 1.0
# EAR40y
# 1.0
# EAR40y_reverse_0f912
# 1.0
# EAR60x
# 1.0
# EAR60x_reverse_9e2fc
# 1.0
# EAR60y
# 1.0
# EAR60y_reverse_02e5e
# 1.0
# EAR80x
# 1.0
# EAR80x_reverse_1065c
# 1.0
# EAR80y
# 1.0
# EAR80y_reverse_2df0a
# 1.0
# ECA4COLIPAabctex
# 1.0
# ECA4COLIPAabctex_reverse_20e46
# 1.0
# ECA4OALpp
# 1.0
# ECA4OALpp_reverse_71af3
# 1.0
# ECAP1pp
# 1.0
# ECAP1pp_reverse_74a2b
# 1.0
# ECAP2pp
# 1.0
# ECAP2pp_reverse_3b2a7
# 1.0
# ECAP3pp
# 1.0
# ECAP3pp_reverse_83672
# 1.0
# ECAtpp
# 1.0
# ECAtpp_reverse_3630a
# 1.0
# ECOAH1
# 1.0
# ECOAH1_reverse_6e99c
# 1.0
# ECOAH2
# 1.0
# ECOAH2_reverse_fa31c
# 1.0
# ECOAH3
# 1.0
# ECOAH3_reverse_fede1
# 1.0
# ECOAH4
# 1.0
# ECOAH4_reverse_b3830
# 1.0
# ECOAH5
# 1.0
# ECOAH5_reverse_0cdd7
# 1.0
# ECOAH6
# 1.0
# ECOAH6_reverse_9bf56
# 1.0
# ECOAH7
# 1.0
# ECOAH7_reverse_b3898
# 1.0
# ECOAH8
# 1.0
# ECOAH8_reverse_19c39
# 1.0
# EDA
# 1.0
# EDA_reverse_81f1b
# 1.0
# EDD
# 1.0
# EDD_reverse_007a2
# 1.0
# EDTXS1
# 1.0
# EDTXS1_reverse_2f111
# 1.0
# EDTXS2
# 1.0
# EDTXS2_reverse_119c0
# 1.0
# EDTXS3
# 1.0
# EDTXS3_reverse_998ec
# 1.0
# EDTXS4
# 1.0
# EDTXS4_reverse_86896
# 1.0
# EGMEACPR
# 1.0
# EGMEACPR_reverse_1b486
# 1.0
# ENLIPAabctex
# 1.0
# ENLIPAabctex_reverse_31d4e
# 1.0
# ENO
# 1.0
# ENO_reverse_40eea
# 1.0
# ENTCS
# 1.0
# ENTCS_reverse_2c03a
# 1.0
# ENTERES
# 1.0
# ENTERES_reverse_43d02
# 1.0
# ENTERES2
# 1.0
# ENTERES2_reverse_17eef
# 1.0
# EPMEACPR
# 1.0
# EPMEACPR_reverse_794bd
# 1.0
# ETHAAL
# 1.0
# ETHAAL_reverse_df637
# 1.0
# ETHAt2pp
# 1.0
# ETHAt2pp_reverse_2d3e3
# 1.0
# ETHAtex
# 1.0
# ETHAtex_reverse_10a5e
# 1.0
# ETHSO3abcpp
# 1.0
# ETHSO3abcpp_reverse_31ebf
# 1.0
# ETHSO3tex
# 1.0
# ETHSO3tex_reverse_cc017
# 1.0
# ETOHtex
# 1.0
# ETOHtex_reverse_462e1
# 1.0
# ETOHtrpp
# 1.0
# ETOHtrpp_reverse_6a5ec
# 1.0
# F6PA
# 1.0
# F6PA_reverse_816ed
# 1.0
# F6PP
# 1.0
# F6PP_reverse_6022a
# 1.0
# F6Pt6_2pp
# 1.0
# F6Pt6_2pp_reverse_2b592
# 1.0
# F6Ptex
# 1.0
# F6Ptex_reverse_b4bbc
# 1.0
# FA100ACPHi
# 1.0
# FA100ACPHi_reverse_838d9
# 1.0
# FA120ACPHi
# 1.0
# FA120ACPHi_reverse_4e287
# 1.0
# FA140ACPHi
# 1.0
# FA140ACPHi_reverse_c7f9a
# 1.0
# FA141ACPHi
# 1.0
# FA141ACPHi_reverse_c0f63
# 1.0
# FA160ACPHi
# 1.0
# FA160ACPHi_reverse_e7083
# 1.0
# FA161ACPHi
# 1.0
# FA161ACPHi_reverse_c2d36
# 1.0
# FA80ACPHi
# 1.0
# FA80ACPHi_reverse_11bcc
# 1.0
# FACOAE100
# 1.0
# FACOAE100_reverse_4e2b1
# 1.0
# FACOAE120
# 1.0
# FACOAE120_reverse_5b66f
# 1.0
# FACOAE140
# 1.0
# FACOAE140_reverse_a2f77
# 1.0
# FACOAE141
# 1.0
# FACOAE141_reverse_53f9d
# 1.0
# FACOAE160
# 1.0
# FACOAE160_reverse_cf5f6
# 1.0
# FACOAE161
# 1.0
# FACOAE161_reverse_eee30
# 1.0
# FACOAE180
# 1.0
# FACOAE180_reverse_7e403
# 1.0
# FACOAE181
# 1.0
# FACOAE181_reverse_801e1
# 1.0
# FACOAE60
# 1.0
# FACOAE60_reverse_69a9a
# 1.0
# FACOAE80
# 1.0
# FACOAE80_reverse_fab77
# 1.0
# FACOAL100t2pp
# 1.0
# FACOAL100t2pp_reverse_8cd18
# 1.0
# FACOAL120t2pp
# 1.0
# FACOAL120t2pp_reverse_7fbe8
# 1.0
# FACOAL140t2pp
# 1.0
# FACOAL140t2pp_reverse_134cb
# 1.0
# FACOAL141t2pp
# 1.0
# FACOAL141t2pp_reverse_a4489
# 1.0
# FACOAL160t2pp
# 1.0
# FACOAL160t2pp_reverse_57f27
# 1.0
# FACOAL161t2pp
# 1.0
# FACOAL161t2pp_reverse_19e85
# 1.0
# FACOAL180t2pp
# 1.0
# FACOAL180t2pp_reverse_4b889
# 1.0
# FACOAL181t2pp
# 1.0
# FACOAL181t2pp_reverse_74ac3
# 1.0
# FACOAL60t2pp
# 1.0
# FACOAL60t2pp_reverse_f9af5
# 1.0
# FACOAL80t2pp
# 1.0
# FACOAL80t2pp_reverse_a6beb
# 1.0
# FADRx
# 1.0
# FADRx_reverse_48623
# 1.0
# FADRx2
# 1.0
# FADRx2_reverse_f1eff
# 1.0
# FALDH2
# 1.0
# FALDH2_reverse_f1aae
# 1.0
# FALDtex
# 1.0
# FALDtex_reverse_1317b
# 1.0
# FALDtpp
# 1.0
# FALDtpp_reverse_a8bc3
# 1.0
# FALGTHLs
# 1.0
# FALGTHLs_reverse_1514d
# 1.0
# FBA
# 1.0
# FBA_reverse_84806
# 1.0
# FBA3
# 1.0
# FBA3_reverse_0d49f
# 1.0
# FBP
# 1.0
# FBP_reverse_bf2c9
# 1.0
# FCI
# 1.0
# FCI_reverse_74198
# 1.0
# FCLK
# 1.0
# FCLK_reverse_8faf5
# 1.0
# FCLPA
# 1.0
# FCLPA_reverse_df7f9
# 1.0
# FCLT
# 1.0
# FCLT_reverse_1a6b6
# 1.0
# FDH4pp
# 1.0
# FDH4pp_reverse_2bad3
# 1.0
# FDH5pp
# 1.0
# FDH5pp_reverse_ab9f8
# 1.0
# FDMO
# 1.0
# FDMO_reverse_0d455
# 1.0
# FDMO2
# 1.0
# FDMO2_reverse_b2043
# 1.0
# FDMO3
# 1.0
# FDMO3_reverse_1830e
# 1.0
# FDMO4
# 1.0
# FDMO4_reverse_0b2e6
# 1.0
# FDMO6
# 1.0
# FDMO6_reverse_68143
# 1.0
# FE2abcpp
# 1.0
# FE2abcpp_reverse_fbca1
# 1.0
# FE2t2pp
# 1.0
# FE2t2pp_reverse_50348
# 1.0
# FE2t3pp
# 1.0
# FE2t3pp_reverse_f87e0
# 1.0
# FE2tex
# 1.0
# FE2tex_reverse_62032
# 1.0
# FE2tpp
# 1.0
# FE2tpp_reverse_07828
# 1.0
# FE3DCITabcpp
# 1.0
# FE3DCITabcpp_reverse_80761
# 1.0
# FE3DCITtonex
# 1.0
# FE3DCITtonex_reverse_1655d
# 1.0
# FE3DHBZR
# 1.0
# FE3DHBZR_reverse_14b6c
# 1.0
# FE3DHBZSabcpp
# 1.0
# FE3DHBZSabcpp_reverse_ca936
# 1.0
# FE3DHBZStonex
# 1.0
# FE3DHBZStonex_reverse_5e203
# 1.0
# FE3HOXR1
# 1.0
# FE3HOXR1_reverse_26ea5
# 1.0
# FE3HOXR2
# 1.0
# FE3HOXR2_reverse_872a1
# 1.0
# FE3HOXR3
# 1.0
# FE3HOXR3_reverse_fc59b
# 1.0
# FE3HOXUtex
# 1.0
# FE3HOXUtex_reverse_6114b
# 1.0
# FE3HOXUtpp
# 1.0
# FE3HOXUtpp_reverse_03898
# 1.0
# FE3HOXabcpp
# 1.0
# FE3HOXabcpp_reverse_784a3
# 1.0
# FE3HOXexs
# 1.0
# FE3HOXexs_reverse_6e61e
# 1.0
# FE3HOXtonex
# 1.0
# FE3HOXtonex_reverse_1dfd1
# 1.0
# FE3Ri
# 1.0
# FE3Ri_reverse_dd1fc
# 1.0
# FE3abcpp
# 1.0
# FE3abcpp_reverse_4aad8
# 1.0
# FE3tex
# 1.0
# FE3tex_reverse_d0931
# 1.0
# FECRMR1
# 1.0
# FECRMR1_reverse_ac48a
# 1.0
# FECRMR2
# 1.0
# FECRMR2_reverse_c664c
# 1.0
# FECRMR3
# 1.0
# FECRMR3_reverse_0579c
# 1.0
# FECRMUtex
# 1.0
# FECRMUtex_reverse_6c617
# 1.0
# FECRMUtpp
# 1.0
# FECRMUtpp_reverse_d3b60
# 1.0
# FECRMabcpp
# 1.0
# FECRMabcpp_reverse_7f712
# 1.0
# FECRMexs
# 1.0
# FECRMexs_reverse_04dda
# 1.0
# FECRMtonex
# 1.0
# FECRMtonex_reverse_4ef83
# 1.0
# FEENTERR1
# 1.0
# FEENTERR1_reverse_a3dda
# 1.0
# FEENTERR2
# 1.0
# FEENTERR2_reverse_0af6f
# 1.0
# FEENTERR3
# 1.0
# FEENTERR3_reverse_d410a
# 1.0
# FEENTERabcpp
# 1.0
# FEENTERabcpp_reverse_a4ab4
# 1.0
# FEENTERexs
# 1.0
# FEENTERexs_reverse_3df6f
# 1.0
# FEENTERtex
# 1.0
# FEENTERtex_reverse_60b33
# 1.0
# FEENTERtonex
# 1.0
# ...
# 1.0
# PLIPA2E140pp_reverse_3c082
# 1.0
# PLIPA2E141pp
# 1.0
# PLIPA2E141pp_reverse_cb320
# 1.0
# PLIPA2E160pp
# 1.0
# PLIPA2E160pp_reverse_5dad9
# 1.0
# PLIPA2E161pp
# 1.0
# PLIPA2E161pp_reverse_47c6f
# 1.0
# PLIPA2E180pp
# 1.0
# PLIPA2E180pp_reverse_b0d54
# 1.0
# PLIPA2E181pp
# 1.0
# PLIPA2E181pp_reverse_b2969
# 1.0
# PLIPA2G120pp
# 1.0
# PLIPA2G120pp_reverse_27cd5
# 1.0
# PLIPA2G140pp
# 1.0
# PLIPA2G140pp_reverse_c09b5
# 1.0
# PLIPA2G141pp
# 1.0
# PLIPA2G141pp_reverse_d1bc8
# 1.0
# PLIPA2G160pp
# 1.0
# PLIPA2G160pp_reverse_787b3
# 1.0
# PLIPA2G161pp
# 1.0
# PLIPA2G161pp_reverse_66ee8
# 1.0
# PLIPA2G180pp
# 1.0
# PLIPA2G180pp_reverse_a9dc2
# 1.0
# PLIPA2G181pp
# 1.0
# PLIPA2G181pp_reverse_c6379
# 1.0
# PMANM
# 1.0
# PMANM_reverse_53eb0
# 1.0
# PMDPHT
# 1.0
# PMDPHT_reverse_8a0fd
# 1.0
# PMEACPE
# 1.0
# PMEACPE_reverse_002c3
# 1.0
# PMPK
# 1.0
# PMPK_reverse_48b12
# 1.0
# PNTK
# 1.0
# PNTK_reverse_236b6
# 1.0
# PNTOt4pp
# 1.0
# PNTOt4pp_reverse_a34a9
# 1.0
# PNTOtex
# 1.0
# PNTOtex_reverse_e5e15
# 1.0
# POAACR
# 1.0
# POAACR_reverse_7d724
# 1.0
# POR5
# 1.0
# POR5_reverse_fe67d
# 1.0
# POX
# 1.0
# POX_reverse_35cf5
# 1.0
# PPA
# 1.0
# PPA_reverse_c5293
# 1.0
# PPA2
# 1.0
# PPA2_reverse_cb6ee
# 1.0
# PPAKr
# 1.0
# PPAKr_reverse_aefb2
# 1.0
# PPALtex
# 1.0
# PPALtex_reverse_cdcdf
# 1.0
# PPALtpp
# 1.0
# PPALtpp_reverse_3bfa7
# 1.0
# PPAt4pp
# 1.0
# PPAt4pp_reverse_ace84
# 1.0
# PPAtex
# 1.0
# PPAtex_reverse_aa50f
# 1.0
# PPBNGS
# 1.0
# PPBNGS_reverse_dc5a2
# 1.0
# PPC
# 1.0
# PPC_reverse_e854a
# 1.0
# PPCDC
# 1.0
# PPCDC_reverse_39306
# 1.0
# PPCK
# 1.0
# PPCK_reverse_2557d
# 1.0
# PPCSCT
# 1.0
# PPCSCT_reverse_8447c
# 1.0
# PPGPPDP
# 1.0
# PPGPPDP_reverse_82153
# 1.0
# PPK2r
# 1.0
# PPK2r_reverse_30874
# 1.0
# PPKr
# 1.0
# PPKr_reverse_7720e
# 1.0
# PPM
# 1.0
# PPM_reverse_4bb1e
# 1.0
# PPM2
# 1.0
# PPM2_reverse_a5e20
# 1.0
# PPNCL2
# 1.0
# PPNCL2_reverse_a65ee
# 1.0
# PPND
# 1.0
# PPND_reverse_5463c
# 1.0
# PPNDH
# 1.0
# PPNDH_reverse_58300
# 1.0
# PPPGO
# 1.0
# PPPGO_reverse_3a681
# 1.0
# PPPGO3
# 1.0
# PPPGO3_reverse_ccd8c
# 1.0
# PPPNDO
# 1.0
# PPPNDO_reverse_01e00
# 1.0
# PPPNt2rpp
# 1.0
# PPPNt2rpp_reverse_b60aa
# 1.0
# PPPNtex
# 1.0
# PPPNtex_reverse_0c5bc
# 1.0
# PPS
# 1.0
# PPS_reverse_1c319
# 1.0
# PPTHpp
# 1.0
# PPTHpp_reverse_ece28
# 1.0
# PPTtex
# 1.0
# PPTtex_reverse_e0a66
# 1.0
# PRAGSr
# 1.0
# PRAGSr_reverse_fd2d8
# 1.0
# PRAIS
# 1.0
# PRAIS_reverse_8e616
# 1.0
# PRAIi
# 1.0
# PRAIi_reverse_e568f
# 1.0
# PRAMPC
# 1.0
# PRAMPC_reverse_54696
# 1.0
# PRASCSi
# 1.0
# PRASCSi_reverse_11704
# 1.0
# PRATPP
# 1.0
# PRATPP_reverse_99bf0
# 1.0
# PRFGS
# 1.0
# PRFGS_reverse_db4e5
# 1.0
# PRMICI
# 1.0
# PRMICI_reverse_af0a9
# 1.0
# PROD2
# 1.0
# PROD2_reverse_972fe
# 1.0
# PROGLYabcpp
# 1.0
# PROGLYabcpp_reverse_dbb93
# 1.0
# PROGLYtex
# 1.0
# PROGLYtex_reverse_098fe
# 1.0
# PROTRS
# 1.0
# PROTRS_reverse_9d634
# 1.0
# PROabcpp
# 1.0
# PROabcpp_reverse_f67d8
# 1.0
# PROt2rpp
# 1.0
# PROt2rpp_reverse_b5589
# 1.0
# PROt4pp
# 1.0
# PROt4pp_reverse_a83c2
# 1.0
# PROtex
# 1.0
# PROtex_reverse_71ca0
# 1.0
# PRPPS
# 1.0
# PRPPS_reverse_dd7f2
# 1.0
# PSCLYSt2pp
# 1.0
# PSCLYSt2pp_reverse_a94ad
# 1.0
# PSCLYStex
# 1.0
# PSCLYStex_reverse_c9eff
# 1.0
# PSCVT
# 1.0
# PSCVT_reverse_1a852
# 1.0
# PSD120
# 1.0
# PSD120_reverse_167dc
# 1.0
# PSD140
# 1.0
# PSD140_reverse_a8f72
# 1.0
# PSD141
# 1.0
# PSD141_reverse_1bafe
# 1.0
# PSD160
# 1.0
# PSD160_reverse_f80ad
# 1.0
# PSD161
# 1.0
# PSD161_reverse_daeb9
# 1.0
# PSD180
# 1.0
# PSD180_reverse_a7b08
# 1.0
# PSD181
# 1.0
# PSD181_reverse_8b615
# 1.0
# PSERT
# 1.0
# PSERT_reverse_cbee4
# 1.0
# PSERtex
# 1.0
# PSERtex_reverse_36126
# 1.0
# PSP_L
# 1.0
# PSP_L_reverse_cfa3c
# 1.0
# PSP_Lpp
# 1.0
# PSP_Lpp_reverse_9456f
# 1.0
# PSSA120
# 1.0
# PSSA120_reverse_146fc
# 1.0
# PSSA140
# 1.0
# PSSA140_reverse_8cef4
# 1.0
# PSSA141
# 1.0
# PSSA141_reverse_7ab04
# 1.0
# PSSA160
# 1.0
# PSSA160_reverse_f5fc1
# 1.0
# PSSA161
# 1.0
# PSSA161_reverse_cbe33
# 1.0
# PSSA180
# 1.0
# PSSA180_reverse_e607c
# 1.0
# PSSA181
# 1.0
# PSSA181_reverse_83a3e
# 1.0
# PTA2
# 1.0
# PTA2_reverse_720d5
# 1.0
# PTAr
# 1.0
# PTAr_reverse_fce15
# 1.0
# PTHRpp
# 1.0
# PTHRpp_reverse_80890
# 1.0
# PTPATi
# 1.0
# PTPATi_reverse_381d9
# 1.0
# PTRCORNt7pp
# 1.0
# PTRCORNt7pp_reverse_b20e8
# 1.0
# PTRCTA
# 1.0
# PTRCTA_reverse_1e90c
# 1.0
# PTRCabcpp
# 1.0
# PTRCabcpp_reverse_96b27
# 1.0
# PTRCt2pp
# 1.0
# PTRCt2pp_reverse_0b90f
# 1.0
# PTRCtex
# 1.0
# PTRCtex_reverse_a3bd6
# 1.0
# PUNP1
# 1.0
# PUNP1_reverse_e404e
# 1.0
# PUNP2
# 1.0
# PUNP2_reverse_af3de
# 1.0
# PUNP3
# 1.0
# PUNP3_reverse_1db03
# 1.0
# PUNP4
# 1.0
# PUNP4_reverse_e2a37
# 1.0
# PUNP5
# 1.0
# PUNP5_reverse_e49fe
# 1.0
# PUNP6
# 1.0
# PUNP6_reverse_00238
# 1.0
# PUNP7
# 1.0
# PUNP7_reverse_05926
# 1.0
# PYAM5PO
# 1.0
# PYAM5PO_reverse_d008c
# 1.0
# PYDAMK
# 1.0
# PYDAMK_reverse_a0071
# 1.0
# PYDAMtex
# 1.0
# PYDAMtex_reverse_03aa6
# 1.0
# PYDAMtpp
# 1.0
# PYDAMtpp_reverse_3412a
# 1.0
# PYDXK
# 1.0
# PYDXK_reverse_6e9be
# 1.0
# PYDXNK
# 1.0
# PYDXNK_reverse_b5b8e
# 1.0
# PYDXNtex
# 1.0
# PYDXNtex_reverse_c98ca
# 1.0
# PYDXNtpp
# 1.0
# PYDXNtpp_reverse_6fb4f
# 1.0
# PYDXPP
# 1.0
# PYDXPP_reverse_26730
# 1.0
# PYDXtex
# 1.0
# PYDXtex_reverse_1b0e1
# 1.0
# PYDXtpp
# 1.0
# PYDXtpp_reverse_58147
# 1.0
# PYK
# 1.0
# PYK_reverse_bc8ff
# 1.0
# PYNP2r
# 1.0
# PYNP2r_reverse_d20f8
# 1.0
# PYROX
# 1.0
# PYROX_reverse_df090
# 1.0
# PYRt2rpp
# 1.0
# PYRt2rpp_reverse_3baab
# 1.0
# PYRtex
# 1.0
# PYRtex_reverse_59eef
# 1.0
# QMO2
# 1.0
# QMO2_reverse_62073
# 1.0
# QMO3
# 1.0
# QMO3_reverse_81f19
# 1.0
# QUIN2tex
# 1.0
# QUIN2tex_reverse_c1717
# 1.0
# QUIN2tpp
# 1.0
# QUIN2tpp_reverse_a8d27
# 1.0
# QUINDH
# 1.0
# QUINDH_reverse_3ca4c
# 1.0
# QULNS
# 1.0
# QULNS_reverse_66da1
# 1.0
# R15BPK
# 1.0
# R15BPK_reverse_37801
# 1.0
# R1PK
# 1.0
# R1PK_reverse_1c909
# 1.0
# R5PP
# 1.0
# R5PP_reverse_475d3
# 1.0
# R5PPpp
# 1.0
# R5PPpp_reverse_13c4d
# 1.0
# R5Ptex
# 1.0
# R5Ptex_reverse_cbfca
# 1.0
# RBFK
# 1.0
# RBFK_reverse_8faa7
# 1.0
# RBFSa
# 1.0
# RBFSa_reverse_61d96
# 1.0
# RBFSb
# 1.0
# RBFSb_reverse_32299
# 1.0
# RBK
# 1.0
# RBK_reverse_ee934
# 1.0
# RBK_L1
# 1.0
# RBK_L1_reverse_7ee06
# 1.0
# RBP4E
# 1.0
# RBP4E_reverse_12591
# 1.0
# REPHACCOAI
# 1.0
# REPHACCOAI_reverse_4d4b5
# 1.0
# RFAMPtex
# 1.0
# RFAMPtex_reverse_202c2
# 1.0
# RFAMPtpp
# 1.0
# RFAMPtpp_reverse_64e26
# 1.0
# RHAT1
# 1.0
# RHAT1_reverse_0bb45
# 1.0
# RHCCE
# 1.0
# RHCCE_reverse_e91ee
# 1.0
# RIBabcpp
# 1.0
# RIBabcpp_reverse_e1bf5
# 1.0
# RIBtex
# 1.0
# RIBtex_reverse_42338
# 1.0
# RMI
# 1.0
# RMI_reverse_ab7c1
# 1.0
# RMK
# 1.0
# RMK_reverse_f9a9f
# 1.0
# RMNtex
# 1.0
# RMNtex_reverse_90350
# 1.0
# RMNtpp
# 1.0
# RMNtpp_reverse_40417
# 1.0
# RMPA
# 1.0
# RMPA_reverse_a5284
# 1.0
# RNDR1
# 1.0
# RNDR1_reverse_f4be1
# 1.0
# RNDR1b
# 1.0
# RNDR1b_reverse_59a84
# 1.0
# RNDR2
# 1.0
# RNDR2_reverse_7df82
# 1.0
# RNDR2b
# 1.0
# RNDR2b_reverse_73295
# 1.0
# RNDR3
# 1.0
# RNDR3_reverse_bc84a
# 1.0
# RNDR3b
# 1.0
# RNDR3b_reverse_036ef
# 1.0
# RNDR4
# 1.0
# RNDR4_reverse_aff84
# 1.0
# RNDR4b
# 1.0
# RNDR4b_reverse_9c1a0
# 1.0
# RNTR1c2
# 1.0
# RNTR1c2_reverse_b4b14
# 1.0
# RNTR2c2
# 1.0
# RNTR2c2_reverse_b6d45
# 1.0
# RNTR3c2
# 1.0
# RNTR3c2_reverse_8ada2
# 1.0
# RNTR4c2
# 1.0
# RNTR4c2_reverse_0f7f0
# 1.0
# RPE
# 1.0
# RPE_reverse_a1b04
# 1.0
# RPI
# 1.0
# RPI_reverse_853a1
# 1.0
# RZ5PP
# 1.0
# RZ5PP_reverse_b2942
# 1.0
# S2FE2SR
# 1.0
# S2FE2SR_reverse_7a140
# 1.0
# S2FE2SS
# 1.0
# S2FE2SS_reverse_dbd1b
# 1.0
# S2FE2SS2
# 1.0
# S2FE2SS2_reverse_db43c
# 1.0
# S2FE2ST
# 1.0
# S2FE2ST_reverse_557c4
# 1.0
# S4FE4SR
# 1.0
# S4FE4SR_reverse_9a130
# 1.0
# S4FE4ST
# 1.0
# S4FE4ST_reverse_caa0d
# 1.0
# S7PI
# 1.0
# S7PI_reverse_6ace9
# 1.0
# SADH
# 1.0
# SADH_reverse_a0164
# 1.0
# SADT2
# 1.0
# SADT2_reverse_2632d
# 1.0
# SARCOX
# 1.0
# SARCOX_reverse_eebad
# 1.0
# SBTPD
# 1.0
# SBTPD_reverse_9a7da
# 1.0
# SBTptspp
# 1.0
# SBTptspp_reverse_05c76
# 1.0
# SBTtex
# 1.0
# SBTtex_reverse_6aeda
# 1.0
# SCYSDS
# 1.0
# SCYSDS_reverse_3bb75
# 1.0
# SDPDS
# 1.0
# SDPDS_reverse_43d25
# 1.0
# SDPTA
# 1.0
# SDPTA_reverse_76834
# 1.0
# SELCYSS
# 1.0
# SELCYSS_reverse_2f401
# 1.0
# SELGTHR
# 1.0
# SELGTHR_reverse_87696
# 1.0
# SELGTHR2
# 1.0
# SELGTHR2_reverse_076d8
# 1.0
# SELGTHR3
# 1.0
# SELGTHR3_reverse_02c0a
# 1.0
# SELNPS
# 1.0
# SELNPS_reverse_498bb
# 1.0
# SELR
# 1.0
# SELR_reverse_c1bf1
# 1.0
# SELtex
# 1.0
# SELtex_reverse_316ff
# 1.0
# SELtpp
# 1.0
# SELtpp_reverse_466c6
# 1.0
# SEPHCHCS
# 1.0
# SEPHCHCS_reverse_cb185
# 1.0
# SERASr
# 1.0
# SERASr_reverse_eb9c5
# 1.0
# SERAT
# 1.0
# SERAT_reverse_0de5e
# 1.0
# SERD_D
# 1.0
# SERD_D_reverse_0aea1
# 1.0
# SERD_L
# 1.0
# SERD_L_reverse_0f0ab
# 1.0
# SERTRS
# 1.0
# SERTRS_reverse_b65b1
# 1.0
# SERTRS2
# 1.0
# SERTRS2_reverse_0c19b
# 1.0
# SERt2rpp
# 1.0
# SERt2rpp_reverse_94979
# 1.0
# SERt4pp
# 1.0
# SERt4pp_reverse_0b585
# 1.0
# SERtex
# 1.0
# SERtex_reverse_85c6a
# 1.0
# SFGTHi
# 1.0
# SFGTHi_reverse_71e0b
# 1.0
# SGDS
# 1.0
# SGDS_reverse_25ac4
# 1.0
# SGSAD
# 1.0
# SGSAD_reverse_57781
# 1.0
# SHCHCS3
# 1.0
# SHCHCS3_reverse_fb361
# 1.0
# SHCHD2
# 1.0
# SHCHD2_reverse_d3585
# 1.0
# SHCHF
# 1.0
# SHCHF_reverse_fbf31
# 1.0
# SHK3Dr
# 1.0
# SHK3Dr_reverse_d5c8f
# 1.0
# SHKK
# 1.0
# SHKK_reverse_163fd
# 1.0
# SHSL1
# 1.0
# SHSL1_reverse_22e26
# 1.0
# SKMt2pp
# 1.0
# SKMt2pp_reverse_b0b41
# 1.0
# SKMtex
# 1.0
# SKMtex_reverse_af580
# 1.0
# SLNTtex
# 1.0
# SLNTtex_reverse_17a8f
# 1.0
# SLNTtpp
# 1.0
# SLNTtpp_reverse_55a3f
# 1.0
# SO2tex
# 1.0
# SO2tex_reverse_0dea8
# 1.0
# SO2tpp
# 1.0
# SO2tpp_reverse_860e1
# 1.0
# SO3tex
# 1.0
# SO3tex_reverse_94e61
# 1.0
# SO4t2pp
# 1.0
# SO4t2pp_reverse_02fd3
# 1.0
# SO4tex
# 1.0
# SO4tex_reverse_1908f
# 1.0
# SOTA
# 1.0
# SOTA_reverse_98c5d
# 1.0
# SPMDAT1
# 1.0
# SPMDAT1_reverse_5edba
# 1.0
# SPMDAT2
# 1.0
# SPMDAT2_reverse_1a39e
# 1.0
# SPMDabcpp
# 1.0
# SPMDabcpp_reverse_7abfe
# 1.0
# SPMDt3pp
# 1.0
# SPMDt3pp_reverse_9cb9f
# 1.0
# SPMDtex
# 1.0
# SPMDtex_reverse_5a2d5
# 1.0
# SPMS
# 1.0
# SPMS_reverse_92c51
# 1.0
# SPODM
# 1.0
# SPODM_reverse_2648f
# 1.0
# SPODMpp
# 1.0
# SPODMpp_reverse_a61b9
# 1.0
# SSALx
# 1.0
# SSALx_reverse_25de3
# 1.0
# SSALy
# 1.0
# SSALy_reverse_c02ab
# 1.0
# SUCASPtpp
# 1.0
# SUCASPtpp_reverse_bb0a7
# 1.0
# SUCBZL
# 1.0
# SUCBZL_reverse_536e6
# 1.0
# SUCBZS
# 1.0
# SUCBZS_reverse_cdbc9
# 1.0
# SUCCt2_2pp
# 1.0
# SUCCt2_2pp_reverse_bb10d
# 1.0
# SUCCt2_3pp
# 1.0
# SUCCt2_3pp_reverse_1fb63
# 1.0
# SUCCt3pp
# 1.0
# SUCCt3pp_reverse_5b004
# 1.0
# SUCCtex
# 1.0
# SUCCtex_reverse_9b687
# 1.0
# SUCDi
# 1.0
# SUCDi_reverse_480f4
# 1.0
# SUCFUMtpp
# 1.0
# SUCFUMtpp_reverse_ace02
# 1.0
# SUCMALtpp
# 1.0
# SUCMALtpp_reverse_e457b
# 1.0
# SUCOAS
# 1.0
# SUCOAS_reverse_22958
# 1.0
# SUCRtex
# 1.0
# SUCRtex_reverse_77415
# 1.0
# SUCTARTtpp
# 1.0
# SUCTARTtpp_reverse_d1f18
# 1.0
# SUCptspp
# 1.0
# SUCptspp_reverse_66a2f
# 1.0
# SULFACabcpp
# 1.0
# SULFACabcpp_reverse_c4992
# 1.0
# SULFACtex
# 1.0
# SULFACtex_reverse_7636a
# 1.0
# SULRi
# 1.0
# SULRi_reverse_25408
# 1.0
# SULabcpp
# 1.0
# SULabcpp_reverse_40679
# 1.0
# T2DECAI
# 1.0
# T2DECAI_reverse_565c3
# 1.0
# TAGURr
# 1.0
# TAGURr_reverse_82d85
# 1.0
# TALA
# 1.0
# TALA_reverse_adfda
# 1.0
# TARTD
# 1.0
# TARTD_reverse_66ff2
# 1.0
# TARTRDtex
# 1.0
# TARTRDtex_reverse_2e0b9
# 1.0
# TARTRt7pp
# 1.0
# TARTRt7pp_reverse_ece0a
# 1.0
# TARTRtex
# 1.0
# TARTRtex_reverse_41e85
# 1.0
# TARTt2_3pp
# 1.0
# TARTt2_3pp_reverse_d5a3c
# 1.0
# TAUDO
# 1.0
# TAUDO_reverse_465a8
# 1.0
# TAURabcpp
# 1.0
# TAURabcpp_reverse_84498
# 1.0
# TAURtex
# 1.0
# TAURtex_reverse_a14b6
# 1.0
# TCYNTtex
# 1.0
# TCYNTtex_reverse_903a3
# 1.0
# TDP
# 1.0
# TDP_reverse_5ec7c
# 1.0
# TDPADGAT
# 1.0
# TDPADGAT_reverse_b1c03
# 1.0
# TDPAGTA
# 1.0
# TDPAGTA_reverse_0f964
# 1.0
# TDPDRE
# 1.0
# TDPDRE_reverse_26405
# 1.0
# TDPDRR
# 1.0
# TDPDRR_reverse_e7bd2
# 1.0
# TDPGDH
# 1.0
# TDPGDH_reverse_f570d
# 1.0
# TDSK
# 1.0
# TDSK_reverse_4bbc5
# 1.0
# TDSR1
# 1.0
# TDSR1_reverse_270e9
# 1.0
# TDSR2
# 1.0
# TDSR2_reverse_b23c2
# 1.0
# TGBPA
# 1.0
# TGBPA_reverse_3cfab
# 1.0
# THD2pp
# 1.0
# THD2pp_reverse_e68d7
# 1.0
# THDPS
# 1.0
# THDPS_reverse_41a90
# 1.0
# THFAT
# 1.0
# THFAT_reverse_463de
# 1.0
# THIORDXi
# 1.0
# THIORDXi_reverse_27f13
# 1.0
# THMDt2pp
# 1.0
# THMDt2pp_reverse_ed1b8
# 1.0
# THMDt2rpp
# 1.0
# THMDt2rpp_reverse_2371a
# 1.0
# THMDtex
# 1.0
# THMDtex_reverse_e82c0
# 1.0
# THMabcpp
# 1.0
# THMabcpp_reverse_f17bf
# 1.0
# THMtex
# 1.0
# THMtex_reverse_1e778
# 1.0
# THRA2i
# 1.0
# THRA2i_reverse_e98cd
# 1.0
# THRAi
# 1.0
# THRAi_reverse_d8e46
# 1.0
# THRD
# 1.0
# THRD_reverse_83253
# 1.0
# THRD_L
# 1.0
# THRD_L_reverse_4c55d
# 1.0
# THRPtex
# 1.0
# THRPtex_reverse_2f25b
# 1.0
# THRS
# 1.0
# THRS_reverse_a994c
# 1.0
# THRTRS
# 1.0
# THRTRS_reverse_12237
# 1.0
# THRabcpp
# 1.0
# THRabcpp_reverse_41c99
# 1.0
# THRt2pp
# 1.0
# THRt2pp_reverse_7cdd2
# 1.0
# THRt2rpp
# 1.0
# THRt2rpp_reverse_b03e3
# 1.0
# THRt4pp
# 1.0
# THRt4pp_reverse_394e5
# 1.0
# THRtex
# 1.0
# THRtex_reverse_2a874
# 1.0
# THYMt3pp
# 1.0
# THYMt3pp_reverse_be8cd
# 1.0
# THYMtex
# 1.0
# THYMtex_reverse_1b098
# 1.0
# THZPSN3
# 1.0
# THZPSN3_reverse_90214
# 1.0
# TKT1
# 1.0
# TKT1_reverse_a1021
# 1.0
# TKT2
# 1.0
# TKT2_reverse_7ebc7
# 1.0
# TMAOR1
# 1.0
# TMAOR1_reverse_ba0cf
# 1.0
# TMAOR1pp
# 1.0
# TMAOR1pp_reverse_dafd5
# 1.0
# TMAOR2
# 1.0
# TMAOR2_reverse_ad798
# 1.0
# TMAOR2pp
# 1.0
# TMAOR2pp_reverse_d7195
# 1.0
# TMAOtex
# 1.0
# TMAOtex_reverse_4519a
# 1.0
# TMAtex
# 1.0
# TMAtex_reverse_4c54e
# 1.0
# TMDK1
# 1.0
# TMDK1_reverse_ecb2e
# 1.0
# TMDPP
# 1.0
# TMDPP_reverse_1aa90
# 1.0
# TMDS
# 1.0
# TMDS_reverse_0a1f4
# 1.0
# TMK
# 1.0
# TMK_reverse_99629
# 1.0
# TMPK
# 1.0
# TMPK_reverse_b7673
# 1.0
# TMPPP
# 1.0
# TMPPP_reverse_f275c
# 1.0
# TPI
# 1.0
# TPI_reverse_c2c3b
# 1.0
# TPRDCOAS
# 1.0
# TPRDCOAS_reverse_56965
# 1.0
# TRDR
# 1.0
# TRDR_reverse_6372e
# 1.0
# TRE6PH
# 1.0
# TRE6PH_reverse_ba9c2
# 1.0
# TRE6PP
# 1.0
# TRE6PP_reverse_4fe3e
# 1.0
# TRE6PS
# 1.0
# TRE6PS_reverse_96346
# 1.0
# TREH
# 1.0
# TREH_reverse_3db52
# 1.0
# TREHpp
# 1.0
# TREHpp_reverse_a400f
# 1.0
# TREptspp
# 1.0
# TREptspp_reverse_dc50f
# 1.0
# TREtex
# 1.0
# TREtex_reverse_1e6cc
# 1.0
# TRPAS2
# 1.0
# TRPAS2_reverse_d1c71
# 1.0
# TRPS1
# 1.0
# TRPS1_reverse_35c22
# 1.0
# TRPS2
# 1.0
# TRPS2_reverse_cd73f
# 1.0
# TRPS3
# 1.0
# TRPS3_reverse_bdfbb
# 1.0
# TRPTRS
# 1.0
# TRPTRS_reverse_f29b7
# 1.0
# TRPt2rpp
# 1.0
# TRPt2rpp_reverse_ff3d1
# 1.0
# TRPtex
# 1.0
# TRPtex_reverse_e7b4f
# 1.0
# TRSARr
# 1.0
# TRSARr_reverse_ac605
# 1.0
# TSULabcpp
# 1.0
# TSULabcpp_reverse_1aea7
# 1.0
# TSULtex
# 1.0
# TSULtex_reverse_0b131
# 1.0
# TTDCAtexi
# 1.0
# TTDCAtexi_reverse_a3936
# 1.0
# TTDCEAtexi
# 1.0
# TTDCEAtexi_reverse_8b32c
# 1.0
# TTRCYCtex
# 1.0
# TTRCYCtex_reverse_64a12
# 1.0
# TTRCYCtpp
# 1.0
# TTRCYCtpp_reverse_16a56
# 1.0
# TUNGSabcpp
# 1.0
# TUNGSabcpp_reverse_a2be8
# 1.0
# TUNGStex
# 1.0
# TUNGStex_reverse_30dbf
# 1.0
# TYMtex
# 1.0
# TYMtex_reverse_996e2
# 1.0
# TYRL
# 1.0
# TYRL_reverse_b74b0
# 1.0
# TYROXDApp
# 1.0
# TYROXDApp_reverse_1bd49
# 1.0
# TYRPpp
# 1.0
# TYRPpp_reverse_0b842
# 1.0
# TYRPtex
# 1.0
# TYRPtex_reverse_208a8
# 1.0
# TYRTA
# 1.0
# TYRTA_reverse_e9311
# 1.0
# TYRTRS
# 1.0
# TYRTRS_reverse_27d64
# 1.0
# TYRt2rpp
# 1.0
# TYRt2rpp_reverse_cf011
# 1.0
# TYRtex
# 1.0
# TYRtex_reverse_6da66
# 1.0
# ThDPAT
# 1.0
# ThDPAT_reverse_ae33f
# 1.0
# U23GAAT
# 1.0
# U23GAAT_reverse_0353e
# 1.0
# UAAGDS
# 1.0
# UAAGDS_reverse_313a9
# 1.0
# UACGALPpp
# 1.0
# UACGALPpp_reverse_840fa
# 1.0
# UACGAMPpp
# 1.0
# UACGAMPpp_reverse_b239e
# 1.0
# UACGAMtex
# 1.0
# UACGAMtex_reverse_0aadf
# 1.0
# UACMAMO
# 1.0
# UACMAMO_reverse_b0219
# 1.0
# UAG2E
# 1.0
# UAG2E_reverse_83643
# 1.0
# UAGAAT
# 1.0
# UAGAAT_reverse_24f8b
# 1.0
# UAGCVT
# 1.0
# UAGCVT_reverse_ba1ab
# 1.0
# UAGDP
# 1.0
# UAGDP_reverse_a5ec0
# 1.0
# UAGPT3
# 1.0
# UAGPT3_reverse_7f3f7
# 1.0
# UAMAGS
# 1.0
# UAMAGS_reverse_a0d94
# 1.0
# UAMAS
# 1.0
# UAMAS_reverse_2b5e6
# 1.0
# UAPGR
# 1.0
# UAPGR_reverse_4f67b
# 1.0
# UDCPDP
# 1.0
# UDCPDP_reverse_1813b
# 1.0
# UDCPDPS
# 1.0
# UDCPDPS_reverse_04082
# 1.0
# UDCPDPpp
# 1.0
# UDCPDPpp_reverse_50c3e
# 1.0
# UDCPPtppi
# 1.0
# UDCPPtppi_reverse_70e48
# 1.0
# UDPACGALtex
# 1.0
# UDPACGALtex_reverse_db14e
# 1.0
# UDPG4E
# 1.0
# UDPG4E_reverse_08c7f
# 1.0
# UDPGALM
# 1.0
# UDPGALM_reverse_dc620
# 1.0
# UDPGALPpp
# 1.0
# UDPGALPpp_reverse_e2436
# 1.0
# UDPGALtex
# 1.0
# UDPGALtex_reverse_19783
# 1.0
# UDPGD
# 1.0
# UDPGD_reverse_de167
# 1.0
# UDPGDC
# 1.0
# UDPGDC_reverse_f654b
# 1.0
# UDPGLCURtex
# 1.0
# UDPGLCURtex_reverse_3d157
# 1.0
# UDPGPpp
# 1.0
# UDPGPpp_reverse_caf0c
# 1.0
# UDPGtex
# 1.0
# UDPGtex_reverse_024fe
# 1.0
# UDPKAAT
# 1.0
# UDPKAAT_reverse_39cbd
# 1.0
# UGLCURPpp
# 1.0
# UGLCURPpp_reverse_02763
# 1.0
# UGLT
# 1.0
# UGLT_reverse_5e7f8
# 1.0
# UGLYCH
# 1.0
# UGLYCH_reverse_38b1a
# 1.0
# UGMDDS
# 1.0
# UGMDDS_reverse_2401f
# 1.0
# UHGADA
# 1.0
# UHGADA_reverse_608c0
# 1.0
# ULA4NFT
# 1.0
# ULA4NFT_reverse_07217
# 1.0
# ULA4Ntppi
# 1.0
# ULA4Ntppi_reverse_52ebe
# 1.0
# UM3PL
# 1.0
# UM3PL_reverse_32754
# 1.0
# UM4PCP
# 1.0
# UM4PCP_reverse_86d06
# 1.0
# UM4PL
# 1.0
# UM4PL_reverse_c309d
# 1.0
# UMPK
# 1.0
# UMPK_reverse_ae8e3
# 1.0
# UMPtex
# 1.0
# UMPtex_reverse_15b55
# 1.0
# UPLA4FNF
# 1.0
# UPLA4FNF_reverse_b8c75
# 1.0
# UPLA4FNT
# 1.0
# UPLA4FNT_reverse_a4d3d
# 1.0
# UPP3MT
# 1.0
# UPP3MT_reverse_2adf0
# 1.0
# UPP3S
# 1.0
# UPP3S_reverse_8bb53
# 1.0
# UPPDC1
# 1.0
# UPPDC1_reverse_cb592
# 1.0
# UPPRT
# 1.0
# UPPRT_reverse_07052
# 1.0
# URACPAH
# 1.0
# URACPAH_reverse_b5224
# 1.0
# URAt2pp
# 1.0
# URAt2pp_reverse_17581
# 1.0
# URAt2rpp
# 1.0
# URAt2rpp_reverse_8694e
# 1.0
# URAtex
# 1.0
# URAtex_reverse_1b290
# 1.0
# URDGLYCD
# 1.0
# URDGLYCD_reverse_cb5de
# 1.0
# UREAtex
# 1.0
# UREAtex_reverse_e1c1e
# 1.0
# UREAtpp
# 1.0
# UREAtpp_reverse_c8094
# 1.0
# URIC
# 1.0
# URIC_reverse_bb103
# 1.0
# URIH
# 1.0
# URIH_reverse_64395
# 1.0
# URIK2
# 1.0
# URIK2_reverse_f3df8
# 1.0
# URIt2pp
# 1.0
# URIt2pp_reverse_0d906
# 1.0
# URIt2rpp
# 1.0
# URIt2rpp_reverse_b0a53
# 1.0
# URItex
# 1.0
# URItex_reverse_fac5c
# 1.0
# USHD
# 1.0
# USHD_reverse_f9e3a
# 1.0
# VALTA
# 1.0
# VALTA_reverse_1d084
# 1.0
# VALTRS
# 1.0
# VALTRS_reverse_72083
# 1.0
# VALabcpp
# 1.0
# VALabcpp_reverse_f400d
# 1.0
# VALt2rpp
# 1.0
# VALt2rpp_reverse_0dc61
# 1.0
# VALtex
# 1.0
# VALtex_reverse_126bd
# 1.0
# VPAMTr
# 1.0
# VPAMTr_reverse_872bd
# 1.0
# WCOS
# 1.0
# WCOS_reverse_1505f
# 1.0
# X5PL3E
# 1.0
# X5PL3E_reverse_a59f0
# 1.0
# XAND
# 1.0
# XAND_reverse_04307
# 1.0
# XANt2pp
# 1.0
# XANt2pp_reverse_d1ca9
# 1.0
# XANtex
# 1.0
# XANtex_reverse_35e9c
# 1.0
# XANtpp
# 1.0
# XANtpp_reverse_97eaa
# 1.0
# XMPtex
# 1.0
# XMPtex_reverse_59397
# 1.0
# XPPT
# 1.0
# XPPT_reverse_acb2c
# 1.0
# XTSNH
# 1.0
# XTSNH_reverse_62c83
# 1.0
# XTSNt2rpp
# 1.0
# XTSNt2rpp_reverse_e1a1b
# 1.0
# XTSNtex
# 1.0
# XTSNtex_reverse_a7e55
# 1.0
# XYLI1
# 1.0
# XYLI1_reverse_ba684
# 1.0
# XYLI2
# 1.0
# XYLI2_reverse_40bca
# 1.0
# XYLK
# 1.0
# XYLK_reverse_f9b1e
# 1.0
# XYLK2
# 1.0
# XYLK2_reverse_ce1fa
# 1.0
# XYLUt2pp
# 1.0
# XYLUt2pp_reverse_a8188
# 1.0
# XYLUtex
# 1.0
# XYLUtex_reverse_653ed
# 1.0
# XYLabcpp
# 1.0
# XYLabcpp_reverse_35686
# 1.0
# XYLt2pp
# 1.0
# XYLt2pp_reverse_441ce
# 1.0
# XYLtex
# 1.0
# XYLtex_reverse_758dc
# 1.0
# ZN2abcpp
# 1.0
# ZN2abcpp_reverse_93cd5
# 1.0
# ZN2t3pp
# 1.0
# ZN2t3pp_reverse_c5ed9
# 1.0
# ZN2tpp
# 1.0
# ZN2tpp_reverse_5a7f0
# 1.0
# ZNabcpp
# 1.0
# ZNabcpp_reverse_14d34
# 1.0
# Zn2tex
# 1.0
# Zn2tex_reverse_6b2c9
# 1.0

# %%
for x in model.variables: 
    if x.name.startswith('DM_') or x.name.startswith('SK_') or x.name.startswith('EX_'):
        model.objective.set_linear_coefficients(coef)

# Set your desired bound on the original objective (here, biomass, which has been added to 
# the universal model from the model to be gapfilled)
model.reactions.get_by_id(objective_reaction).lower_bound = 0.80

# optimize and grab active reactions. 1E-8 is an arbitrary threshold, and in my example nothing
# had fluxes between 1E-5 and 1E-10, suggesting the threshold isn't as big of a deal as in the
# MILP formulation. This code will also return flux through exchange reactions (and any reaction
# from the model that was not present in the universal; you'll have to find another way to filter these).
solution = model.optimize()
get_fluxes = set([r.id for r in model.reactions])
add_reactions_to_model = [rxn for rxn in get_fluxes if abs(solution.x_dict[rxn]) > 1E-8]
